# %% [markdown]
# > title : 제 4회 ETRI 휴먼이해 인공지능 논문경진대회 <br>
# > author : hjy,byc <br>

# %% [markdown]
# ### 📦 라이브러리

# %%
! pip install haversine >/dev/null
! pip install optuna  >/dev/null
! pip install category_encoders >/dev/null
! pip install tabpfn  >/dev/null
! pip install catboost >/dev/null

# %%
# 기본 모듈
import os
import sys
import re
import ast
import glob
import random
import warnings
from collections import Counter
from math import radians, cos, sin, asin, sqrt
from functools import reduce
from datetime import datetime, timedelta, time

# 데이터 처리
import numpy as np
import pandas as pd

# 시각화
import matplotlib.pyplot as plt
import seaborn as sns

# 머신러닝
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score
from sklearn.metrics import f1_score, roc_auc_score, roc_curve
from sklearn.preprocessing import LabelEncoder, StandardScaler
from category_encoders import TargetEncoder
from lightgbm import LGBMClassifier, log_evaluation, early_stopping
import lightgbm as lgb
from tabpfn import TabPFNClassifier

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# 기타
from tqdm import tqdm
from tqdm.auto import tqdm as auto_tqdm  # 필요 시 구분
from scipy.stats import entropy
from haversine import haversine
from io import StringIO

# pandas 옵션
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# 기타
warnings.filterwarnings('ignore')

# %%
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils.class_weight import compute_sample_weight
from sklearn import metrics

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(1)

# %%
string = """
subject_id,sleep_date
id01,2024-07-24
id01,2024-08-26
id01,2024-08-28
id01,2024-08-29
id02,2024-08-23
id02,2024-09-24
id02,2024-09-26
id02,2024-09-27
id03,2024-08-30
id03,2024-09-01
id03,2024-09-02
id03,2024-09-06
id04,2024-09-03
id04,2024-10-10
id04,2024-10-12
id04,2024-10-13
id05,2024-10-19
id05,2024-10-23
id05,2024-10-24
id05,2024-10-27
id06,2024-07-25
id06,2024-07-26
id06,2024-07-27
id06,2024-07-30
id07,2024-07-07
id07,2024-08-02
id07,2024-08-04
id07,2024-08-05
id08,2024-08-28
id08,2024-08-29
id08,2024-08-30
id08,2024-09-02
id09,2024-08-02
id09,2024-08-31
id09,2024-09-02
id09,2024-09-03
id10,2024-08-28
id10,2024-08-30
id10,2024-08-31
id10,2024-09-03
"""

# DataFrame 생성
valid_ids = pd.read_csv(StringIO(string), sep=',')
valid_ids['pk'] = valid_ids['subject_id']+valid_ids['sleep_date']

# %% [markdown]
# ### 📦 데이터 읽기

# %%
from google.colab import drive, files
drive.mount('/content/drive')

path = '/content/drive/MyDrive/data/ch2025_data_items/share/'

train = pd.read_parquet(f'{path}train_63775.parquet')
test = pd.read_parquet(f'{path}test_63775.parquet')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### ============================

# %% [markdown]
# ### LLM

# %%
import pandas as pd
import torch
from torch import nn
from huggingface_hub import login
import os
from torch.utils.data import Dataset
import numpy as np
import pandas as pd
import re
from transformers import LlamaTokenizer, LlamaForCausalLM
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification, LlamaForSequenceClassification
from peft import (
    LoraConfig,
    get_peft_model,
    get_peft_model_state_dict,
)
from tqdm import tqdm

from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchmetrics import Accuracy

import wandb
wandb.login(key="5fa8dfb2c5be3c888bfe0101437a8fa22fbdf0e0")
wandb.init(project="etri_lifelog", entity="byc3230")

import warnings
warnings.filterwarnings("ignore")
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

from transformers import LlamaTokenizer, LlamaForCausalLM
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification, LlamaForSequenceClassification

from peft import TaskType

import torch
import torch.nn as nn
import torch.nn.functional as F
# Out:
# 2025-06-09 10:06:43.981248: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749463604.175248      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749463604.227803      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
#llm_model_path = 'Qwen/Qwen2.5-0.5B'
#llm_model_path = "Qwen/Qwen3-0.6B-Base" #똑같음
#llm_model_path = "Qwen/Qwen3-1.7B" # 성공 좋음
#llm_model_path = "EleutherAI/pythia-70m"
#llm_model_path = "facebook/opt-125m" # 괜찮음
#llm_model_path = "openai-community/gpt2"
#llm_model_path = 'Qwen/Qwen2.5-0.5B-Instruct'
#llm_model_path = "distilbert/distilgpt2"
llm_model_path = "Qwen/Qwen3-0.6B"

tokenizer = AutoTokenizer.from_pretrained(llm_model_path, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# tokenizer_config.json:   0%|          | 0.00/9.73k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %%
config = LoraConfig(
    # r=16,
    # lora_alpha=32,
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],#Best
    #target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
    lora_dropout=0.1,
    bias="none",
    # task_type="SEQ_CLS",
    #task_type=TaskType.SEQ_CLS,
    modules_to_save=["classifier"],
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class CustomDataset(Dataset):
    def __init__(self, twitterDF):
        self.twitterDF = twitterDF

    def __len__(self):
        return len(self.twitterDF.index)

    def __getitem__(self, idx):
        return np.array([idx])

# %%
def train_iter(model, loader, optimizer, criterion, twitterDFTrain_clean):
    model.train()

    total_loss = 0
    correct = 0
    pred = []
    label = []
    for batchIdx, sampledIdx in enumerate(tqdm(loader, position=0, leave=True)):
        #print(data)

        optimizer.zero_grad()

        #text
        sampledIdx = sampledIdx.cpu().data.numpy()
        sampledRowText = list(twitterDFTrain_clean["text"].iloc[list(sampledIdx.flatten())])
        #label
        sampledRowLabels = torch.tensor(list(twitterDFTrain_clean["label"].iloc[list(sampledIdx.flatten())])).to(device)

        #encoded
        encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to(device) # Output shape: [bs, num_Labels]
        encoded_inputIds = encoded_input["input_ids"].to(device)
        encoded_attnMask = encoded_input["attention_mask"].to(device)

        #model
        outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)
        #print(outputs)

        # label type change
        sampledRowLabels = sampledRowLabels.to(outputs.logits.device).long()  # shape: [1]
        #print(outputs.logits)
        # loss
        loss = criterion(outputs.logits, sampledRowLabels)
        total_loss += loss.item()

        #acurracy
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
        predicted_class = torch.argmax(outputs.logits, dim=-1)
        pred.extend(predicted_class.flatten().cpu().data.numpy())
        label.extend(sampledRowLabels.cpu().data.numpy())

        #back propagation
        loss.backward()
        optimizer.step()

    train_accuracy_score = metrics.f1_score(label,pred, average='macro')
    return total_loss / len(loader), train_accuracy_score

# %%
def valid_iter(model, valid_loader, criterion, twitterDFVal_clean):
    model.eval()
    with torch.no_grad():

        total_loss = 0
        correct = 0

        pred = []
        label = []

        for batchIdx, sampledIdx in enumerate(tqdm(valid_loader, position=0, leave=True)):

            sampledRowText = list(twitterDFVal_clean["text"].iloc[list(sampledIdx.flatten())])
            sampledRowLabels = torch.tensor(list(twitterDFVal_clean["label"].iloc[list(sampledIdx.flatten())]))

            encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to(device) # Output shape: [bs, num_Labels]
            encoded_inputIds = encoded_input["input_ids"].to(device)
            encoded_attnMask = encoded_input["attention_mask"].to(device)

            #model
            outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)

            # label type change
            sampledRowLabels = sampledRowLabels.to(outputs.logits.device).long()  # shape: [1]

            # loss
            loss = criterion(outputs.logits, sampledRowLabels)
            total_loss += loss.item()

            #acurracy
            probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
            predicted_class = torch.argmax(outputs.logits, dim=-1)
            pred.extend(predicted_class.flatten().cpu().data.numpy())
            label.extend(sampledRowLabels.cpu().data.numpy())

        valid_accuracy_score = metrics.f1_score(label,pred, average='macro')
    return total_loss/len(valid_loader), valid_accuracy_score

# %%
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha  # optional: list or tensor of class weights
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none', weight=self.alpha)
        pt = torch.exp(-ce_loss)  # prevents nans when probability is 0
        focal_loss = ((1 - pt) ** self.gamma) * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
def seed_worker(worker_id):
    worker_seed = 42 + worker_id
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(42)

# %%
# Define your training loop
#epochs = 5
epochs = 16
#optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
#criterion = nn.BCEWithLogitsLoss()

total_loss = 0
correct = 0

#best model 를 찾기 위한
best = np.inf

#3번까지 validation loss 터지면 stop 시킴
patience = 3

#best model save
#result_path = "/kaggle/working/"
#best_model_path = os.path.join(result_path, 'best_model.pt')
best_model_path = 'best_model.pt'
bad_counter = 0

# %% [markdown]
# ### get_oof_predictions

# %%
def get_oof_predictions(X, y, lgb_params, xgb_params, n_splits=5, is_multiclass=False, num_class=None, early_stop=False):
    oof_preds_lgb = np.zeros(len(X))
    oof_preds_xgb = np.zeros(len(X))
    oof_preds_cat = np.zeros(len(X))
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    for train_idx, valid_idx in skf.split(X, y):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        if is_multiclass:
            llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=3, torch_dtype=torch.float16, device_map='auto')
            lora_model = get_peft_model(llm_model, config)
        else:
            llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=2, torch_dtype=torch.float16, device_map='auto')
            lora_model = get_peft_model(llm_model, config)
        # LightGBM
        if is_multiclass:
            lgb_model = LGBMClassifier(**lgb_params, objective='multiclass', num_class=num_class)
        else:
            lgb_model = LGBMClassifier(**lgb_params)

        # XGBoost
        if is_multiclass:
            xgb_model = XGBClassifier(**xgb_params, objective='multi:softmax', num_class=num_class)
        else:
            xgb_model = XGBClassifier(**xgb_params)

        # CatBoost
        if is_multiclass:
            cat_model = CatBoostClassifier(**common_params_cat2, objective='MultiClass', classes_count=num_class)
        else:
            cat_model = CatBoostClassifier(**common_params_cat)

        if early_stop:
            lgb_model.fit(
                X_train, y_train,
                eval_set=[(X_train, y_train), (X_valid, y_valid)],
                callbacks=[early_stopping(stopping_rounds=100, verbose=False)]
            )
            xgb_model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                early_stopping_rounds=100,
                verbose=False
            )
            cat_model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                early_stopping_rounds=100,
                verbose=False
            )
        else:
            X_train_llm = X_train
            X_valid_llm = X_valid

            def prepare_input_text(row):
                target_cols = ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']
                feature_cols = [col for col in X_train.columns if col not in target_cols]

                instruct_txt = ""
                if is_multiclass:
                    instruct_txt = "Classify 0 or 1 or 2. ###DATA### "
                else:
                    instruct_txt = "Classify 0 or 1. ###DATA### "

                for clm in feature_cols:
                    instruct_txt += f"{clm} : {row[clm]}, "

                return instruct_txt.strip()[:-1]+'.'

            X_train_llm['input'] = X_train_llm.apply(lambda x: prepare_input_text(x),axis=1)
            X_valid_llm['input'] = X_valid_llm.apply(lambda x: prepare_input_text(x),axis=1)

            X_train_llm["label"] = y_train
            X_valid_llm['label'] = y_valid
            X_train_llm["text"] = X_train_llm["input"]
            X_valid_llm["text"] = X_valid_llm["input"]

            training_data = CustomDataset(X_train_llm)
            validation_data = CustomDataset(X_valid_llm)

            train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True)
            val_dataloader = DataLoader(validation_data, batch_size=1, shuffle=False)

            twitterDFTrain_clean = X_train_llm
            twitterDFVal_clean = X_valid_llm

            if is_multiclass:
                total_loss = 0
                correct = 0
                bad_counter = 0
                #best model 를 찾기 위한
                best = np.inf

                for epoch in range(epochs):
                    avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, twitterDFTrain_clean)

                    avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, twitterDFVal_clean)

                    if avg_vaild_loss < best:
                        best = avg_vaild_loss
                        torch.save(llm_model.state_dict(), best_model_path)
                        bad_counter = 0
                    else:
                        bad_counter += 1

                    if bad_counter == patience:
                        break

                    print(f'Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')

                    wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})
            else:
                total_loss = 0
                correct = 0
                bad_counter = 0
                #best model 를 찾기 위한
                best = np.inf
                for epoch in range(epochs):
                    avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, twitterDFTrain_clean)

                    avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, twitterDFVal_clean)

                    if avg_vaild_loss < best:
                        best = avg_vaild_loss
                        torch.save(llm_model.state_dict(), best_model_path)
                        bad_counter = 0
                    else:
                        bad_counter += 1

                    if bad_counter == patience:
                        break

                    print(f'Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')

                    wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})

            if is_multiclass:

                # 클래스 weight 계산
                classes = np.unique(y_train)
                weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
                class_weights = dict(zip(classes, weights))

                # 각 샘플에 대해 weight 매핑
                w_train = pd.Series(y_train).map(class_weights)
                #print(w_train)

                w_train = compute_sample_weight(class_weight='balanced', y=y_train)
                print(w_train)

                lgb_model.fit(X_train, y_train, sample_weight=w_train)
                xgb_model.fit(X_train, y_train, sample_weight=w_train)
                cat_model.fit(X_train, y_train)
            else:
                lgb_model.fit(X_train, y_train)
                xgb_model.fit(X_train, y_train)
                cat_model.fit(X_train, y_train)


        # Get predictions
        lgb_preds = lgb_model.predict(X_valid)
        xgb_preds = xgb_model.predict(X_valid)
        cat_preds = cat_model.predict(X_valid).ravel()  # ✅ 2차원 → 1차원

        # Store predictions
        oof_preds_lgb[valid_idx] = lgb_preds
        oof_preds_xgb[valid_idx] = xgb_preds
        oof_preds_cat[valid_idx] = cat_preds

    # Ensemble predictions (7:3 ratio)
    oof_preds = lgb_A * oof_preds_lgb + xgb_B * oof_preds_xgb + cat_C * oof_preds_cat

    if not is_multiclass:
        oof_preds = (oof_preds > 0.5).astype(int)
    else:
        oof_preds = np.round(oof_preds).astype(int)

    return oof_preds

# %%
Prompt = {
    "Q1": "Based on the following sleep-related information, classify the overall perceived sleep quality upon waking as either below or above the individual’s average. (0: Below average, 1: Above average) ",
    "Q2": "Using the following data, determine the level of physical fatigue the individual felt before sleep. (0: High fatigue, 1: Low fatigue) ",
    "Q3": "Based on the information below, classify the stress level the individual experienced before going to bed. (0: High stress, 1: Low stress) ",
    "S1": "Based on the provided information, classify how well the individual's total sleep time (TST) aligns with recommended sleep guidelines. (0: Not met, 1: Partially met, 2: Fully met) ",
    "S2": "Using the following indicators, determine whether the individual met the guideline for sleep efficiency (SE). (0: Not met, 1: Met) ",
    "S3": "From the data provided, assess if the sleep onset latency (SOL) guideline was met. (0: Not met, 1: Met) "
}

# %% [markdown]
# ### inference

# %%
def inference(model, loader, test_data, col):
    #best model 불러와서 call 하기
    model.load_state_dict(torch.load(col+"_"+best_model_path))
    model.eval()

    preds = []
    preds_prob = []
    with torch.no_grad():
        total_loss = 0
        correct = 0

        pred = []
        label = []

        for batchIdx, sampledIdx in enumerate(tqdm(loader, position=0, leave=True)):

            sampledRowText = list(test_data["text"].iloc[list(sampledIdx.flatten())])

            encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to("cuda") # Output shape: [bs, num_Labels]
            encoded_inputIds = encoded_input["input_ids"].to("cuda")
            encoded_attnMask = encoded_input["attention_mask"].to("cuda")

            outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)
            logits = outputs.logits


            #acurracy
            probs = torch.nn.functional.softmax(outputs.logits.cpu(), dim=-1)

            #확률구하기
            preds_prob.extend(probs.cpu().data.numpy())

            #acurracy
            pred.extend(torch.argmax(logits, dim=1).flatten().cpu().data.numpy())

    return pred, preds_prob

# %% [markdown]
# ### run_basemodel

# %%
import gc
#epochs = 1
epochs = 16
print("=====epochs "+str(epochs)+" gogo======")
def run_basemodel(train, test, valid_ids, common_params, n_splits, random_state=42, early_stop=False):

    #version 33로 진행완료 Best
    lgb_A = 0.3
    xgb_B = 0.3
    cat_C = 0.3
    llm_D = 0.1

    print("=========valid_ids==========")
    print(valid_ids)
    train_df = train.copy()
    test_df = test.copy()

    submission_final = test_df[['subject_id', 'sleep_date', 'lifelog_date']].copy()
    submission_final['lifelog_date'] = pd.to_datetime(submission_final['lifelog_date']).dt.date

    # 타겟
    targets_binary = ['Q1', 'Q2', 'Q3', 'S2', 'S3']
    targets_binary_name = ['기상직후수면질','취침전신체적피로','취침전스트레스','수면효율','수면잠들기시간']
    target_multiclass = 'S1'
    all_targets = targets_binary + [target_multiclass]

    # 노이즈 수준 설정
    def add_noise(series, noise_level, seed=3):
        rng = np.random.default_rng(seed)
        return series * (1 + noise_level * rng.standard_normal(len(series)))

    noise_level = 0.015  # 필요에 따라 조정

    # 타겟인코딩
    # m = 0: 스무딩 없이 범주별 평균만 사용합니다. 관측 수가 많은 범주에는 적합하지만, 적은 경우 과적합 위험이 있습니다.
    # m = 1~10: 일반적인 기본값으로, 대부분의 상황에서 안정적인 성능을 보입니다.
    # m = 50~300: 관측 수가 매우 적은 범주가 많거나 데이터가 희소한 경우에 유용합니다.
    for tgt in all_targets:

      encoder_feats = ['subject_id','month','weekend'] # 'weekday', 'subject_id','month','weekend'

      #### 타겟인코딩1

      subject_mean = train_df.groupby(encoder_feats)[tgt].mean().rename(f'{tgt}_te')
      train_df = train_df.merge(subject_mean, on=encoder_feats, how='left')
      test_df = test_df.merge(subject_mean, on=encoder_feats, how='left')
      global_mean = train_df[tgt].mean()
      test_df[f'{tgt}_te'] = test_df[f'{tgt}_te'].fillna(global_mean)

      # 노이즈 추가
      train_df[f'{tgt}_te'] = add_noise(train_df[f'{tgt}_te'], noise_level)
      test_df[f'{tgt}_te'] = add_noise(test_df[f'{tgt}_te'], noise_level)

      #### 타겟인코딩2

      # 새로운 범주형 열 생성
      train_df['TMP'] = train_df[encoder_feats].applymap(str).apply(lambda x: ''.join(x) ,axis=1)
      test_df['TMP'] = test_df[encoder_feats].applymap(str).apply(lambda x: ''.join(x) ,axis=1)

      # 인코더
      encoder = TargetEncoder(cols=['TMP'], smoothing=300) # 40
      encoder.fit(train_df[['TMP']], train_df[tgt])

      # 인코딩 결과를 새로운 열에 저장
      train_df[f'{tgt}_te2'] = encoder.transform(train_df[['TMP']])
      test_df[f'{tgt}_te2'] = encoder.transform(test_df[['TMP']])

      # 노이즈 추가
      train_df[f'{tgt}_te2'] = add_noise(train_df[f'{tgt}_te2'], noise_level)
      test_df[f'{tgt}_te2'] = add_noise(test_df[f'{tgt}_te2'], noise_level)

      # 불필요한 변수 제거
      train_df = train_df.drop(columns=['TMP'])
      test_df = test_df.drop(columns=['TMP'])


    # 인코딩
    PK = ['sleep_date', 'lifelog_date', 'subject_id']
    encoder = LabelEncoder()
    categorical_features = [i for i in train_df.select_dtypes(include=['object', 'category']).columns if i not in PK+['pk']]
    for col in categorical_features:
        print(col)
        train_df[col] = encoder.fit_transform(train_df[col])
        test_df[col] = encoder.fit_transform(test_df[col])


    # X
    X = train_df.drop(columns=PK + all_targets)
    test_X = test_df.drop(columns=PK + all_targets)
    print(f'# X shape: {X.shape}')
    print(f'# test_X shape: {test_X.shape}')

    print('\n STEP1: 실험 결과 확인')
    print("=============== Validation Results ==============")
    total_avg_f1s = []
    best_iteration_temp = {k: [] for k in all_targets}

    val_f1 = []

    binary_val_preds = {}
    multiclass_val_preds = {}

    binary_test_preds = {}
    multiclass_test_preds = {}

    test_preds = {}

    # Find optimal weights
    best_weights = []
    best_scores = []

    for col in targets_binary:
        # binary
        y = train_df[col]

        valid_ids['pk'] = valid_ids['subject_id']+valid_ids['sleep_date']
        train_df['pk'] = train_df['subject_id']+train_df['sleep_date']

        X_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
        X_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
        y_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()
        y_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()

        # Get parameters for both models
        lgb_params = common_params[col].copy()
        lgb_params['random_state'] = random_state

        xgb_params = {
            'n_estimators': 1000,
            'learning_rate': 0.01,
            'max_depth': 6,
            'min_child_weight': 1,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': random_state
        }

        # Train LLM
        is_multiclass = False
        llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=2, torch_dtype=torch.float16, device_map='auto')
        lora_model = get_peft_model(llm_model, config)
        print(llm_model)
        #optimizer = torch.optim.AdamW(llm_model.parameters(), lr=1e-6, weight_decay=1e-4)
        optimizer = torch.optim.AdamW(llm_model.parameters(), lr=3e-4, weight_decay=1e-4)
        criterion = FocalLoss(gamma=2.0)

        # Add learning rate scheduler
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=0.5,
            patience=2,
            verbose=True,
            min_lr=1e-6
        )

        total_loss = 0
        correct = 0
        bad_counter = 0
        #best model 를 찾기 위한
        best = np.inf

        X_train_llm = X_train.copy()
        X_valid_llm = X_valid.copy()

        X_train_llm = X_train_llm[X_Feature[col]]
        X_valid_llm = X_valid_llm[X_Feature[col]]

        def prepare_input_text(row):
            target_cols = ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']
            feature_cols = [col for col in X_Feature[col] if col not in target_cols]


            # 프롬프트 시작 문장에 결측치 설명 추가
            base_prompt = Prompt["S1"] if is_multiclass else Prompt[col]
            instruct_txt = base_prompt.strip() + "\n(Note: -1.0 indicates missing value in the data)\n###DATA###\n"

            if is_multiclass:
                # feature 값을 alias 이름과 함께 텍스트로 구성
                for orig_name, alias_name in zip(X_Feature["S1"], X_Feature_alias["S1"]):
                    if orig_name not in target_cols:
                        instruct_txt += f"{alias_name} : {row[orig_name]}, "
            else:
                # feature 값을 alias 이름과 함께 텍스트로 구성
                for orig_name, alias_name in zip(X_Feature[col], X_Feature_alias[col]):
                    if orig_name not in target_cols:
                        instruct_txt += f"{alias_name} : {row[orig_name]}, "

            #print(instruct_txt)
            return instruct_txt.strip()[:-1]+'.'

        ######## llm 학습 시작 #################
        is_multiclass = False
        X_train_llm['input'] = X_train_llm.apply(lambda x: prepare_input_text(x),axis=1)
        #print(X_train_llm.head(1))
        X_valid_llm['input'] = X_valid_llm.apply(lambda x: prepare_input_text(x),axis=1)

        # X_train_llm["label"] = y_train[:15]
        # X_valid_llm["label"] = y_valid[:15]
        X_train_llm["label"] = y_train
        X_valid_llm["label"] = y_valid
        X_train_llm["text"] = X_train_llm["input"]
        X_valid_llm["text"] = X_valid_llm["input"]

        training_data = CustomDataset(X_train_llm)
        validation_data = CustomDataset(X_valid_llm)

        train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True,worker_init_fn=seed_worker, generator=g)
        val_dataloader = DataLoader(validation_data, batch_size=1, shuffle=False)

        # twitterDFTrain_clean = X_train_llm[:15]
        # twitterDFVal_clean = X_valid_llm[:15]

        twitterDFTrain_clean = X_train_llm
        twitterDFVal_clean = X_valid_llm


        for epoch in range(epochs):
            avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, twitterDFTrain_clean)

            avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, twitterDFVal_clean)

            # Update learning rate based on validation loss
            scheduler.step(avg_vaild_loss)

            if avg_vaild_loss < best:
                best = avg_vaild_loss
                # torch.save(llm_model.state_dict(), col+"_"+best_model_path)
                torch.save(llm_model.cpu().state_dict(), col+"_"+ best_model_path)
                llm_model.cuda()
                bad_counter = 0
            else:
                bad_counter += 1

            if bad_counter == patience:
                break

            print(f'{col} Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')

            wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})

            # ✅ 메모리 정리
            del avg_train_loss, avg_train_acc, avg_vaild_loss, avg_vaild_acc
            gc.collect()
            torch.cuda.empty_cache()
        ######## llm 학습 끝 #################

        # Train LightGBM
        lgb_model = LGBMClassifier(**lgb_params)
        if early_stop:
            lgb_model.fit(
                X_train, y_train,
                eval_set=[(X_train, y_train), (X_valid, y_valid)],
                callbacks=[early_stopping(stopping_rounds=100,verbose=False)]
            )
            best_iteration_temp[col].append(lgb_model.best_iteration_)
        else:
            lgb_model.fit(X_train, y_train)
            best_iteration_temp[col].append(1000)

        # Train XGBoost
        xgb_model = XGBClassifier(**xgb_params)
        if early_stop:
            xgb_model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                early_stopping_rounds=100,
                verbose=False
            )
        else:
            xgb_model.fit(X_train, y_train)


        tabpfn_params = {
            'device': 'cuda'
        }

        # Train TabPFN
        tabpfn_model = TabPFNClassifier(**tabpfn_params)
        tabpfn_model.fit(X_train, y_train)

        # Get predictions and ensemble
        _, llm_pred_valid = inference(llm_model, val_dataloader, X_valid_llm, col)

        lgb_pred_valid = lgb_model.predict_proba(X_valid)[:, 1]
        xgb_pred_valid = xgb_model.predict_proba(X_valid)[:, 1]
        # cat_pred_valid = cat_model.predict_proba(X_valid)[:, 1]
        # tabnet_pred_valid = tabpfn_model.predict_proba(X_valid.values)[:, 1]
        cat_pred_valid = tabpfn_model.predict_proba(X_valid.values)[:, 1]

        llm_pred_valid = np.array([arr[1] for arr in llm_pred_valid], dtype=np.float32)
        # print(llm_pred_valid)
        pred_valid = (lgb_A * lgb_pred_valid + xgb_B * xgb_pred_valid + cat_C * cat_pred_valid + llm_D * llm_pred_valid  > 0.5).astype(int)

        f1 = f1_score(y_valid, pred_valid, average='macro')
        val_f1.append(f1)

        # Store predictions
        binary_val_preds[col] = {
            'llm': llm_pred_valid,
            'lgb': lgb_pred_valid,
            'xgb': xgb_pred_valid,
            'cat': cat_pred_valid,
            'true': y_valid
        }

    # multiclass
    y = train_df[target_multiclass]

    X_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
    X_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
    y_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()
    y_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()

    # Get parameters for both models
    lgb_params = common_params['S1'].copy()
    lgb_params['random_state'] = random_state

    xgb_params = {
        'n_estimators': 1000,
        'learning_rate': 0.01,
        'max_depth': 6,
        'min_child_weight': 1,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'random_state': random_state
    }

    # 클래스 weight 계산
    classes = np.unique(y_train)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
    class_weights = dict(zip(classes, weights))

    # 각 샘플에 대해 weight 매핑
    w_train = pd.Series(y_train).map(class_weights)
    # print("----compute_class_weight:")
    # print(w_train)

    w_train = compute_sample_weight(class_weight='balanced', y=y_train)
    # print("----compute_sample_weight:")
    # print(w_train)

    ######## llm 학습 시작 #################
    is_multiclass = True
    llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=3, torch_dtype=torch.float16, device_map='auto')
    lora_model = get_peft_model(llm_model, config)

    optimizer = torch.optim.AdamW(llm_model.parameters(), lr=3e-4, weight_decay=1e-4)
    #optimizer = torch.optim.AdamW(llm_model.parameters(), lr=1e-5, weight_decay=1e-4)
    # alpha = torch.tensor([1.048, 0.670, 1.807], dtype=torch.float16, device=device)
    # criterion = FocalLoss(gamma=2.0,alpha=alpha)
    criterion = FocalLoss(gamma=2.0)

    # Add learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=2,
        verbose=True,
        min_lr=1e-6
    )

    total_loss = 0
    correct = 0
    bad_counter = 0

    #best model 를 찾기 위한
    best = np.inf

    X_train_llm = X_train.copy()
    X_valid_llm = X_valid.copy()

    X_train_llm = X_train_llm[X_Feature["S1"]]
    X_valid_llm = X_valid_llm[X_Feature["S1"]]

    X_train_llm['input'] = X_train_llm.apply(lambda x: prepare_input_text(x),axis=1)
    #print(X_train_llm.head(1))
    X_valid_llm['input'] = X_valid_llm.apply(lambda x: prepare_input_text(x),axis=1)

    # X_train_llm["label"] = y_train[:15]
    # X_valid_llm["label"] = y_valid[:15]
    X_train_llm["label"] = y_train
    X_valid_llm["label"] = y_valid
    X_train_llm["text"] = X_train_llm["input"]
    X_valid_llm["text"] = X_valid_llm["input"]

    training_data = CustomDataset(X_train_llm)
    validation_data = CustomDataset(X_valid_llm)

    #train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True,worker_init_fn=seed_worker, generator=g)
    train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True)
    val_dataloader = DataLoader(validation_data, batch_size=1, shuffle=False)

    # twitterDFTrain_clean = X_train_llm[:15]
    # twitterDFVal_clean = X_valid_llm[:15]

    twitterDFTrain_clean = X_train_llm
    twitterDFVal_clean = X_valid_llm


    for epoch in range(epochs):
        avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, twitterDFTrain_clean)

        avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, twitterDFVal_clean)

        # Update learning rate based on validation loss
        scheduler.step(avg_vaild_loss)

        if avg_vaild_loss < best:
            best = avg_vaild_loss
            # torch.save(llm_model.state_dict(), "S1_"+best_model_path)
            torch.save(llm_model.cpu().state_dict(), "S1_" + best_model_path)
            llm_model.cuda()
            bad_counter = 0
        else:
            bad_counter += 1

        if bad_counter == patience:
            break

        print(f'S1 Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')

        wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})

        # ✅ 메모리 정리
        del avg_train_loss, avg_train_acc, avg_vaild_loss, avg_vaild_acc
        gc.collect()
        torch.cuda.empty_cache()

    ######## llm 학습 끝 #################

    # Train LightGBM
    lgb_model = LGBMClassifier(**lgb_params, objective='multiclass', num_class=3)
    if early_stop:
        lgb_model.fit(
            X_train, y_train,
            eval_set=[(X_train, y_train), (X_valid, y_valid)],
            callbacks=[early_stopping(stopping_rounds=100,verbose=False)], sample_weight=w_train
        )
        best_iteration_temp[target_multiclass].append(lgb_model.best_iteration_)
    else:
        lgb_model.fit(X_train, y_train, sample_weight=w_train)
        best_iteration_temp[target_multiclass].append(1000)

    # Train XGBoost
    xgb_model = XGBClassifier(**xgb_params, objective='multi:softmax', num_class=3)
    if early_stop:
        xgb_model.fit(
            X_train, y_train,
            eval_set=[(X_valid, y_valid)],
            early_stopping_rounds=100,
            verbose=False, sample_weight=w_train
        )
    else:
        xgb_model.fit(X_train, y_train,sample_weight=w_train)


    tabpfn_params = {
        'device': 'cuda'
    }

    # Train TabPFN
    tabpfn_model = TabPFNClassifier(**tabpfn_params)
    tabpfn_model.fit(X_train, y_train)

    # Get predictions and ensemble
    _, llm_pred_valid = inference(llm_model, val_dataloader, X_valid_llm, "S1")
    lgb_pred_valid = lgb_model.predict_proba(X_valid)
    xgb_pred_valid = xgb_model.predict_proba(X_valid)
    #cat_pred_valid = cat_model.predict_proba(X_valid)
    #tabnet_pred_valid = tabpfn_model.predict_proba(X_valid.values)
    cat_pred_valid = tabpfn_model.predict_proba(X_valid.values)
    # print(llm_pred_valid)
    # print(lgb_pred_valid)
    llm_pred_valid = np.array(llm_pred_valid, dtype=np.float32)
    #print(llm_pred_valid)
    pred_valid = np.argmax(lgb_A * lgb_pred_valid + xgb_B * xgb_pred_valid + cat_C * cat_pred_valid + llm_D * llm_pred_valid, axis=1)

    f1 = f1_score(y_valid, pred_valid, average='macro')
    val_f1.append(f1)

    multiclass_val_preds = {
        'llm': llm_pred_valid,
        'lgb': lgb_pred_valid,
        'xgb': xgb_pred_valid,
        'cat': cat_pred_valid,
        'true': y_valid
    }

    # Generate all possible weight combinations that sum to 1
    step = 0.1
    for lgb_A in np.arange(0, 1.1, step):
        for xgb_B in np.arange(0, 1.1 - lgb_A, step):
            for cat_C in np.arange(0, 1.1 - lgb_A - xgb_B, step):
                llm_D = 1 - (lgb_A + xgb_B + cat_C)
                if llm_D >= 0:
                    weights = (lgb_A, xgb_B, cat_C, llm_D)
                    print("========================================")
                    print(f"\nTrying weights: lgb_A={lgb_A:.1f}, xgb_B={xgb_B:.1f}, cat_C={cat_C:.1f}, llm_D={llm_D:.1f}")

                    # Calculate validation score with current weights
                    val_scores = []

                    # Binary targets
                    for col in targets_binary:
                        preds = binary_val_preds[col]

                        ensemble_pred = (lgb_A * preds['lgb'] + xgb_B * preds['xgb'] +
                                      cat_C * preds['cat'] + llm_D * preds['llm'] > 0.5).astype(int)
                        f1 = f1_score(preds['true'], ensemble_pred, average='macro')
                        val_scores.append(f1)
                        print(f" Validation Score {col}:{f1:.4f}")

                    # Multiclass target
                    preds = multiclass_val_preds
                    ensemble_pred = np.argmax(lgb_A * preds['lgb'] + xgb_B * preds['xgb'] +
                                           cat_C * preds['cat'] + llm_D * preds['llm'], axis=1)
                    f1 = f1_score(preds['true'], ensemble_pred, average='macro')
                    print(f" Validation Score S1:{f1:.4f}")
                    val_scores.append(f1)

                    avg_score = np.mean(val_scores)
                    best_weights.append(weights)
                    best_scores.append(avg_score)

                    print(f"Average Validation Score: {avg_score:.4f}")

    # Sort results and get top 3
    #sorted_indices = np.argsort(best_scores)[::-1][:3]
    sorted_indices = np.argsort(best_scores)[::-1]
    top_3_weights = [best_weights[i] for i in sorted_indices]
    top_3_scores = [best_scores[i] for i in sorted_indices]

    print("\nTop All Weight Combinations:")
    for i, (weights, score) in enumerate(zip(top_3_weights, top_3_scores)):
        print(f"Rank {i+1}: lgb_A={weights[0]:.1f}, xgb_B={weights[1]:.1f}, cat_C={weights[2]:.1f}, llm_D={weights[3]:.1f} - Score: {score:.4f}")

    avg_f1 = np.mean(val_f1)
    total_avg_f1s.append(avg_f1)
    detail = " ".join([f"{name}({tname}):{score:.4f}" for name, tname, score in zip(targets_binary + [target_multiclass], targets_binary_name + ['S1'], val_f1)])
    print(f" 평균 F1: {avg_f1:.4f} / [상세] {detail}")

    best_iteration_dict = {k: max(best_iteration_temp[k]) for k in all_targets}

    if early_stop==True:
      print("\n[best_iteration_dict]")
      for k, v in best_iteration_dict.items():
          print(f"{k}: {v}")

    print(f"# 전체 평균 F1: {np.mean(total_avg_f1s):.4f}")
    print("================================================")

    # modoling with 100% train & no valid
    print('\n STEP2: 전체 데이터로 모델 재학습')
    print("====== modeling with 100% train & no valid =====")

    # binary
    binary_preds = {}
    binary_preds_proba = {}
    for col in targets_binary:
        # Get parameters for both models
        lgb_params = common_params[col].copy()
        lgb_params['random_state'] = random_state

        xgb_params = {
            'n_estimators': 1000,
            'learning_rate': 0.01,
            'max_depth': 6,
            'min_child_weight': 1,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': random_state
        }

        y = train_df[col]

        if early_stop:
            lgb_params['n_estimators'] = best_iteration_dict[col]
            xgb_params['n_estimators'] = best_iteration_dict[col]

        # LLM Valid Model load and Inference

        is_multiclass = False
        test_X_llm = test_X.copy()
        test_X_llm = test_X_llm[X_Feature[col]]
        test_X_llm['input'] = test_X_llm.apply(lambda x: prepare_input_text(x),axis=1)
        test_X_llm["text"] = test_X_llm["input"]
        test_data = CustomDataset(test_X_llm)
        test_dataloader = DataLoader(test_data, batch_size=1, shuffle=False)

        llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=2, torch_dtype=torch.float16, device_map='auto')
        lora_model = get_peft_model(llm_model, config)
        _, llm_pred = inference(llm_model, test_dataloader, test_X_llm, col)
        llm_pred = np.array([arr[1] for arr in llm_pred], dtype=np.float32)

        # Train LightGBM
        lgb_model = LGBMClassifier(**lgb_params)
        lgb_model.fit(X, y)

        # Train XGBoost
        xgb_model = XGBClassifier(**xgb_params)
        xgb_model.fit(X, y)

        # Train CatBoost
        # cat_model = CatBoostClassifier(**common_params_cat)
        # cat_model.fit(X, y)

        tabpfn_params = {
            'device': 'cuda'
        }

        # Train TabPFN
        tabpfn_model = TabPFNClassifier(**tabpfn_params)
        tabpfn_model.fit(X, y)

        # Get predictions and ensemble
        #_, llm_pred_vaild = inference(llm_model, val_dataloader, X_valid_llm, "S1")
        lgb_pred = lgb_model.predict_proba(test_X)[:, 1]
        xgb_pred = xgb_model.predict_proba(test_X)[:, 1]
        #cat_pred = cat_model.predict_proba(test_X)[:, 1]
        cat_pred = tabpfn_model.predict_proba(test_X)[:, 1]

        binary_preds[col] = (lgb_A * lgb_pred + xgb_B * xgb_pred + cat_C * cat_pred + llm_D * llm_pred  > 0.5).astype(int)
        #binary_preds_proba[col] = lgb_A * lgb_model.predict_proba(test_X) + xgb_B * xgb_model.predict_proba(test_X) + cat_C * cat_model.predict_proba(test_X)

        # Store predictions
        binary_test_preds[col] = {
            'llm': llm_pred,
            'lgb': lgb_pred,
            'xgb': xgb_pred,
            'cat': cat_pred
        }

        # Feature importance (using LightGBM's importance)
        fi_df = pd.DataFrame({'feature': X.columns, 'importance': lgb_model.feature_importances_})
        top10 = fi_df.sort_values(by='importance', ascending=False).head(10)
        feat_str = ", ".join([f"{row['feature']}({int(row['importance'])})" for _, row in top10.iterrows()])
        print(f"[{col}] {feat_str}")

    # multiclass
    y = train_df['S1']

    # Get parameters for both models
    lgb_params = common_params['S1'].copy()
    lgb_params['random_state'] = random_state

    xgb_params = {
        'n_estimators': 1000,
        'learning_rate': 0.01,
        'max_depth': 6,
        'min_child_weight': 1,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'random_state': random_state
    }

    if early_stop:
        lgb_params['n_estimators'] = best_iteration_dict['S1']
        xgb_params['n_estimators'] = best_iteration_dict['S1']

    # 클래스 weight 계산
    classes = np.unique(y)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y)
    class_weights = dict(zip(classes, weights))

    # 각 샘플에 대해 weight 매핑
    w_train = pd.Series(y).map(class_weights)
    # print("----compute_class_weight:")
    # print(w_train)

    w_train = compute_sample_weight(class_weight='balanced', y=y)
    # print("----compute_sample_weight:")
    # print(w_train)

    # LLM Valid Model load and Inference

    is_multiclass = True
    test_X_llm = test_X.copy()
    test_X_llm = test_X_llm[X_Feature["S1"]]
    test_X_llm['input'] = test_X_llm.apply(lambda x: prepare_input_text(x),axis=1)
    test_X_llm["text"] = test_X_llm["input"]
    test_data = CustomDataset(test_X_llm)
    test_dataloader = DataLoader(test_data, batch_size=1, shuffle=False)

    llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=3, torch_dtype=torch.float16, device_map='auto')
    lora_model = get_peft_model(llm_model, config)
    _, llm_pred = inference(llm_model, test_dataloader, test_X_llm, "S1")
    llm_pred = np.array(llm_pred, dtype=np.float32)
    #print(llm_pred)

    # Train LightGBM
    lgb_model = LGBMClassifier(**lgb_params, objective='multiclass', num_class=3)
    lgb_model.fit(X, y, sample_weight=w_train)

    # Train XGBoost
    xgb_model = XGBClassifier(**xgb_params, objective='multi:softmax', num_class=3)
    xgb_model.fit(X, y, sample_weight=w_train)

    # Train CatBoost
    # cat_model = CatBoostClassifier(**common_params_cat2, objective='MultiClass', classes_count=3)
    # cat_model.fit(X, y)

    tabpfn_params = {
        'device': 'cuda'
    }

     # Train TabPFN
    tabpfn_model = TabPFNClassifier(**tabpfn_params)
    tabpfn_model.fit(X, y)

    # Get predictions and ensemble
    lgb_pred = lgb_model.predict_proba(test_X)
    xgb_pred = xgb_model.predict_proba(test_X)
    #cat_pred = cat_model.predict_proba(test_X)
    cat_pred = tabpfn_model.predict_proba(test_X)

    multiclass_test_preds = {
        'llm': llm_pred,
        'lgb': lgb_pred,
        'xgb': xgb_pred,
        'cat': cat_pred
    }

    multiclass_pred = np.argmax(lgb_A * lgb_pred + xgb_B * xgb_pred + cat_C * cat_pred +llm_D * llm_pred, axis=1)
    multiclass_pred_proba = lgb_A * lgb_pred + xgb_B * xgb_pred + cat_C * cat_pred + llm_D * llm_pred

    # Feature importance
    fi_df = pd.DataFrame({'feature': X.columns, 'importance': lgb_model.feature_importances_})
    top10 = fi_df.sort_values(by='importance', ascending=False).head(10)
    feat_str = ", ".join([f"{row['feature']}({int(row['importance'])})" for _, row in top10.iterrows()])
    print(f"[S1] {feat_str}")

    # 예측 저장
    submission_final['S1'] = multiclass_pred
    for col in targets_binary:
      submission_final[col] = binary_preds[col]
    submission_final = submission_final[['subject_id', 'sleep_date', 'lifelog_date', 'Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']]
    fname = f"submission_{np.mean(total_avg_f1s)}.csv"
    submission_final.to_csv(fname, index=False)
    print(f"# {fname} 저장 완료")
    print(f"# submission shape:{submission_final.shape}")
    print("================================================")
    print("\nTop 3 Weight Combinations:")
    for i, (weights, score) in enumerate(zip(top_3_weights, top_3_scores)):
        print(f"Rank {i+1}: lgb_A={weights[0]:.1f}, xgb_B={weights[1]:.1f}, cat_C={weights[2]:.1f}, llm_D={weights[3]:.1f} - Score: {score:.4f}")

        # Generate submission with these weights
        lgb_A, xgb_B, cat_C, llm_D = weights

        # Binary predictions
        for col in targets_binary:
            preds = binary_test_preds[col]
            ensemble_pred = (lgb_A * preds['lgb'] + xgb_B * preds['xgb'] +
                          cat_C * preds['cat'] + llm_D * preds['llm'] > 0.5).astype(int)
            submission_final[col] = ensemble_pred

        # Multiclass prediction
        preds = multiclass_test_preds
        ensemble_pred = np.argmax(lgb_A * preds['lgb'] + xgb_B * preds['xgb'] +
                               cat_C * preds['cat'] + llm_D * preds['llm'], axis=1)
        submission_final['S1'] = ensemble_pred

        fname = f"submission_top{i+1}_{score:.4f}.csv"
        submission_final.to_csv(fname, index=False)
        print(f"Saved submission to {fname}")

    # Use the best weights for final submission
    best_weights = top_3_weights[0]
    lgb_A, xgb_B, cat_C, llm_D = best_weights

    # 모델별 예측결과 비율 비교
    a11 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].sum()
    a13 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].apply(len)
    a12 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].mean()
    a21 = submission_final[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].sum()
    a23 = submission_final[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].apply(len)
    a22 = submission_final[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].mean()
    result = pd.concat([a11, a13, a12, a21, a23, a22], axis=1)
    result.columns = ['학습sum','학습len','학습mean','테스트sum','테스트len','테스트mean']
    print('\n STEP3: 예측결과 비교표')
    display(result)
    oof_result = []
    return submission_final, oof_result
# Out:
# =====epochs 16 gogo======

# %% [markdown]
# ### ============================

# %% [markdown]
# ### 📦 모델 학습

# %%
X_Feature = {
    "Q1": ["Q1_te2", "wake_time_ratio", "mlight_first_wakeup_minutes", "wake_time_diff", "Q1_te", "lights_off_time", "sleep_duration_ratio", "active_hour_mean_speed", "beforebed_통화_time", "rolling_sleep_time_2d", "activehour_NAVER_time"],
    "Q2": ["Q2_te", "Q2_te2", "activehour_total_screen_time", "beforebed_unique_bssid_count", "wake_time_lag1", "light_rolling_wake_time_2d", "beforebed_max_rssi", "active_hour_std_hr", "beforebed_top_bssid_count", "activehour_screen_time_vs_avg_pct", "activehour_메신저_time"],
    "Q3": ["Q3_te2", "light_sleep_time_lag2", "mlight_first_wakeup_minutes", "rolling_sleep_time_3d", "light_rolling_sleep_duration_3d", "Q3_te", "beforebed_scan_count", "active_hour_distance_x", "activehour_통화_time", "walking_minutes"],
    "S1": ["S1_te", "wake_time_diff", "S1_te2", "sleep_duration_ratio", "m_activity_met@240min@sum@04h00m", "beforebed_screen_time_vs_avg_pct", "wake_time_ratio", "rolling_wake_time_3d", "m_activity_0@240min@std@20h00m", "m_activity@240min@std@12h00m", "beforebed_메신저_time", "sleep_duration_diff", "light_sleep_time_diff", "active_hour_min_hr"],
    "S2": ["S2_te2", "S2_te", "light_sleep_time_lag1", "work_hour_unknown_ratio", "m_activity@240min@std@12h00m", "beforebed_strong_signal_ratio", "light_rolling_wake_time_2d", "free_hour_rssi_mean", "activehour_전화_time", "sleep_hour_mean_speed","activehour_screen_time_vs_avg_pct","light_wake_time_diff_lag2","beforebed_max_rssi","avg_charging_duration","m_activity_met@240min@std@12h00m"],
    "S3": ["S3_te", "S3_te2", "beforebed_메신저_time", "light_wake_time_diff", "sleep_time_diff_lag1", "light_sleep_time_lag2", "m_activity_met@240min@sum@16h00m", "free_hour_rssi_max", "light_weekday_avg_sleep", "불끈시간부터기상시간","sleep_hour_distance_x","activehour_scan_count"]
}

X_Feature_alias = {
    "Q1": [
        "Q1_encoded_time_2",
        "wake_time_to_baseline_ratio",
        "minutes_to_first_wake_after_light",
        "wake_time_difference",
        "Q1_encoded_time",
        "lights_off_clock_time",
        "sleep_duration_ratio_to_guideline",
        "mean_speed_during_active_hours",
        "call_duration_before_bed",
        "sleep_time_rolling_avg_2d",
        "NAVER_time_active_hours"
    ],
    "Q2": [
        "Q2_encoded_time",
        "Q2_encoded_time_2",
        "total_screen_time_active_hours",
        "unique_wifi_count_before_bed",
        "previous_day_wake_time",
        "light_based_wake_time_rolling_avg_2d",
        "max_wifi_signal_before_bed",
        "std_heart_rate_active_hours",
        "frequent_wifi_count_before_bed",
        "screen_time_vs_avg_pct_active_hours",
        "messenger_usage_time_active_hours"
    ],
    "Q3": [
        "Q3_encoded_time_2",
        "light_sleep_duration_lag2",
        "minutes_to_first_wake_after_light",
        "sleep_time_rolling_avg_3d",
        "light_based_sleep_duration_rolling_avg_3d",
        "Q3_encoded_time",
        "wifi_scan_count_before_bed",
        "distance_traveled_active_hours",
        "call_duration_active_hours",
        "total_walking_minutes"
    ],
    "S1": [
        "S1_encoded_time",
        "wake_time_difference",
        "S1_encoded_time_2",
        "sleep_duration_ratio_to_guideline",
        "met_sum_0to4am",
        "screen_time_vs_avg_pct_before_bed",
        "wake_time_to_baseline_ratio",
        "wake_time_rolling_avg_3d",
        "activity_std_8pm_to_midnight",
        "activity_std_12pm_to_4pm"
        "messenger_usage_time_before_bed",
        "sleep_time_difference",
        "light_based_sleep_time_difference",
        "activity_time_mininum_hours"

    ],
    "S2": [
        "S2_encoded_time_2",
        "S2_encoded_time",
        "light_sleep_duration_lag1",
        "unknown_activity_ratio_work_hours",
        "activity_std_12pm_to_4pm",
        "strong_wifi_signal_ratio_before_bed",
        "light_based_wake_time_rolling_avg_2d",
        "avg_wifi_signal_strength_free_hours",
        "phone_call_time_active_hours",
        "mean_movement_speed_sleep_hours",
        "activity_time_screen_hour_vs_avg_pct","light_wake_time_diff_lag2","beforebed_max_rssi","avg_charging_duration","m_activity_met@240min@std@12h00m"
    ],
    "S3": [
        "S3_encoded_time",
        "S3_encoded_time_2",
        "messenger_usage_time_before_bed",
        "light_based_wake_time_difference",
        "sleep_time_difference_lag1",
        "light_sleep_duration_lag2",
        "met_sum_4pm_to_8pm",
        "max_wifi_signal_strength_free_hours",
        "light_based_weekday_avg_sleep_duration",
        "time_from_first_movement_to_final_wake",
        "sleep_hour_distance_x","active_hour_scan_count"
    ]
}

# %%
# 공통 하이퍼파라미터
common_params = {
  'n_estimators': 5000,
  "learning_rate": 0.01,
  # "shrinkage_rate": 0.12,
  # 'min_data_in_leaf':2,
  # 'bagging_fraction':0.9,
  # 'feature_fraction':0.6,
  'lambda_l1': 5,
  'lambda_l2': 1,
  # 'max_depth': 4,
  'n_jobs': -1,
  'verbosity': -1
}

# 모델별 세부 하이퍼파라미터
best_param_dict = {}
best_param_dict['Q3'] = common_params
best_param_dict['S1'] = common_params
best_param_dict['S2'] = common_params
best_param_dict['S3'] = common_params
best_param_dict['Q1'] = common_params
best_param_dict['Q2'] = common_params


common_params_cat = {
    'iterations': 2000,           # n_estimators에 해당
    'learning_rate': 0.01,
    'l2_leaf_reg': 1,             # reg_lambda에 해당
    'depth': 6,                   # max_depth에 해당
    'thread_count': -1,           # n_jobs에 해당
    # 'subsample': 0.8,
    'rsm': 0.8,                   # colsample_bylevel에 해당
    'min_data_in_leaf': 1,        # min_child_weight에 유사
    'border_count': 200,          # max_bin에 해당
    'task_type': 'CPU',           # 'hist'에 대응
    'random_state' : 41,
    'verbose' : False
}

common_params_cat2 = {
    'iterations': 2000,           # n_estimators에 해당
    'learning_rate': 0.01,
    'class_weights': [1.048, 0.670, 1.807],  # [0, 1, 2] 순서
    'l2_leaf_reg': 1,             # reg_lambda에 해당
    'depth': 6,                   # max_depth에 해당
    'thread_count': -1,           # n_jobs에 해당
    # 'subsample': 0.8,
    'rsm': 0.8,                   # colsample_bylevel에 해당
    'min_data_in_leaf': 1,        # min_child_weight에 유사
    'border_count': 200,          # max_bin에 해당
    'task_type': 'CPU',           # 'hist'에 대응
    'random_state' : 41,
    'verbose' : False
}

submission_final, oof_result = run_basemodel(train, test, valid_ids, best_param_dict, n_splits=5, random_state=41, early_stop=False)
# Out:
# =========valid_ids==========
#    subject_id  sleep_date              pk
# 0        id01  2024-07-24  id012024-07-24
# 1        id01  2024-08-26  id012024-08-26
# 2        id01  2024-08-28  id012024-08-28
# 3        id01  2024-08-29  id012024-08-29
# 4        id02  2024-08-23  id022024-08-23
# 5        id02  2024-09-24  id022024-09-24
# 6        id02  2024-09-26  id022024-09-26
# 7        id02  2024-09-27  id022024-09-27
# 8        id03  2024-08-30  id032024-08-30
# 9        id03  2024-09-01  id032024-09-01
# 10       id03  2024-09-02  id032024-09-02
# 11       id03  2024-09-06  id032024-09-06
# 12       id04  2024-09-03  id042024-09-03
# 13       id04  2024-10-10  id042024-10-10
# 14       id04  2024-10-12  id042024-10-12
# 15       id04  2024-10-13  id042024-10-13
# 16       id05  2024-10-19  id052024-10-19
# 17       id05  2024-10-23  id052024-10-23
# 18       id05  2024-10-24  id052024-10-24
# 19       id05  2024-10-27  id052024-10-27
# 20       id06  2024-07-25  id062024-07-25
# 21       id06  2024-07-26  id062024-07-26
# 22       id06  2024-07-27  id062024-07-27
# 23       id06  2024-07-30  id062024-07-30
# 24       id07  2024-07-07  id072024-07-07
# 25       id07  2024-08-02  id072024-08-02
# 26       id07  2024-08-04  id072024-08-04
# 27       id07  2024-08-05  id072024-08-05
# 28       id08  2024-08-28  id082024-08-28
# 29       id08  2024-08-29  id082024-08-29
# 30       id08  2024-08-30  id082024-08-30
# 31       id08  2024-09-02  id082024-09-02
# 32       id09  2024-08-02  id092024-08-02
# 33       id09  2024-08-31  id092024-08-31
# 34       id09  2024-09-02  id092024-09-02
# 35       id09  2024-09-03  id092024-09-03
# 36       id10  2024-08-28  id102024-08-28
# 37       id10  2024-08-30  id102024-08-30
# 38       id10  2024-08-31  id102024-08-31
# 39       id10  2024-09-03  id102024-09-03
# light_week_type_lag1
# weekday
# week_type
# week_type_lag1
# activehour_top_bssid
# beforebed_top_bssid
# # X shape: (450, 247)
# # test_X shape: (250, 247)
#
#  STEP1: 실험 결과 확인
# =============== Validation Results ==============
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Qwen3ForSequenceClassification(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 1024)
#     (layers): ModuleList(
#       (0-27): 28 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=2048, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=2048, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (v_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=1024, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=1024, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (o_proj): Linear(in_features=2048, out_features=1024, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (up_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (down_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((1024,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (score): Linear(in_features=1024, out_features=2, bias=False)
# )
# 100%|██████████| 410/410 [01:10<00:00,  5.78it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.42it/s]
# Q1 Epoch: 1: t_loss:0.274 t_acc:0.558 v_loss:0.172 v_acc:0.549
# 100%|██████████| 410/410 [01:09<00:00,  5.86it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.49it/s]
# Q1 Epoch: 2: t_loss:0.167 t_acc:0.611 v_loss:0.205 v_acc:0.440
# 100%|██████████| 410/410 [01:09<00:00,  5.87it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.47it/s]
# Q1 Epoch: 3: t_loss:0.152 t_acc:0.685 v_loss:0.155 v_acc:0.467
# 100%|██████████| 410/410 [01:09<00:00,  5.86it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.50it/s]
# Q1 Epoch: 4: t_loss:0.147 t_acc:0.712 v_loss:0.204 v_acc:0.531
# 100%|██████████| 410/410 [01:10<00:00,  5.84it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.42it/s]
# Q1 Epoch: 5: t_loss:0.160 t_acc:0.678 v_loss:0.149 v_acc:0.637
# 100%|██████████| 410/410 [01:10<00:00,  5.84it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.37it/s]
# Q1 Epoch: 6: t_loss:0.134 t_acc:0.746 v_loss:0.155 v_acc:0.721
# 100%|██████████| 410/410 [01:09<00:00,  5.87it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.44it/s]
# Q1 Epoch: 7: t_loss:0.155 t_acc:0.700 v_loss:0.142 v_acc:0.725
# 100%|██████████| 410/410 [01:09<00:00,  5.88it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.46it/s]
# Q1 Epoch: 8: t_loss:0.131 t_acc:0.753 v_loss:0.170 v_acc:0.646
# 100%|██████████| 410/410 [01:09<00:00,  5.87it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.54it/s]
# Q1 Epoch: 9: t_loss:0.119 t_acc:0.778 v_loss:0.157 v_acc:0.710
# 100%|██████████| 410/410 [01:09<00:00,  5.88it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.46it/s]
# tabpfn-v2-classifier.ckpt:   0%|          | 0.00/29.0M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/37.0 [00:00<?, ?B/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.46it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Qwen3ForSequenceClassification(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 1024)
#     (layers): ModuleList(
#       (0-27): 28 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=2048, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=2048, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (v_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=1024, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=1024, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (o_proj): Linear(in_features=2048, out_features=1024, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (up_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (down_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((1024,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (score): Linear(in_features=1024, out_features=2, bias=False)
# )
# 100%|██████████| 410/410 [01:03<00:00,  6.41it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.52it/s]
# Q2 Epoch: 1: t_loss:0.299 t_acc:0.584 v_loss:0.152 v_acc:0.670
# 100%|██████████| 410/410 [01:04<00:00,  6.38it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.29it/s]
# Q2 Epoch: 2: t_loss:0.166 t_acc:0.649 v_loss:0.155 v_acc:0.603
# 100%|██████████| 410/410 [01:04<00:00,  6.40it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.52it/s]
# Q2 Epoch: 3: t_loss:0.160 t_acc:0.675 v_loss:0.133 v_acc:0.715
# 100%|██████████| 410/410 [01:04<00:00,  6.38it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.54it/s]
# Q2 Epoch: 4: t_loss:0.158 t_acc:0.666 v_loss:0.149 v_acc:0.673
# 100%|██████████| 410/410 [01:04<00:00,  6.39it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.64it/s]
# Q2 Epoch: 5: t_loss:0.159 t_acc:0.677 v_loss:0.245 v_acc:0.365
# 100%|██████████| 410/410 [01:04<00:00,  6.40it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.51it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.38it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Qwen3ForSequenceClassification(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 1024)
#     (layers): ModuleList(
#       (0-27): 28 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=2048, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=2048, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (v_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=1024, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=1024, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (o_proj): Linear(in_features=2048, out_features=1024, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (up_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (down_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((1024,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (score): Linear(in_features=1024, out_features=2, bias=False)
# )
# 100%|██████████| 410/410 [01:01<00:00,  6.64it/s]
# 100%|██████████| 40/40 [00:02<00:00, 17.22it/s]
# Q3 Epoch: 1: t_loss:0.214 t_acc:0.575 v_loss:0.198 v_acc:0.373
# 100%|██████████| 410/410 [01:01<00:00,  6.62it/s]
# 100%|██████████| 40/40 [00:02<00:00, 17.06it/s]
# Q3 Epoch: 2: t_loss:0.165 t_acc:0.630 v_loss:0.167 v_acc:0.516
# 100%|██████████| 410/410 [01:01<00:00,  6.64it/s]
# 100%|██████████| 40/40 [00:02<00:00, 17.23it/s]
# Q3 Epoch: 3: t_loss:0.151 t_acc:0.677 v_loss:0.172 v_acc:0.498
# 100%|██████████| 410/410 [01:01<00:00,  6.65it/s]
# 100%|██████████| 40/40 [00:02<00:00, 17.24it/s]
# Q3 Epoch: 4: t_loss:0.144 t_acc:0.709 v_loss:0.146 v_acc:0.702
# 100%|██████████| 410/410 [01:01<00:00,  6.64it/s]
# 100%|██████████| 40/40 [00:02<00:00, 17.18it/s]
# Q3 Epoch: 5: t_loss:0.143 t_acc:0.704 v_loss:0.182 v_acc:0.516
# 100%|██████████| 410/410 [01:01<00:00,  6.62it/s]
# 100%|██████████| 40/40 [00:02<00:00, 17.17it/s]
# Q3 Epoch: 6: t_loss:0.150 t_acc:0.685 v_loss:0.150 v_acc:0.580
# 100%|██████████| 410/410 [01:01<00:00,  6.64it/s]
# 100%|██████████| 40/40 [00:02<00:00, 17.22it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.83it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Qwen3ForSequenceClassification(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 1024)
#     (layers): ModuleList(
#       (0-27): 28 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=2048, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=2048, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (v_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=1024, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=1024, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (o_proj): Linear(in_features=2048, out_features=1024, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (up_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (down_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((1024,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (score): Linear(in_features=1024, out_features=2, bias=False)
# )
# 100%|██████████| 410/410 [01:30<00:00,  4.51it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.26it/s]
# S2 Epoch: 1: t_loss:0.262 t_acc:0.521 v_loss:0.203 v_acc:0.298
# 100%|██████████| 410/410 [01:30<00:00,  4.51it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.29it/s]
# S2 Epoch: 2: t_loss:0.156 t_acc:0.555 v_loss:0.217 v_acc:0.432
# 100%|██████████| 410/410 [01:30<00:00,  4.52it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.28it/s]
# S2 Epoch: 3: t_loss:0.135 t_acc:0.660 v_loss:0.177 v_acc:0.500
# 100%|██████████| 410/410 [01:30<00:00,  4.52it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.29it/s]
# S2 Epoch: 4: t_loss:0.127 t_acc:0.693 v_loss:0.186 v_acc:0.467
# 100%|██████████| 410/410 [01:30<00:00,  4.51it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.27it/s]
# S2 Epoch: 5: t_loss:0.128 t_acc:0.690 v_loss:0.141 v_acc:0.615
# 100%|██████████| 410/410 [01:30<00:00,  4.52it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.31it/s]
# S2 Epoch: 6: t_loss:0.135 t_acc:0.671 v_loss:0.286 v_acc:0.298
# 100%|██████████| 410/410 [01:30<00:00,  4.52it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.26it/s]
# S2 Epoch: 7: t_loss:0.131 t_acc:0.690 v_loss:0.170 v_acc:0.680
# 100%|██████████| 410/410 [01:30<00:00,  4.52it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.30it/s]
# 100%|██████████| 40/40 [00:03<00:00, 12.37it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Qwen3ForSequenceClassification(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 1024)
#     (layers): ModuleList(
#       (0-27): 28 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=2048, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=2048, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (k_proj): Linear(in_features=1024, out_features=1024, bias=False)
#           (v_proj): lora.Linear(
#             (base_layer): Linear(in_features=1024, out_features=1024, bias=False)
#             (lora_dropout): ModuleDict(
#               (default): Dropout(p=0.1, inplace=False)
#             )
#             (lora_A): ModuleDict(
#               (default): Linear(in_features=1024, out_features=16, bias=False)
#             )
#             (lora_B): ModuleDict(
#               (default): Linear(in_features=16, out_features=1024, bias=False)
#             )
#             (lora_embedding_A): ParameterDict()
#             (lora_embedding_B): ParameterDict()
#             (lora_magnitude_vector): ModuleDict()
#           )
#           (o_proj): Linear(in_features=2048, out_features=1024, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (up_proj): Linear(in_features=1024, out_features=3072, bias=False)
#           (down_proj): Linear(in_features=3072, out_features=1024, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((1024,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((1024,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (score): Linear(in_features=1024, out_features=2, bias=False)
# )
# 100%|██████████| 410/410 [01:09<00:00,  5.93it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.79it/s]
# S3 Epoch: 1: t_loss:0.255 t_acc:0.546 v_loss:0.302 v_acc:0.344
# 100%|██████████| 410/410 [01:09<00:00,  5.92it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.71it/s]
# S3 Epoch: 2: t_loss:0.167 t_acc:0.613 v_loss:0.167 v_acc:0.469
# 100%|██████████| 410/410 [01:09<00:00,  5.93it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.66it/s]
# S3 Epoch: 3: t_loss:0.144 t_acc:0.700 v_loss:0.136 v_acc:0.740
# 100%|██████████| 410/410 [01:09<00:00,  5.93it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.69it/s]
# S3 Epoch: 4: t_loss:0.130 t_acc:0.698 v_loss:0.140 v_acc:0.697
# 100%|██████████| 410/410 [01:09<00:00,  5.93it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.75it/s]
# S3 Epoch: 5: t_loss:0.129 t_acc:0.707 v_loss:0.145 v_acc:0.693
# 100%|██████████| 410/410 [01:09<00:00,  5.94it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.76it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.75it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [01:23<00:00,  4.89it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.06it/s]
# S1 Epoch: 1: t_loss:0.578 t_acc:0.368 v_loss:0.480 v_acc:0.190
# 100%|██████████| 410/410 [01:23<00:00,  4.88it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.14it/s]
# S1 Epoch: 2: t_loss:0.458 t_acc:0.289 v_loss:0.489 v_acc:0.190
# 100%|██████████| 410/410 [01:23<00:00,  4.89it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.10it/s]
# S1 Epoch: 3: t_loss:0.463 t_acc:0.319 v_loss:0.458 v_acc:0.362
# 100%|██████████| 410/410 [01:23<00:00,  4.89it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.13it/s]
# S1 Epoch: 4: t_loss:0.451 t_acc:0.338 v_loss:0.520 v_acc:0.201
# 100%|██████████| 410/410 [01:23<00:00,  4.89it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.17it/s]
# S1 Epoch: 5: t_loss:0.450 t_acc:0.361 v_loss:0.425 v_acc:0.324
# 100%|██████████| 410/410 [01:23<00:00,  4.89it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.11it/s]
# S1 Epoch: 6: t_loss:0.387 t_acc:0.493 v_loss:0.545 v_acc:0.400
# 100%|██████████| 410/410 [01:23<00:00,  4.89it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.12it/s]
# S1 Epoch: 7: t_loss:0.375 t_acc:0.485 v_loss:0.456 v_acc:0.401
# 100%|██████████| 410/410 [01:23<00:00,  4.89it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.17it/s]
# 100%|██████████| 40/40 [00:03<00:00, 13.13it/s]
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.0, llm_D=1.0
#  Validation Score Q1:0.7253
#  Validation Score Q2:0.7151
#  Validation Score Q3:0.7024
#  Validation Score S2:0.6154
#  Validation Score S3:0.7396
#  Validation Score S1:0.3242
# Average Validation Score: 0.6370
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.1, llm_D=0.9
#  Validation Score Q1:0.7253
#  Validation Score Q2:0.7151
#  Validation Score Q3:0.6644
#  Validation Score S2:0.6050
#  Validation Score S3:0.7396
#  Validation Score S1:0.3520
# Average Validation Score: 0.6336
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.2, llm_D=0.8
#  Validation Score Q1:0.7025
#  Validation Score Q2:0.7151
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5833
#  Validation Score S3:0.7396
#  Validation Score S1:0.4184
# Average Validation Score: 0.6305
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.3, llm_D=0.7
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5908
#  Validation Score S3:0.7396
#  Validation Score S1:0.4469
# Average Validation Score: 0.6310
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.4, llm_D=0.6
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6429
#  Validation Score S2:0.6190
#  Validation Score S3:0.7396
#  Validation Score S1:0.4683
# Average Validation Score: 0.6458
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.5, llm_D=0.5
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5489
#  Validation Score S3:0.7396
#  Validation Score S1:0.4466
# Average Validation Score: 0.6270
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.6, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5489
#  Validation Score S3:0.7396
#  Validation Score S1:0.4237
# Average Validation Score: 0.6232
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.7, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4720
#  Validation Score S3:0.7396
#  Validation Score S1:0.4456
# Average Validation Score: 0.6141
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.8, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.7396
#  Validation Score S1:0.4456
# Average Validation Score: 0.6132
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.9, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.7396
#  Validation Score S1:0.4456
# Average Validation Score: 0.6132
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=1.0, llm_D=0.0
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.7396
#  Validation Score S1:0.4456
# Average Validation Score: 0.6094
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.0, llm_D=0.9
#  Validation Score Q1:0.6925
#  Validation Score Q2:0.7151
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5908
#  Validation Score S3:0.6698
#  Validation Score S1:0.4384
# Average Validation Score: 0.6218
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.1, llm_D=0.8
#  Validation Score Q1:0.7253
#  Validation Score Q2:0.7484
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4436
# Average Validation Score: 0.6345
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.2, llm_D=0.7
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4463
# Average Validation Score: 0.6235
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.3, llm_D=0.6
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6429
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4674
# Average Validation Score: 0.6263
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.4, llm_D=0.5
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5489
#  Validation Score S3:0.6698
#  Validation Score S1:0.4906
# Average Validation Score: 0.6227
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.5, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4987
#  Validation Score S3:0.6931
#  Validation Score S1:0.4906
# Average Validation Score: 0.6182
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.6, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4720
#  Validation Score S3:0.6931
#  Validation Score S1:0.4687
# Average Validation Score: 0.6037
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.7, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4667
#  Validation Score S3:0.6931
#  Validation Score S1:0.4456
# Average Validation Score: 0.5990
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.8, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6931
#  Validation Score S1:0.4456
# Average Validation Score: 0.6026
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.9, llm_D=0.0
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6931
#  Validation Score S1:0.4456
# Average Validation Score: 0.5989
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.0, llm_D=0.8
#  Validation Score Q1:0.7484
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4843
# Average Validation Score: 0.6465
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.1, llm_D=0.7
#  Validation Score Q1:0.7025
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5611
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4888
# Average Validation Score: 0.6252
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.2, llm_D=0.6
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5247
#  Validation Score S3:0.6698
#  Validation Score S1:0.4674
# Average Validation Score: 0.6170
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.3, llm_D=0.5
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5747
#  Validation Score S3:0.6698
#  Validation Score S1:0.4674
# Average Validation Score: 0.6253
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.4, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5489
#  Validation Score S3:0.6698
#  Validation Score S1:0.4889
# Average Validation Score: 0.6213
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.5, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5223
#  Validation Score S3:0.6698
#  Validation Score S1:0.4889
# Average Validation Score: 0.6168
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.6, llm_D=0.2
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4949
#  Validation Score S3:0.6698
#  Validation Score S1:0.4906
# Average Validation Score: 0.6176
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.7, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6698
#  Validation Score S1:0.4456
# Average Validation Score: 0.6052
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.8, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6698
#  Validation Score S1:0.4456
# Average Validation Score: 0.6050
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.0, llm_D=0.7
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5423
#  Validation Score S2:0.5500
#  Validation Score S3:0.6698
#  Validation Score S1:0.4843
# Average Validation Score: 0.6138
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.1, llm_D=0.6
#  Validation Score Q1:0.7333
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5747
#  Validation Score S3:0.6698
#  Validation Score S1:0.4849
# Average Validation Score: 0.6338
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.2, llm_D=0.5
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5747
#  Validation Score S3:0.6698
#  Validation Score S1:0.4878
# Average Validation Score: 0.6338
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.3, llm_D=0.4
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5489
#  Validation Score S3:0.6698
#  Validation Score S1:0.4674
# Average Validation Score: 0.6261
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.4, llm_D=0.3
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5223
#  Validation Score S3:0.6698
#  Validation Score S1:0.4889
# Average Validation Score: 0.6252
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.5, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5455
#  Validation Score S3:0.6698
#  Validation Score S1:0.4889
# Average Validation Score: 0.6219
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.6, llm_D=0.1
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5396
#  Validation Score S3:0.6698
#  Validation Score S1:0.4889
# Average Validation Score: 0.6172
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.7, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6698
#  Validation Score S1:0.4466
# Average Validation Score: 0.6052
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.0, llm_D=0.6
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6581
#  Validation Score S2:0.5747
#  Validation Score S3:0.6698
#  Validation Score S1:0.4843
# Average Validation Score: 0.6373
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.1, llm_D=0.5
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5489
#  Validation Score S3:0.6698
#  Validation Score S1:0.4849
# Average Validation Score: 0.6270
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.2, llm_D=0.4
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5489
#  Validation Score S3:0.6698
#  Validation Score S1:0.4878
# Average Validation Score: 0.6273
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.3, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4365
# Average Validation Score: 0.6261
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.4, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5455
#  Validation Score S3:0.6698
#  Validation Score S1:0.4889
# Average Validation Score: 0.6303
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.5, llm_D=0.1
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5455
#  Validation Score S3:0.6698
#  Validation Score S1:0.4889
# Average Validation Score: 0.6232
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.6, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6698
#  Validation Score S1:0.4889
# Average Validation Score: 0.6270
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.0, llm_D=0.5
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6581
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4849
# Average Validation Score: 0.6433
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.1, llm_D=0.4
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6581
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4849
# Average Validation Score: 0.6383
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.2, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.3, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6698
#  Validation Score S1:0.4365
# Average Validation Score: 0.6246
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.4, llm_D=0.1
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4538
# Average Validation Score: 0.6282
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.5, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6429
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.5087
# Average Validation Score: 0.6447
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.0, llm_D=0.4
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.1, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5726
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6417
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.2, llm_D=0.2
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6322
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.3, llm_D=0.1
#  Validation Score Q1:0.6419
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4878
# Average Validation Score: 0.6237
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.4, llm_D=0.0
#  Validation Score Q1:0.6419
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4538
# Average Validation Score: 0.6180
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, cat_C=0.0, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5726
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6417
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, cat_C=0.1, llm_D=0.2
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6334
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, cat_C=0.2, llm_D=0.1
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6334
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, cat_C=0.3, llm_D=0.0
#  Validation Score Q1:0.6132
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4878
# Average Validation Score: 0.6253
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, cat_C=0.0, llm_D=0.2
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7630
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6295
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, cat_C=0.1, llm_D=0.1
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6334
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, cat_C=0.2, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6334
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.9, cat_C=0.0, llm_D=0.1
#  Validation Score Q1:0.6931
#  Validation Score Q2:0.7630
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4823
# Average Validation Score: 0.6338
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.9, cat_C=0.1, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7917
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6343
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=1.0, cat_C=0.0, llm_D=0.0
#  Validation Score Q1:0.6931
#  Validation Score Q2:0.7917
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4823
# Average Validation Score: 0.6386
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.0, llm_D=0.9
#  Validation Score Q1:0.6925
#  Validation Score Q2:0.7151
#  Validation Score Q3:0.6238
#  Validation Score S2:0.6050
#  Validation Score S3:0.6698
#  Validation Score S1:0.3115
# Average Validation Score: 0.6030
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.1, llm_D=0.8
#  Validation Score Q1:0.6703
#  Validation Score Q2:0.7484
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5833
#  Validation Score S3:0.6931
#  Validation Score S1:0.4131
# Average Validation Score: 0.6186
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.2, llm_D=0.7
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6429
#  Validation Score S2:0.5960
#  Validation Score S3:0.6931
#  Validation Score S1:0.4249
# Average Validation Score: 0.6270
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.3, llm_D=0.6
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6429
#  Validation Score S2:0.5726
#  Validation Score S3:0.6931
#  Validation Score S1:0.4463
# Average Validation Score: 0.6267
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.4, llm_D=0.5
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6429
#  Validation Score S2:0.5489
#  Validation Score S3:0.6931
#  Validation Score S1:0.4469
# Average Validation Score: 0.6228
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.5, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5000
#  Validation Score S3:0.6931
#  Validation Score S1:0.4683
# Average Validation Score: 0.6147
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.6, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4987
#  Validation Score S3:0.6931
#  Validation Score S1:0.4237
# Average Validation Score: 0.6007
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.7, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4667
#  Validation Score S3:0.6931
#  Validation Score S1:0.4456
# Average Validation Score: 0.5990
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.8, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4667
#  Validation Score S3:0.6931
#  Validation Score S1:0.4456
# Average Validation Score: 0.5990
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.9, llm_D=0.0
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4667
#  Validation Score S3:0.6931
#  Validation Score S1:0.4237
# Average Validation Score: 0.5953
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.0, llm_D=0.8
#  Validation Score Q1:0.7802
#  Validation Score Q2:0.7802
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.3929
# Average Validation Score: 0.6405
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.1, llm_D=0.7
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4667
# Average Validation Score: 0.6287
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.2, llm_D=0.6
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4249
# Average Validation Score: 0.6145
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.3, llm_D=0.5
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5247
#  Validation Score S3:0.6698
#  Validation Score S1:0.4674
# Average Validation Score: 0.6136
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.4, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5000
#  Validation Score S3:0.6698
#  Validation Score S1:0.4674
# Average Validation Score: 0.6095
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.5, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5223
#  Validation Score S3:0.6698
#  Validation Score S1:0.4906
# Average Validation Score: 0.6171
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.6, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4949
#  Validation Score S3:0.6698
#  Validation Score S1:0.4687
# Average Validation Score: 0.6089
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.7, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6698
#  Validation Score S1:0.4456
# ...
# Saved submission to submission_top150_0.6269.csv
# Rank 151: lgb_A=0.5, xgb_B=0.0, cat_C=0.4, llm_D=0.1 - Score: 0.6269
# Saved submission to submission_top151_0.6269.csv
# Rank 152: lgb_A=0.1, xgb_B=0.4, cat_C=0.3, llm_D=0.2 - Score: 0.6269
# Saved submission to submission_top152_0.6269.csv
# Rank 153: lgb_A=0.4, xgb_B=0.2, cat_C=0.1, llm_D=0.3 - Score: 0.6267
# Saved submission to submission_top153_0.6267.csv
# Rank 154: lgb_A=0.3, xgb_B=0.2, cat_C=0.1, llm_D=0.4 - Score: 0.6267
# Saved submission to submission_top154_0.6267.csv
# Rank 155: lgb_A=0.1, xgb_B=0.0, cat_C=0.3, llm_D=0.6 - Score: 0.6267
# Saved submission to submission_top155_0.6267.csv
# Rank 156: lgb_A=0.5, xgb_B=0.1, cat_C=0.3, llm_D=0.1 - Score: 0.6264
# Saved submission to submission_top156_0.6264.csv
# Rank 157: lgb_A=0.0, xgb_B=0.1, cat_C=0.3, llm_D=0.6 - Score: 0.6263
# Saved submission to submission_top157_0.6263.csv
# Rank 158: lgb_A=0.3, xgb_B=0.3, cat_C=0.3, llm_D=0.1 - Score: 0.6261
# Saved submission to submission_top158_0.6261.csv
# Rank 159: lgb_A=0.2, xgb_B=0.3, cat_C=0.1, llm_D=0.4 - Score: 0.6261
# Saved submission to submission_top159_0.6261.csv
# Rank 160: lgb_A=0.0, xgb_B=0.4, cat_C=0.3, llm_D=0.3 - Score: 0.6261
# Saved submission to submission_top160_0.6261.csv
# Rank 161: lgb_A=0.1, xgb_B=0.2, cat_C=0.0, llm_D=0.7 - Score: 0.6261
# Saved submission to submission_top161_0.6261.csv
# Rank 162: lgb_A=0.0, xgb_B=0.3, cat_C=0.3, llm_D=0.4 - Score: 0.6261
# Saved submission to submission_top162_0.6261.csv
# Rank 163: lgb_A=0.2, xgb_B=0.3, cat_C=0.2, llm_D=0.3 - Score: 0.6257
# Saved submission to submission_top163_0.6257.csv
# Rank 164: lgb_A=0.2, xgb_B=0.3, cat_C=0.3, llm_D=0.2 - Score: 0.6254
# Saved submission to submission_top164_0.6254.csv
# Rank 165: lgb_A=0.0, xgb_B=0.2, cat_C=0.3, llm_D=0.5 - Score: 0.6253
# Saved submission to submission_top165_0.6253.csv
# Rank 166: lgb_A=0.0, xgb_B=0.7, cat_C=0.3, llm_D=0.0 - Score: 0.6253
# Saved submission to submission_top166_0.6253.csv
# Rank 167: lgb_A=0.0, xgb_B=0.2, cat_C=0.1, llm_D=0.7 - Score: 0.6252
# Saved submission to submission_top167_0.6252.csv
# Rank 168: lgb_A=0.0, xgb_B=0.3, cat_C=0.4, llm_D=0.3 - Score: 0.6252
# Saved submission to submission_top168_0.6252.csv
# Rank 169: lgb_A=0.7, xgb_B=0.0, cat_C=0.0, llm_D=0.3 - Score: 0.6248
# Saved submission to submission_top169_0.6248.csv
# Rank 170: lgb_A=0.4, xgb_B=0.0, cat_C=0.6, llm_D=0.0 - Score: 0.6247
# Saved submission to submission_top170_0.6247.csv
# Rank 171: lgb_A=0.0, xgb_B=0.5, cat_C=0.3, llm_D=0.2 - Score: 0.6246
# Saved submission to submission_top171_0.6246.csv
# Rank 172: lgb_A=0.2, xgb_B=0.0, cat_C=0.1, llm_D=0.7 - Score: 0.6239
# Saved submission to submission_top172_0.6239.csv
# Rank 173: lgb_A=0.5, xgb_B=0.1, cat_C=0.0, llm_D=0.4 - Score: 0.6238
# Saved submission to submission_top173_0.6238.csv
# Rank 174: lgb_A=0.4, xgb_B=0.1, cat_C=0.1, llm_D=0.4 - Score: 0.6238
# Saved submission to submission_top174_0.6238.csv
# Rank 175: lgb_A=0.4, xgb_B=0.1, cat_C=0.0, llm_D=0.5 - Score: 0.6238
# Saved submission to submission_top175_0.6238.csv
# Rank 176: lgb_A=0.5, xgb_B=0.0, cat_C=0.0, llm_D=0.5 - Score: 0.6237
# Saved submission to submission_top176_0.6237.csv
# Rank 177: lgb_A=0.0, xgb_B=0.6, cat_C=0.3, llm_D=0.1 - Score: 0.6237
# Saved submission to submission_top177_0.6237.csv
# Rank 178: lgb_A=0.0, xgb_B=0.1, cat_C=0.2, llm_D=0.7 - Score: 0.6235
# Saved submission to submission_top178_0.6235.csv
# Rank 179: lgb_A=0.1, xgb_B=0.3, cat_C=0.1, llm_D=0.5 - Score: 0.6233
# Saved submission to submission_top179_0.6233.csv
# Rank 180: lgb_A=0.0, xgb_B=0.0, cat_C=0.6, llm_D=0.4 - Score: 0.6232
# Saved submission to submission_top180_0.6232.csv
# Rank 181: lgb_A=0.0, xgb_B=0.4, cat_C=0.5, llm_D=0.1 - Score: 0.6232
# Saved submission to submission_top181_0.6232.csv
# Rank 182: lgb_A=0.3, xgb_B=0.2, cat_C=0.0, llm_D=0.5 - Score: 0.6231
# Saved submission to submission_top182_0.6231.csv
# Rank 183: lgb_A=0.1, xgb_B=0.0, cat_C=0.4, llm_D=0.5 - Score: 0.6228
# Saved submission to submission_top183_0.6228.csv
# Rank 184: lgb_A=0.0, xgb_B=0.1, cat_C=0.4, llm_D=0.5 - Score: 0.6227
# Saved submission to submission_top184_0.6227.csv
# Rank 185: lgb_A=0.1, xgb_B=0.2, cat_C=0.3, llm_D=0.4 - Score: 0.6227
# Saved submission to submission_top185_0.6227.csv
# Rank 186: lgb_A=0.1, xgb_B=0.2, cat_C=0.4, llm_D=0.3 - Score: 0.6227
# Saved submission to submission_top186_0.6227.csv
# Rank 187: lgb_A=0.1, xgb_B=0.2, cat_C=0.1, llm_D=0.6 - Score: 0.6224
# Saved submission to submission_top187_0.6224.csv
# Rank 188: lgb_A=0.8, xgb_B=0.1, cat_C=0.1, llm_D=0.0 - Score: 0.6222
# Saved submission to submission_top188_0.6222.csv
# Rank 189: lgb_A=0.7, xgb_B=0.1, cat_C=0.0, llm_D=0.2 - Score: 0.6220
# Saved submission to submission_top189_0.6220.csv
# Rank 190: lgb_A=0.6, xgb_B=0.1, cat_C=0.0, llm_D=0.3 - Score: 0.6220
# Saved submission to submission_top190_0.6220.csv
# Rank 191: lgb_A=0.2, xgb_B=0.2, cat_C=0.6, llm_D=0.0 - Score: 0.6220
# Saved submission to submission_top191_0.6220.csv
# Rank 192: lgb_A=0.0, xgb_B=0.3, cat_C=0.5, llm_D=0.2 - Score: 0.6219
# Saved submission to submission_top192_0.6219.csv
# Rank 193: lgb_A=0.1, xgb_B=0.5, cat_C=0.4, llm_D=0.0 - Score: 0.6219
# Saved submission to submission_top193_0.6219.csv
# Rank 194: lgb_A=0.2, xgb_B=0.1, cat_C=0.0, llm_D=0.7 - Score: 0.6219
# Saved submission to submission_top194_0.6219.csv
# Rank 195: lgb_A=0.1, xgb_B=0.3, cat_C=0.6, llm_D=0.0 - Score: 0.6218
# Saved submission to submission_top195_0.6218.csv
# Rank 196: lgb_A=0.0, xgb_B=0.1, cat_C=0.0, llm_D=0.9 - Score: 0.6218
# Saved submission to submission_top196_0.6218.csv
# Rank 197: lgb_A=0.0, xgb_B=0.2, cat_C=0.4, llm_D=0.4 - Score: 0.6213
# Saved submission to submission_top197_0.6213.csv
# Rank 198: lgb_A=0.4, xgb_B=0.0, cat_C=0.3, llm_D=0.3 - Score: 0.6212
# Saved submission to submission_top198_0.6212.csv
# Rank 199: lgb_A=0.8, xgb_B=0.0, cat_C=0.1, llm_D=0.1 - Score: 0.6208
# Saved submission to submission_top199_0.6208.csv
# Rank 200: lgb_A=0.2, xgb_B=0.0, cat_C=0.0, llm_D=0.8 - Score: 0.6208
# Saved submission to submission_top200_0.6208.csv
# Rank 201: lgb_A=0.4, xgb_B=0.0, cat_C=0.1, llm_D=0.5 - Score: 0.6206
# Saved submission to submission_top201_0.6206.csv
# Rank 202: lgb_A=0.7, xgb_B=0.0, cat_C=0.3, llm_D=0.0 - Score: 0.6201
# Saved submission to submission_top202_0.6201.csv
# Rank 203: lgb_A=0.5, xgb_B=0.1, cat_C=0.1, llm_D=0.3 - Score: 0.6201
# Saved submission to submission_top203_0.6201.csv
# Rank 204: lgb_A=0.2, xgb_B=0.2, cat_C=0.0, llm_D=0.6 - Score: 0.6199
# Saved submission to submission_top204_0.6199.csv
# Rank 205: lgb_A=0.8, xgb_B=0.0, cat_C=0.2, llm_D=0.0 - Score: 0.6199
# Saved submission to submission_top205_0.6199.csv
# Rank 206: lgb_A=0.1, xgb_B=0.2, cat_C=0.6, llm_D=0.1 - Score: 0.6198
# Saved submission to submission_top206_0.6198.csv
# Rank 207: lgb_A=0.6, xgb_B=0.1, cat_C=0.2, llm_D=0.1 - Score: 0.6197
# Saved submission to submission_top207_0.6197.csv
# Rank 208: lgb_A=0.5, xgb_B=0.1, cat_C=0.2, llm_D=0.2 - Score: 0.6195
# Saved submission to submission_top208_0.6195.csv
# Rank 209: lgb_A=0.1, xgb_B=0.3, cat_C=0.2, llm_D=0.4 - Score: 0.6194
# Saved submission to submission_top209_0.6194.csv
# Rank 210: lgb_A=0.2, xgb_B=0.1, cat_C=0.3, llm_D=0.4 - Score: 0.6187
# Saved submission to submission_top210_0.6187.csv
# Rank 211: lgb_A=0.1, xgb_B=0.0, cat_C=0.1, llm_D=0.8 - Score: 0.6186
# Saved submission to submission_top211_0.6186.csv
# Rank 212: lgb_A=0.0, xgb_B=0.1, cat_C=0.5, llm_D=0.4 - Score: 0.6182
# Saved submission to submission_top212_0.6182.csv
# Rank 213: lgb_A=0.0, xgb_B=0.6, cat_C=0.4, llm_D=0.0 - Score: 0.6180
# Saved submission to submission_top213_0.6180.csv
# Rank 214: lgb_A=0.2, xgb_B=0.0, cat_C=0.2, llm_D=0.6 - Score: 0.6177
# Saved submission to submission_top214_0.6177.csv
# Rank 215: lgb_A=0.0, xgb_B=0.2, cat_C=0.6, llm_D=0.2 - Score: 0.6176
# Saved submission to submission_top215_0.6176.csv
# Rank 216: lgb_A=0.3, xgb_B=0.0, cat_C=0.1, llm_D=0.6 - Score: 0.6174
# Saved submission to submission_top216_0.6174.csv
# Rank 217: lgb_A=0.1, xgb_B=0.2, cat_C=0.5, llm_D=0.2 - Score: 0.6173
# Saved submission to submission_top217_0.6173.csv
# Rank 218: lgb_A=0.0, xgb_B=0.3, cat_C=0.6, llm_D=0.1 - Score: 0.6172
# Saved submission to submission_top218_0.6172.csv
# Rank 219: lgb_A=0.1, xgb_B=0.1, cat_C=0.5, llm_D=0.3 - Score: 0.6171
# Saved submission to submission_top219_0.6171.csv
# Rank 220: lgb_A=0.0, xgb_B=0.2, cat_C=0.2, llm_D=0.6 - Score: 0.6170
# Saved submission to submission_top220_0.6170.csv
# Rank 221: lgb_A=0.0, xgb_B=0.2, cat_C=0.5, llm_D=0.3 - Score: 0.6168
# Saved submission to submission_top221_0.6168.csv
# Rank 222: lgb_A=0.2, xgb_B=0.2, cat_C=0.1, llm_D=0.5 - Score: 0.6164
# Saved submission to submission_top222_0.6164.csv
# Rank 223: lgb_A=0.4, xgb_B=0.0, cat_C=0.4, llm_D=0.2 - Score: 0.6163
# Saved submission to submission_top223_0.6163.csv
# Rank 224: lgb_A=0.4, xgb_B=0.0, cat_C=0.0, llm_D=0.6 - Score: 0.6163
# Saved submission to submission_top224_0.6163.csv
# Rank 225: lgb_A=0.7, xgb_B=0.0, cat_C=0.2, llm_D=0.1 - Score: 0.6163
# Saved submission to submission_top225_0.6163.csv
# Rank 226: lgb_A=0.7, xgb_B=0.0, cat_C=0.1, llm_D=0.2 - Score: 0.6163
# Saved submission to submission_top226_0.6163.csv
# Rank 227: lgb_A=0.7, xgb_B=0.1, cat_C=0.2, llm_D=0.0 - Score: 0.6162
# Saved submission to submission_top227_0.6162.csv
# Rank 228: lgb_A=0.6, xgb_B=0.1, cat_C=0.1, llm_D=0.2 - Score: 0.6161
# Saved submission to submission_top228_0.6161.csv
# Rank 229: lgb_A=0.3, xgb_B=0.0, cat_C=0.5, llm_D=0.2 - Score: 0.6154
# Saved submission to submission_top229_0.6154.csv
# Rank 230: lgb_A=0.7, xgb_B=0.1, cat_C=0.1, llm_D=0.1 - Score: 0.6154
# Saved submission to submission_top230_0.6154.csv
# Rank 231: lgb_A=0.6, xgb_B=0.0, cat_C=0.2, llm_D=0.2 - Score: 0.6150
# Saved submission to submission_top231_0.6150.csv
# Rank 232: lgb_A=0.5, xgb_B=0.0, cat_C=0.2, llm_D=0.3 - Score: 0.6148
# Saved submission to submission_top232_0.6148.csv
# Rank 233: lgb_A=0.1, xgb_B=0.0, cat_C=0.5, llm_D=0.4 - Score: 0.6147
# Saved submission to submission_top233_0.6147.csv
# Rank 234: lgb_A=0.5, xgb_B=0.0, cat_C=0.1, llm_D=0.4 - Score: 0.6147
# Saved submission to submission_top234_0.6147.csv
# Rank 235: lgb_A=0.1, xgb_B=0.1, cat_C=0.2, llm_D=0.6 - Score: 0.6145
# Saved submission to submission_top235_0.6145.csv
# Rank 236: lgb_A=0.2, xgb_B=0.1, cat_C=0.1, llm_D=0.6 - Score: 0.6145
# Saved submission to submission_top236_0.6145.csv
# Rank 237: lgb_A=0.0, xgb_B=0.0, cat_C=0.7, llm_D=0.3 - Score: 0.6141
# Saved submission to submission_top237_0.6141.csv
# Rank 238: lgb_A=0.4, xgb_B=0.0, cat_C=0.2, llm_D=0.4 - Score: 0.6138
# Saved submission to submission_top238_0.6138.csv
# Rank 239: lgb_A=0.0, xgb_B=0.3, cat_C=0.0, llm_D=0.7 - Score: 0.6138
# Saved submission to submission_top239_0.6138.csv
# Rank 240: lgb_A=0.1, xgb_B=0.1, cat_C=0.3, llm_D=0.5 - Score: 0.6136
# Saved submission to submission_top240_0.6136.csv
# Rank 241: lgb_A=0.1, xgb_B=0.2, cat_C=0.2, llm_D=0.5 - Score: 0.6136
# Saved submission to submission_top241_0.6136.csv
# Rank 242: lgb_A=0.2, xgb_B=0.1, cat_C=0.7, llm_D=0.0 - Score: 0.6136
# Saved submission to submission_top242_0.6136.csv
# Rank 243: lgb_A=0.2, xgb_B=0.1, cat_C=0.5, llm_D=0.2 - Score: 0.6132
# Saved submission to submission_top243_0.6132.csv
# Rank 244: lgb_A=0.2, xgb_B=0.1, cat_C=0.4, llm_D=0.3 - Score: 0.6132
# Saved submission to submission_top244_0.6132.csv
# Rank 245: lgb_A=0.0, xgb_B=0.0, cat_C=0.8, llm_D=0.2 - Score: 0.6132
# Saved submission to submission_top245_0.6132.csv
# Rank 246: lgb_A=0.0, xgb_B=0.0, cat_C=0.9, llm_D=0.1 - Score: 0.6132
# Saved submission to submission_top246_0.6132.csv
# Rank 247: lgb_A=0.2, xgb_B=0.1, cat_C=0.6, llm_D=0.1 - Score: 0.6128
# Saved submission to submission_top247_0.6128.csv
# Rank 248: lgb_A=0.3, xgb_B=0.1, cat_C=0.1, llm_D=0.5 - Score: 0.6124
# Saved submission to submission_top248_0.6124.csv
# Rank 249: lgb_A=0.2, xgb_B=0.0, cat_C=0.3, llm_D=0.5 - Score: 0.6123
# Saved submission to submission_top249_0.6123.csv
# Rank 250: lgb_A=0.4, xgb_B=0.0, cat_C=0.5, llm_D=0.1 - Score: 0.6119
# Saved submission to submission_top250_0.6119.csv
# Rank 251: lgb_A=0.6, xgb_B=0.0, cat_C=0.1, llm_D=0.3 - Score: 0.6117
# Saved submission to submission_top251_0.6117.csv
# Rank 252: lgb_A=0.3, xgb_B=0.1, cat_C=0.2, llm_D=0.4 - Score: 0.6116
# Saved submission to submission_top252_0.6116.csv
# Rank 253: lgb_A=0.2, xgb_B=0.1, cat_C=0.2, llm_D=0.5 - Score: 0.6116
# Saved submission to submission_top253_0.6116.csv
# Rank 254: lgb_A=0.3, xgb_B=0.1, cat_C=0.0, llm_D=0.6 - Score: 0.6115
# Saved submission to submission_top254_0.6115.csv
# Rank 255: lgb_A=0.3, xgb_B=0.0, cat_C=0.3, llm_D=0.4 - Score: 0.6109
# Saved submission to submission_top255_0.6109.csv
# Rank 256: lgb_A=0.1, xgb_B=0.1, cat_C=0.4, llm_D=0.4 - Score: 0.6095
# Saved submission to submission_top256_0.6095.csv
# Rank 257: lgb_A=0.0, xgb_B=0.0, cat_C=1.0, llm_D=0.0 - Score: 0.6094
# Saved submission to submission_top257_0.6094.csv
# Rank 258: lgb_A=0.1, xgb_B=0.1, cat_C=0.6, llm_D=0.2 - Score: 0.6089
# Saved submission to submission_top258_0.6089.csv
# Rank 259: lgb_A=0.1, xgb_B=0.2, cat_C=0.7, llm_D=0.0 - Score: 0.6089
# Saved submission to submission_top259_0.6089.csv
# Rank 260: lgb_A=0.3, xgb_B=0.0, cat_C=0.4, llm_D=0.3 - Score: 0.6074
# Saved submission to submission_top260_0.6074.csv
# Rank 261: lgb_A=0.3, xgb_B=0.0, cat_C=0.2, llm_D=0.5 - Score: 0.6072
# Saved submission to submission_top261_0.6072.csv
# Rank 262: lgb_A=0.3, xgb_B=0.0, cat_C=0.6, llm_D=0.1 - Score: 0.6065
# Saved submission to submission_top262_0.6065.csv
# Rank 263: lgb_A=0.0, xgb_B=0.2, cat_C=0.7, llm_D=0.1 - Score: 0.6052
# Saved submission to submission_top263_0.6052.csv
# Rank 264: lgb_A=0.0, xgb_B=0.3, cat_C=0.7, llm_D=0.0 - Score: 0.6052
# Saved submission to submission_top264_0.6052.csv
# Rank 265: lgb_A=0.0, xgb_B=0.2, cat_C=0.8, llm_D=0.0 - Score: 0.6050
# Saved submission to submission_top265_0.6050.csv
# Rank 266: lgb_A=0.1, xgb_B=0.1, cat_C=0.8, llm_D=0.0 - Score: 0.6040
# Saved submission to submission_top266_0.6040.csv
# Rank 267: lgb_A=0.1, xgb_B=0.1, cat_C=0.7, llm_D=0.1 - Score: 0.6040
# Saved submission to submission_top267_0.6040.csv
# Rank 268: lgb_A=0.0, xgb_B=0.1, cat_C=0.6, llm_D=0.3 - Score: 0.6037
# Saved submission to submission_top268_0.6037.csv
# Rank 269: lgb_A=0.1, xgb_B=0.0, cat_C=0.0, llm_D=0.9 - Score: 0.6030
# Saved submission to submission_top269_0.6030.csv
# Rank 270: lgb_A=0.0, xgb_B=0.1, cat_C=0.8, llm_D=0.1 - Score: 0.6026
# Saved submission to submission_top270_0.6026.csv
# Rank 271: lgb_A=0.3, xgb_B=0.0, cat_C=0.7, llm_D=0.0 - Score: 0.6014
# Saved submission to submission_top271_0.6014.csv
# Rank 272: lgb_A=0.1, xgb_B=0.0, cat_C=0.6, llm_D=0.3 - Score: 0.6007
# Saved submission to submission_top272_0.6007.csv
# Rank 273: lgb_A=0.0, xgb_B=0.1, cat_C=0.7, llm_D=0.2 - Score: 0.5990
# Saved submission to submission_top273_0.5990.csv
# Rank 274: lgb_A=0.1, xgb_B=0.0, cat_C=0.8, llm_D=0.1 - Score: 0.5990
# Saved submission to submission_top274_0.5990.csv
# Rank 275: lgb_A=0.1, xgb_B=0.0, cat_C=0.7, llm_D=0.2 - Score: 0.5990
# Saved submission to submission_top275_0.5990.csv
# Rank 276: lgb_A=0.2, xgb_B=0.0, cat_C=0.8, llm_D=0.0 - Score: 0.5990
# Saved submission to submission_top276_0.5990.csv
# Rank 277: lgb_A=0.0, xgb_B=0.1, cat_C=0.9, llm_D=0.0 - Score: 0.5989
# Saved submission to submission_top277_0.5989.csv
# Rank 278: lgb_A=0.2, xgb_B=0.0, cat_C=0.5, llm_D=0.3 - Score: 0.5967
# Saved submission to submission_top278_0.5967.csv
# Rank 279: lgb_A=0.2, xgb_B=0.0, cat_C=0.4, llm_D=0.4 - Score: 0.5966
# Saved submission to submission_top279_0.5966.csv
# Rank 280: lgb_A=0.1, xgb_B=0.0, cat_C=0.9, llm_D=0.0 - Score: 0.5953
# Saved submission to submission_top280_0.5953.csv
# Rank 281: lgb_A=0.2, xgb_B=0.0, cat_C=0.7, llm_D=0.1 - Score: 0.5951
# Saved submission to submission_top281_0.5951.csv
# Rank 282: lgb_A=0.2, xgb_B=0.0, cat_C=0.6, llm_D=0.2 - Score: 0.5889
# Saved submission to submission_top282_0.5889.csv
#
#  STEP3: 예측결과 비교표
#     학습sum  학습len  학습mean  테스트sum  테스트len  테스트mean
# Q1    223    450  0.4956     139     250   0.5560
# Q2    253    450  0.5622     157     250   0.6280
# Q3    270    450  0.6000     177     250   0.7080
# S1    390    450  0.8667     193     250   0.7720
# S2    293    450  0.6511     147     250   0.5880
# S3    298    450  0.6622     176     250   0.7040

# %% [markdown]
# ### 📦 제출

# %%
import pandas as pd
import os
from pathlib import Path

# Reference file
reference_file = '/kaggle/input/dacon-etri-lifelog/submission_0.624161182814381_best.csv'
ref_df = pd.read_csv(reference_file)

# Get all CSV files in data directory
data_dir = Path('/kaggle/working')
csv_files = list(data_dir.glob('*.csv'))

# Store differences for each file
differences = []

for csv_file in csv_files:
    if csv_file.name == os.path.basename(reference_file):
        continue

    # Read current file
    current_df = pd.read_csv(csv_file)

    # Calculate differences in specified columns
    diff_count = 0
    for col in ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']:
        diff_count += (ref_df[col] != current_df[col]).sum()

    differences.append((csv_file.name, diff_count))
    print(f"File: {csv_file.name}, Differences: {diff_count}")

# Sort by difference count and get top 20
differences.sort(key=lambda x: x[1])
print("\nTop 20 files with smallest differences:")
for i, (file_name, diff_count) in enumerate(differences[:20], 1):
    print(f"{i}. {file_name}: {diff_count} differences")
# Out:
# File: submission_top232_0.6148.csv, Differences: 111
# File: submission_top173_0.6238.csv, Differences: 102
# File: submission_top277_0.5989.csv, Differences: 151
# File: submission_top5_0.6469.csv, Differences: 66
# File: submission_top248_0.6124.csv, Differences: 107
# File: submission_top85_0.6346.csv, Differences: 64
# File: submission_top163_0.6257.csv, Differences: 62
# File: submission_top197_0.6213.csv, Differences: 106
# File: submission_top42_0.6392.csv, Differences: 48
# File: submission_top150_0.6269.csv, Differences: 110
# File: submission_top52_0.6383.csv, Differences: 50
# File: submission_top271_0.6014.csv, Differences: 136
# File: submission_top134_0.6280.csv, Differences: 102
# File: submission_top4_0.6471.csv, Differences: 52
# File: submission_top51_0.6383.csv, Differences: 51
# File: submission_top108_0.6317.csv, Differences: 83
# File: submission_top27_0.6422.csv, Differences: 87
# File: submission_top276_0.5990.csv, Differences: 146
# File: submission_top168_0.6252.csv, Differences: 83
# File: submission_top148_0.6270.csv, Differences: 76
# File: submission_top220_0.6170.csv, Differences: 112
# File: submission_top33_0.6412.csv, Differences: 65
# File: submission_top258_0.6089.csv, Differences: 121
# File: submission_top114_0.6310.csv, Differences: 73
# File: submission_top143_0.6271.csv, Differences: 56
# File: submission_top48_0.6386.csv, Differences: 52
# File: submission_top267_0.6040.csv, Differences: 126
# File: submission_top6_0.6465.csv, Differences: 55
# File: submission_top238_0.6138.csv, Differences: 118
# File: submission_top178_0.6235.csv, Differences: 163
# File: submission_top195_0.6218.csv, Differences: 86
# File: submission_top249_0.6123.csv, Differences: 155
# File: submission_top199_0.6208.csv, Differences: 102
# File: submission_top259_0.6089.csv, Differences: 106
# File: submission_top223_0.6163.csv, Differences: 118
# File: submission_top36_0.6405.csv, Differences: 58
# File: submission_top188_0.6222.csv, Differences: 88
# File: submission_top179_0.6233.csv, Differences: 62
# File: submission_top216_0.6174.csv, Differences: 154
# File: submission_top16_0.6444.csv, Differences: 57
# File: submission_top3_0.6478.csv, Differences: 42
# File: submission_top75_0.6354.csv, Differences: 115
# File: submission_top77_0.6354.csv, Differences: 49
# File: submission_top59_0.6372.csv, Differences: 61
# File: submission_top141_0.6273.csv, Differences: 58
# File: submission_top102_0.6334.csv, Differences: 50
# File: submission_top231_0.6150.csv, Differences: 101
# File: submission_top221_0.6168.csv, Differences: 108
# File: submission_top213_0.6180.csv, Differences: 55
# File: submission_top106_0.6322.csv, Differences: 44
# File: submission_top155_0.6267.csv, Differences: 177
# File: submission_top82_0.6352.csv, Differences: 86
# File: submission_top31_0.6417.csv, Differences: 47
# File: submission_top139_0.6276.csv, Differences: 79
# File: submission_top120_0.6305.csv, Differences: 237
# File: submission_top185_0.6227.csv, Differences: 88
# File: submission_top246_0.6132.csv, Differences: 190
# File: submission_top119_0.6305.csv, Differences: 73
# File: submission_top61_0.6372.csv, Differences: 68
# File: submission_top205_0.6199.csv, Differences: 99
# File: submission_top46_0.6387.csv, Differences: 70
# File: submission_top38_0.6402.csv, Differences: 56
# File: submission_top166_0.6253.csv, Differences: 50
# File: submission_top274_0.5990.csv, Differences: 169
# File: submission_top17_0.6438.csv, Differences: 44
# File: submission_top191_0.6220.csv, Differences: 94
# File: submission_top21_0.6433.csv, Differences: 50
# File: submission_top242_0.6136.csv, Differences: 113
# File: submission_top128_0.6287.csv, Differences: 148
# File: submission_top124_0.6296.csv, Differences: 46
# File: submission_top227_0.6162.csv, Differences: 83
# File: submission_top159_0.6261.csv, Differences: 59
# File: submission_top192_0.6219.csv, Differences: 91
# File: submission_top23_0.6432.csv, Differences: 49
# File: submission_top91_0.6339.csv, Differences: 95
# File: submission_top241_0.6136.csv, Differences: 87
# File: submission_top275_0.5990.csv, Differences: 168
# File: submission_top158_0.6261.csv, Differences: 66
# File: submission_top118_0.6308.csv, Differences: 56
# File: submission_top196_0.6218.csv, Differences: 234
# File: submission_top272_0.6007.csv, Differences: 170
# File: submission_top2_0.6487.csv, Differences: 42
# File: submission_top56_0.6381.csv, Differences: 69
# File: submission_top74_0.6355.csv, Differences: 85
# File: submission_top200_0.6208.csv, Differences: 221
# File: submission_top257_0.6094.csv, Differences: 194
# File: submission_top184_0.6227.csv, Differences: 152
# File: submission_top79_0.6354.csv, Differences: 54
# File: submission_top169_0.6248.csv, Differences: 127
# File: submission_top154_0.6267.csv, Differences: 71
# File: submission_top177_0.6237.csv, Differences: 50
# File: submission_top234_0.6147.csv, Differences: 122
# File: submission_top152_0.6269.csv, Differences: 60
# File: submission_top115_0.6310.csv, Differences: 204
# File: submission_top35_0.6405.csv, Differences: 187
# File: submission_top14_0.6449.csv, Differences: 63
# File: submission_top144_0.6270.csv, Differences: 191
# File: submission_top133_0.6281.csv, Differences: 102
# File: submission_top247_0.6128.csv, Differences: 110
# File: submission_top107_0.6321.csv, Differences: 74
# File: submission_top11_0.6461.csv, Differences: 47
# File: submission_top164_0.6254.csv, Differences: 63
# File: submission_top201_0.6206.csv, Differences: 134
# File: submission_top117_0.6308.csv, Differences: 49
# File: submission_top209_0.6194.csv, Differences: 64
# File: submission_top254_0.6115.csv, Differences: 122
# File: submission_top138_0.6277.csv, Differences: 100
# File: submission_top245_0.6132.csv, Differences: 190
# File: submission_top172_0.6239.csv, Differences: 180
# File: submission_top190_0.6220.csv, Differences: 100
# File: submission_top215_0.6176.csv, Differences: 107
# File: submission_top157_0.6263.csv, Differences: 156
# File: submission_top28_0.6418.csv, Differences: 53
# File: submission_top176_0.6237.csv, Differences: 139
# File: submission_top181_0.6232.csv, Differences: 68
# File: submission_top94_0.6338.csv, Differences: 74
# File: submission_top104_0.6327.csv, Differences: 101
# File: submission_top126_0.6295.csv, Differences: 55
# File: submission_top263_0.6052.csv, Differences: 106
# File: submission_top86_0.6346.csv, Differences: 110
# File: submission_top222_0.6164.csv, Differences: 73
# File: submission_top244_0.6132.csv, Differences: 109
# File: submission_top131_0.6284.csv, Differences: 130
# File: submission_top37_0.6405.csv, Differences: 57
# File: submission_top13_0.6451.csv, Differences: 48
# File: submission_top149_0.6269.csv, Differences: 75
# File: submission_top127_0.6289.csv, Differences: 45
# File: submission_top260_0.6074.csv, Differences: 137
# File: submission_top153_0.6267.csv, Differences: 75
# File: submission_top98_0.6336.csv, Differences: 307
# File: submission_top7_0.6465.csv, Differences: 48
# File: submission_top20_0.6436.csv, Differences: 51
# File: submission_top57_0.6373.csv, Differences: 76
# File: submission_top90_0.6340.csv, Differences: 71
# File: submission_top9_0.6464.csv, Differences: 52
# File: submission_top40_0.6394.csv, Differences: 115
# File: submission_top229_0.6154.csv, Differences: 131
# File: submission_top58_0.6373.csv, Differences: 69
# File: submission_top186_0.6227.csv, Differences: 92
# File: submission_top70_0.6359.csv, Differences: 55
# File: submission_top256_0.6095.csv, Differences: 138
# File: submission_top18_0.6438.csv, Differences: 51
# File: submission_top198_0.6212.csv, Differences: 125
# File: submission_top49_0.6386.csv, Differences: 56
# File: submission_top125_0.6296.csv, Differences: 44
# File: submission_top39_0.6398.csv, Differences: 61
# File: submission_top165_0.6253.csv, Differences: 113
# File: submission_top261_0.6072.csv, Differences: 134
# File: submission_top239_0.6138.csv, Differences: 101
# File: submission_top189_0.6220.csv, Differences: 95
# File: submission_top265_0.6050.csv, Differences: 123
# File: submission_top111_0.6315.csv, Differences: 81
# File: submission_top253_0.6116.csv, Differences: 111
# File: submission_top240_0.6136.csv, Differences: 131
# File: submission_top140_0.6276.csv, Differences: 71
# File: submission_top264_0.6052.csv, Differences: 98
# File: submission_top224_0.6163.csv, Differences: 161
# File: submission_top76_0.6354.csv, Differences: 97
# File: submission_top10_0.6461.csv, Differences: 51
# File: submission_top116_0.6309.csv, Differences: 189
# File: submission_top204_0.6199.csv, Differences: 88
# File: submission_top43_0.6392.csv, Differences: 45
# File: submission_top262_0.6065.csv, Differences: 128
# File: submission_top112_0.6314.csv, Differences: 122
# File: submission_top237_0.6141.csv, Differences: 195
# File: submission_top84_0.6348.csv, Differences: 49
# File: submission_top71_0.6359.csv, Differences: 49
# File: submission_top64_0.6371.csv, Differences: 74
# File: submission_top50_0.6384.csv, Differences: 65
# File: submission_top137_0.6277.csv, Differences: 69
# File: submission_top175_0.6238.csv, Differences: 110
# File: submission_top65_0.6370.csv, Differences: 389
# File: submission_top62_0.6372.csv, Differences: 67
# File: submission_top278_0.5967.csv, Differences: 147
# File: submission_top95_0.6338.csv, Differences: 75
# File: submission_top44_0.6388.csv, Differences: 49
# File: submission_top162_0.6261.csv, Differences: 74
# File: submission_top167_0.6252.csv, Differences: 121
# File: submission_top225_0.6163.csv, Differences: 99
# File: submission_top121_0.6303.csv, Differences: 64
# File: submission_top219_0.6171.csv, Differences: 128
# File: submission_top113_0.6313.csv, Differences: 76
# File: submission_top15_0.6447.csv, Differences: 61
# File: submission_top19_0.6436.csv, Differences: 52
# File: submission_top156_0.6264.csv, Differences: 88
# File: submission_top78_0.6354.csv, Differences: 53
# File: submission_top41_0.6392.csv, Differences: 51
# File: submission_top217_0.6173.csv, Differences: 95
# File: submission_top194_0.6219.csv, Differences: 144
# File: submission_top54_0.6382.csv, Differences: 51
# File: submission_top214_0.6177.csv, Differences: 153
# File: submission_top53_0.6383.csv, Differences: 65
# File: submission_top251_0.6117.csv, Differences: 107
# File: submission_top45_0.6388.csv, Differences: 54
# File: submission_top160_0.6261.csv, Differences: 62
# File: submission_top270_0.6026.csv, Differences: 150
# File: submission_top151_0.6269.csv, Differences: 111
# File: submission_top88_0.6343.csv, Differences: 56
# File: submission_top266_0.6040.csv, Differences: 130
# File: submission_top252_0.6116.csv, Differences: 101
# File: submission_top132_0.6282.csv, Differences: 59
# File: submission_top123_0.6300.csv, Differences: 92
# File: submission_top12_0.6458.csv, Differences: 193
# File: submission_top34_0.6409.csv, Differences: 57
# File: submission_top147_0.6270.csv, Differences: 62
# File: submission_top174_0.6238.csv, Differences: 92
# File: submission_top206_0.6198.csv, Differences: 98
# File: submission_top29_0.6418.csv, Differences: 51
# File: submission_top103_0.6329.csv, Differences: 97
# File: submission_top130_0.6286.csv, Differences: 105
# File: submission_top100_0.6334.csv, Differences: 52
# File: submission_top105_0.6327.csv, Differences: 83
# File: submission_top83_0.6351.csv, Differences: 69
# File: submission_top55_0.6382.csv, Differences: 52
# File: submission_top99_0.6334.csv, Differences: 44
# File: submission_top145_0.6270.csv, Differences: 109
# File: submission_top109_0.6317.csv, Differences: 96
# File: submission_top210_0.6187.csv, Differences: 114
# File: submission_top250_0.6119.csv, Differences: 118
# File: submission_0.6261336267831857.csv, Differences: 101
# File: submission_top80_0.6354.csv, Differences: 60
# File: submission_top207_0.6197.csv, Differences: 84
# File: submission_top226_0.6163.csv, Differences: 104
# File: submission_top142_0.6272.csv, Differences: 62
# File: submission_top233_0.6147.csv, Differences: 171
# File: submission_top218_0.6172.csv, Differences: 91
# File: submission_top129_0.6287.csv, Differences: 101
# File: submission_top97_0.6337.csv, Differences: 81
# File: submission_top183_0.6228.csv, Differences: 168
# File: submission_top92_0.6338.csv, Differences: 79
# File: submission_top135_0.6279.csv, Differences: 71
# File: submission_top1_0.6492.csv, Differences: 53
# File: submission_top171_0.6246.csv, Differences: 59
# File: submission_top26_0.6423.csv, Differences: 67
# File: submission_top236_0.6145.csv, Differences: 114
# File: submission_top8_0.6465.csv, Differences: 142
# File: submission_top63_0.6371.csv, Differences: 89
# File: submission_top72_0.6357.csv, Differences: 81
# File: submission_top243_0.6132.csv, Differences: 108
# File: submission_top170_0.6247.csv, Differences: 115
# File: submission_top235_0.6145.csv, Differences: 132
# File: submission_top24_0.6430.csv, Differences: 60
# File: submission_top193_0.6219.csv, Differences: 54
# File: submission_top255_0.6109.csv, Differences: 137
# File: submission_top180_0.6232.csv, Differences: 197
# File: submission_top68_0.6364.csv, Differences: 62
# File: submission_top73_0.6357.csv, Differences: 82
# File: submission_top60_0.6372.csv, Differences: 50
# File: submission_top203_0.6201.csv, Differences: 91
# File: submission_top89_0.6342.csv, Differences: 63
# File: submission_top280_0.5953.csv, Differences: 168
# File: submission_top30_0.6417.csv, Differences: 59
# File: submission_top96_0.6337.csv, Differences: 81
# File: submission_top25_0.6427.csv, Differences: 50
# File: submission_top211_0.6186.csv, Differences: 230
# File: submission_top146_0.6270.csv, Differences: 187
# File: submission_top47_0.6386.csv, Differences: 69
# File: submission_top279_0.5966.csv, Differences: 149
# File: submission_top87_0.6345.csv, Differences: 190
# File: submission_top208_0.6195.csv, Differences: 87
# File: submission_top281_0.5951.csv, Differences: 148
# File: submission_top228_0.6161.csv, Differences: 89
# File: submission_top67_0.6365.csv, Differences: 84
# File: submission_top93_0.6338.csv, Differences: 59
# File: submission_top269_0.6030.csv, Differences: 283
# File: submission_top32_0.6417.csv, Differences: 47
# File: submission_top69_0.6363.csv, Differences: 53
# File: submission_top161_0.6261.csv, Differences: 109
# File: submission_top187_0.6224.csv, Differences: 98
# File: submission_top273_0.5990.csv, Differences: 153
# File: submission_top182_0.6231.csv, Differences: 79
# File: submission_top22_0.6433.csv, Differences: 64
# File: submission_top268_0.6037.csv, Differences: 152
# File: submission_top282_0.5889.csv, Differences: 147
# File: submission_top202_0.6201.csv, Differences: 102
# File: submission_top81_0.6352.csv, Differences: 52
# File: submission_top122_0.6301.csv, Differences: 70
# File: submission_top66_0.6368.csv, Differences: 95
# File: submission_top101_0.6334.csv, Differences: 54
# File: submission_top212_0.6182.csv, Differences: 152
# File: submission_top136_0.6279.csv, Differences: 60
# File: submission_top110_0.6315.csv, Differences: 68
# File: submission_top230_0.6154.csv, Differences: 91
#
# Top 20 files with smallest differences:
# 1. submission_top3_0.6478.csv: 42 differences
# 2. submission_top2_0.6487.csv: 42 differences
# 3. submission_top106_0.6322.csv: 44 differences
# 4. submission_top17_0.6438.csv: 44 differences
# 5. submission_top125_0.6296.csv: 44 differences
# 6. submission_top99_0.6334.csv: 44 differences
# 7. submission_top127_0.6289.csv: 45 differences
# 8. submission_top43_0.6392.csv: 45 differences
# 9. submission_top124_0.6296.csv: 46 differences
# 10. submission_top31_0.6417.csv: 47 differences
# 11. submission_top11_0.6461.csv: 47 differences
# 12. submission_top32_0.6417.csv: 47 differences
# 13. submission_top42_0.6392.csv: 48 differences
# 14. submission_top13_0.6451.csv: 48 differences
# 15. submission_top7_0.6465.csv: 48 differences
# 16. submission_top77_0.6354.csv: 49 differences
# 17. submission_top23_0.6432.csv: 49 differences
# 18. submission_top117_0.6308.csv: 49 differences
# 19. submission_top84_0.6348.csv: 49 differences
# 20. submission_top71_0.6359.csv: 49 differences
