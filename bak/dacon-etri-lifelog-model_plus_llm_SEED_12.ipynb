# %% [markdown]
# > title : 제 4회 ETRI 휴먼이해 인공지능 논문경진대회 <br>
# > author : hjy,byc <br>

# %% [markdown]
# ### 📦 라이브러리

# %%
! pip install haversine >/dev/null
! pip install optuna  >/dev/null
! pip install category_encoders >/dev/null
! pip install tabpfn  >/dev/null
! pip install catboost >/dev/null
! pip install torchmetrics >/dev/null

# %%
# 기본 모듈
import os
import sys
import re
import ast
import glob
import random
import warnings
from collections import Counter
from math import radians, cos, sin, asin, sqrt
from functools import reduce
from datetime import datetime, timedelta, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 머신러닝
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score
from sklearn.metrics import f1_score, roc_auc_score, roc_curve
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils.class_weight import compute_class_weight, compute_sample_weight
from category_encoders import TargetEncoder
from lightgbm import LGBMClassifier, log_evaluation, early_stopping
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import lightgbm as lgb
from tabpfn import TabPFNClassifier

# PyTorch
import torch
from torch import nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# Hugging Face
from huggingface_hub import login
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    LlamaTokenizer,
    LlamaForCausalLM,
    LlamaForSequenceClassification
)

# PEFT (Parameter-Efficient Fine-Tuning)
from peft import (
    LoraConfig,
    get_peft_model,
    get_peft_model_state_dict,
    TaskType
)

# Evaluation & Utilities
from torchmetrics import Accuracy

# 기타
from tqdm import tqdm
from tqdm.auto import tqdm as auto_tqdm  # 필요 시 구분
from scipy.stats import entropy
from haversine import haversine
from io import StringIO
import gc

# wandb
import wandb
wandb.login(key="5fa8dfb2c5be3c888bfe0101437a8fa22fbdf0e0")
wandb.init(project="etri_lifelog", entity="byc3230")

pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# 기타
warnings.filterwarnings('ignore')
# Out:
# 2025-06-15 03:46:41.430641: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749959201.618201      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749959201.670740      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: byc3230 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.9
# wandb: Run data is saved locally in /kaggle/working/wandb/run-20250615_034658-6l6ebl80
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run warm-snow-183
# wandb: ⭐️ View project at https://wandb.ai/byc3230/etri_lifelog
# wandb: 🚀 View run at https://wandb.ai/byc3230/etri_lifelog/runs/6l6ebl80

# %%
string = """
subject_id,sleep_date
id01,2024-07-24
id01,2024-08-26
id01,2024-08-28
id01,2024-08-29
id02,2024-08-23
id02,2024-09-24
id02,2024-09-26
id02,2024-09-27
id03,2024-08-30
id03,2024-09-01
id03,2024-09-02
id03,2024-09-06
id04,2024-09-03
id04,2024-10-10
id04,2024-10-12
id04,2024-10-13
id05,2024-10-19
id05,2024-10-23
id05,2024-10-24
id05,2024-10-27
id06,2024-07-25
id06,2024-07-26
id06,2024-07-27
id06,2024-07-30
id07,2024-07-07
id07,2024-08-02
id07,2024-08-04
id07,2024-08-05
id08,2024-08-28
id08,2024-08-29
id08,2024-08-30
id08,2024-09-02
id09,2024-08-02
id09,2024-08-31
id09,2024-09-02
id09,2024-09-03
id10,2024-08-28
id10,2024-08-30
id10,2024-08-31
id10,2024-09-03
"""

# DataFrame 생성
valid_ids = pd.read_csv(StringIO(string), sep=',')
valid_ids['pk'] = valid_ids['subject_id']+valid_ids['sleep_date']

# %% [markdown]
# ### 📦 데이터 읽기

# %%
# from google.colab import drive, files
# drive.mount('/content/drive')

# google path
#path = '/content/drive/MyDrive/data/ch2025_data_items/share/'

# kaggle path
path = '../input/'

# [1]공통
train = pd.read_parquet(f'{path}train_63775_v2.parquet')
test = pd.read_parquet(f'{path}test_63775_v2.parquet')

# [2]version2 train,test 데이터셋 by 현종열
# train = pd.read_parquet(f'{path}train_hjy_0603_v1.parquet')
# test = pd.read_parquet(f'{path}test_hjy_0603_v1.parquet')

# [3]QWEN3 8B 활용한 결측처리 (대상: mScreenStatus)
# mScreenStatus_llm = pd.read_excel(f'{path}mScreenStatus_llm결측값생성후파생변수생성_20250609_v1.xlsx')
# feats = ['sleep_time', 'wake_time', 'sleep_duration_min', 'avg_sleep_time', 'avg_wake_time', 'avg_sleep_duration', 'sleep_time_diff', 'wake_time_diff', 'sleep_duration_diff', 'sleep_time_ratio', 'wake_time_ratio', 'sleep_duration_ratio', 'sleep_time_lag1', 'wake_time_lag1', 'sleep_duration_lag1', 'sleep_time_diff_lag1', 'wake_time_diff_lag1', 'sleep_duration_diff_lag1', 'sleep_time_ratio_lag1', 'wake_time_ratio_lag1', 'sleep_duration_ratio_lag1', 'sleep_time_lag2', 'wake_time_lag2', 'sleep_duration_lag2', 'sleep_time_diff_lag2', 'wake_time_diff_lag2', 'sleep_duration_diff_lag2', 'sleep_time_ratio_lag2', 'wake_time_ratio_lag2', 'sleep_duration_ratio_lag2', 'sleep_time_mean2d', 'wake_time_mean2d', 'sleep_duration_min_mean2d', 'sleep_time_diff_mean2d', 'wake_time_diff_mean2d', 'sleep_duration_diff_mean2d', 'sleep_time_ratio_mean2d', 'wake_time_ratio_mean2d', 'sleep_duration_ratio_mean2d', 'sleep_time_std2d', 'wake_time_std2d', 'sleep_duration_min_std2d', 'sleep_time_diff_std2d', 'wake_time_diff_std2d', 'sleep_duration_diff_std2d', 'sleep_time_ratio_std2d', 'wake_time_ratio_std2d', 'sleep_duration_ratio_std2d', 'sleep_time_mean3d', 'wake_time_mean3d', 'sleep_duration_min_mean3d', 'sleep_time_diff_mean3d', 'wake_time_diff_mean3d', 'sleep_duration_diff_mean3d', 'sleep_time_ratio_mean3d', 'wake_time_ratio_mean3d', 'sleep_duration_ratio_mean3d', 'sleep_time_std3d', 'wake_time_std3d', 'sleep_duration_min_std3d', 'sleep_time_diff_std3d', 'wake_time_diff_std3d', 'sleep_duration_diff_std3d', 'sleep_time_ratio_std3d', 'wake_time_ratio_std3d', 'sleep_duration_ratio_std3d', 'sleep_time_mean5d', 'wake_time_mean5d', 'sleep_duration_min_mean5d', 'sleep_time_diff_mean5d', 'wake_time_diff_mean5d', 'sleep_duration_diff_mean5d', 'sleep_time_ratio_mean5d', 'wake_time_ratio_mean5d', 'sleep_duration_ratio_mean5d', 'sleep_time_std5d', 'wake_time_std5d', 'sleep_duration_min_std5d', 'sleep_time_diff_std5d', 'wake_time_diff_std5d', 'sleep_duration_diff_std5d', 'sleep_time_ratio_std5d', 'wake_time_ratio_std5d', 'sleep_duration_ratio_std5d', 'sleep_time_mean7d', 'wake_time_mean7d', 'sleep_duration_min_mean7d', 'sleep_time_diff_mean7d', 'wake_time_diff_mean7d', 'sleep_duration_diff_mean7d', 'sleep_time_ratio_mean7d', 'wake_time_ratio_mean7d', 'sleep_duration_ratio_mean7d', 'sleep_time_std7d', 'wake_time_std7d', 'sleep_duration_min_std7d', 'sleep_time_diff_std7d', 'wake_time_diff_std7d', 'sleep_duration_diff_std7d', 'sleep_time_ratio_std7d', 'wake_time_ratio_std7d', 'sleep_duration_ratio_std7d', 'weekday_avg_sleep', 'sleep_duration_weekday_avg_diff', 'sleep_duration_weekday_avg_div']
# drop_features = [i for i in feats if i in train.columns]
# train = train.drop(columns=drop_features)
# train = train.merge(mScreenStatus_llm,on=['subject_id','lifelog_date'],how='left')
# test = test.drop(columns=drop_features)
# test = test.merge(mScreenStatus_llm,on=['subject_id','lifelog_date'],how='left')

# check 
print('# train  shape:',train.shape)
print('# test   shape:',test.shape)
# Out:
# # train  shape: (450, 259)
# # test   shape: (250, 259)

# %%
# 숫자형 컬럼만 선택해서 결측값 -1로 채우기
train[train.select_dtypes(include='number').columns] = train.select_dtypes(include='number').fillna(-1)
test[test.select_dtypes(include='number').columns] = test.select_dtypes(include='number').fillna(-1)

# %% [markdown]
# # LLM 설정

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
llm_model_path = "Qwen/Qwen3-0.6B"

# %%
config = LoraConfig(
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],#Best
    #target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
    lora_dropout=0.1,
    bias="none",
    modules_to_save=["classifier"],
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
tokenizer = AutoTokenizer.from_pretrained(llm_model_path, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# tokenizer_config.json:   0%|          | 0.00/9.73k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %%
class CustomDataset(Dataset):
    def __init__(self, df):
        self.df = df

    def __len__(self):
        return len(self.df.index)

    def __getitem__(self, idx):
        return np.array([idx])

# %%
def train_iter(model, loader, optimizer, criterion, df_clean):
    model.train()
    
    total_loss = 0
    correct = 0
    pred = []
    label = []
    for batchIdx, sampledIdx in enumerate(tqdm(loader, position=0, leave=True)):
        #print(data)
        
        optimizer.zero_grad()
        
        #text
        sampledIdx = sampledIdx.cpu().data.numpy()
        sampledRowText = list(df_clean["text"].iloc[list(sampledIdx.flatten())])
        #label
        sampledRowLabels = torch.tensor(list(df_clean["label"].iloc[list(sampledIdx.flatten())])).to(device)
        
        #encoded
        encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to(device) # Output shape: [bs, num_Labels]
        encoded_inputIds = encoded_input["input_ids"].to(device)
        encoded_attnMask = encoded_input["attention_mask"].to(device)

        #model
        outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)
        #print(outputs)

        # label type change
        sampledRowLabels = sampledRowLabels.to(outputs.logits.device).long()  # shape: [1]
        #print(outputs.logits)
        # loss
        loss = criterion(outputs.logits, sampledRowLabels) 
        total_loss += loss.item()
        
        #acurracy
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
        predicted_class = torch.argmax(outputs.logits, dim=-1)
        pred.extend(predicted_class.flatten().cpu().data.numpy())
        label.extend(sampledRowLabels.cpu().data.numpy())     

        #back propagation
        loss.backward()
        optimizer.step()

    train_accuracy_score = metrics.f1_score(label,pred, average='macro')
    return total_loss / len(loader), train_accuracy_score

# %%
def valid_iter(model, valid_loader, criterion, df_clean):
    model.eval()
    with torch.no_grad():
        
        total_loss = 0
        correct = 0

        pred = []
        label = []

        for batchIdx, sampledIdx in enumerate(tqdm(valid_loader, position=0, leave=True)):
            
            sampledRowText = list(df_clean["text"].iloc[list(sampledIdx.flatten())])
            sampledRowLabels = torch.tensor(list(df_clean["label"].iloc[list(sampledIdx.flatten())]))

            encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to(device) # Output shape: [bs, num_Labels]
            encoded_inputIds = encoded_input["input_ids"].to(device)
            encoded_attnMask = encoded_input["attention_mask"].to(device)
            
            #model
            outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)
    
            # label type change
            sampledRowLabels = sampledRowLabels.to(outputs.logits.device).long()  # shape: [1]
            
            # loss
            loss = criterion(outputs.logits, sampledRowLabels) 
            total_loss += loss.item()
            
            #acurracy
            probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
            predicted_class = torch.argmax(outputs.logits, dim=-1)
            pred.extend(predicted_class.flatten().cpu().data.numpy())
            label.extend(sampledRowLabels.cpu().data.numpy())     

        valid_accuracy_score = metrics.f1_score(label,pred, average='macro')
    return total_loss/len(valid_loader), valid_accuracy_score

# %%
model_loading_path = "/kaggle/working/"

def inference(model, loader, test_data, col):
    #best model 불러와서 call 하기
    model.load_state_dict(torch.load(model_loading_path + col+"_"+best_model_path))
    model.eval()
    
    preds = []
    preds_prob = []
    with torch.no_grad():
        total_loss = 0
        correct = 0

        pred = []
        label = []
        
        for batchIdx, sampledIdx in enumerate(tqdm(loader, position=0, leave=True)):
            
            sampledRowText = list(test_data["text"].iloc[list(sampledIdx.flatten())])

            encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to("cuda") # Output shape: [bs, num_Labels]
            encoded_inputIds = encoded_input["input_ids"].to("cuda")
            encoded_attnMask = encoded_input["attention_mask"].to("cuda")
            
            outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)
            logits = outputs.logits


            #acurracy
            probs = torch.nn.functional.softmax(outputs.logits.cpu(), dim=-1)
            
            #확률구하기
            preds_prob.extend(probs.cpu().data.numpy())

            #acurracy
            pred.extend(torch.argmax(logits, dim=1).flatten().cpu().data.numpy())
            
    return pred, preds_prob

# %%
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha  # optional: list or tensor of class weights
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none', weight=self.alpha)
        pt = torch.exp(-ce_loss)  # prevents nans when probability is 0
        focal_loss = ((1 - pt) ** self.gamma) * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
# Define your training loop
epochs = 16
total_loss = 0
correct = 0

#best model 를 찾기 위한
best = np.inf

#3번까지 validation loss 터지면 stop 시킴
patience = 3

#best model save
#result_path = "/kaggle/working/"
#best_model_path = os.path.join(result_path, 'best_model.pt')
best_model_path = 'best_model.pt'
bad_counter = 0

# %%
# 피처 추가
X_Feature = {
    "Q1": ["Q1_te2", "wake_time_ratio", "mlight_first_wakeup_minutes", "wake_time_diff", "Q1_te", "lights_off_time", "sleep_duration_ratio", "active_hour_mean_speed", "beforebed_통화_time", "rolling_sleep_time_2d", "activehour_NAVER_time"],
    "Q2": ["Q2_te", "Q2_te2", "activehour_total_screen_time", "beforebed_unique_bssid_count", "wake_time_lag1", "light_rolling_wake_time_2d", "beforebed_max_rssi", "active_hour_std_hr", "beforebed_top_bssid_count", "activehour_screen_time_vs_avg_pct", "activehour_메신저_time"],
    "Q3": ["Q3_te2", "light_sleep_time_lag2", "mlight_first_wakeup_minutes", "rolling_sleep_time_3d", "light_rolling_sleep_duration_3d", "Q3_te", "beforebed_scan_count", "active_hour_distance_x", "activehour_통화_time", "walking_minutes"],
    "S1": ["S1_te", "wake_time_diff", "S1_te2", "sleep_duration_ratio", "m_activity_met@240min@sum@04h00m", "beforebed_screen_time_vs_avg_pct", "wake_time_ratio", "rolling_wake_time_3d", "m_activity_0@240min@std@20h00m", "m_activity@240min@std@12h00m", "beforebed_메신저_time", "sleep_duration_diff", "light_sleep_time_diff", "active_hour_min_hr"],
    "S2": ["S2_te2", "S2_te", "light_sleep_time_lag1", "work_hour_unknown_ratio", "m_activity@240min@std@12h00m", "beforebed_strong_signal_ratio", "light_rolling_wake_time_2d", "free_hour_rssi_mean", "activehour_전화_time", "sleep_hour_mean_speed","activehour_screen_time_vs_avg_pct","light_wake_time_diff_lag2","beforebed_max_rssi","avg_charging_duration","m_activity_met@240min@std@12h00m"],
    "S3": ["S3_te", "S3_te2", "beforebed_메신저_time", "light_wake_time_diff", "sleep_time_diff_lag1", "light_sleep_time_lag2", "m_activity_met@240min@sum@16h00m", "free_hour_rssi_max", "light_weekday_avg_sleep", "불끈시간부터기상시간","sleep_hour_distance_x","activehour_scan_count"]
}

# %%
X_Feature_alias = {
    "Q1": [
        "Q1_encoded_time_2",
        "wake_time_to_baseline_ratio",
        "minutes_to_first_wake_after_light",
        "wake_time_difference",
        "Q1_encoded_time",
        "lights_off_clock_time",
        "sleep_duration_ratio_to_guideline",
        "mean_speed_during_active_hours",
        "call_duration_before_bed",
        "sleep_time_rolling_avg_2d",
        "NAVER_time_active_hours"
    ],
    "Q2": [
        "Q2_encoded_time",
        "Q2_encoded_time_2",
        "total_screen_time_active_hours",
        "unique_wifi_count_before_bed",
        "previous_day_wake_time",
        "light_based_wake_time_rolling_avg_2d",
        "max_wifi_signal_before_bed",
        "std_heart_rate_active_hours",
        "frequent_wifi_count_before_bed",
        "screen_time_vs_avg_pct_active_hours",
        "messenger_usage_time_active_hours"
    ],
    "Q3": [
        "Q3_encoded_time_2",
        "light_sleep_duration_lag2",
        "minutes_to_first_wake_after_light",
        "sleep_time_rolling_avg_3d",
        "light_based_sleep_duration_rolling_avg_3d",
        "Q3_encoded_time",
        "wifi_scan_count_before_bed",
        "distance_traveled_active_hours",
        "call_duration_active_hours",
        "total_walking_minutes"
    ],
    "S1": [
        "S1_encoded_time",
        "wake_time_difference",
        "S1_encoded_time_2",
        "sleep_duration_ratio_to_guideline",
        "met_sum_0to4am",
        "screen_time_vs_avg_pct_before_bed",
        "wake_time_to_baseline_ratio",
        "wake_time_rolling_avg_3d",
        "activity_std_8pm_to_midnight",
        "activity_std_12pm_to_4pm"
        "messenger_usage_time_before_bed",
        "sleep_time_difference",
        "light_based_sleep_time_difference",
        "activity_time_mininum_hours"
        
    ],
    "S2": [
        "S2_encoded_time_2",
        "S2_encoded_time",
        "light_sleep_duration_lag1",
        "unknown_activity_ratio_work_hours",
        "activity_std_12pm_to_4pm",
        "strong_wifi_signal_ratio_before_bed",
        "light_based_wake_time_rolling_avg_2d",
        "avg_wifi_signal_strength_free_hours",
        "phone_call_time_active_hours",
        "mean_movement_speed_sleep_hours",
        "activity_time_screen_hour_vs_avg_pct","light_wake_time_diff_lag2","beforebed_max_rssi","avg_charging_duration","m_activity_met@240min@std@12h00m"
    ],
    "S3": [
        "S3_encoded_time",
        "S3_encoded_time_2",
        "messenger_usage_time_before_bed",
        "light_based_wake_time_difference",
        "sleep_time_difference_lag1",
        "light_sleep_duration_lag2",
        "met_sum_4pm_to_8pm",
        "max_wifi_signal_strength_free_hours",
        "light_based_weekday_avg_sleep_duration",
        "time_from_first_movement_to_final_wake",
        "sleep_hour_distance_x","active_hour_scan_count"
    ]
}

# %%
Prompt = {
    "Q1": "Based on the following sleep-related information, classify the overall perceived sleep quality upon waking as either below or above the individual’s average. (0: Below average, 1: Above average) ",
    "Q2": "Using the following data, determine the level of physical fatigue the individual felt before sleep. (0: High fatigue, 1: Low fatigue) ",
    "Q3": "Based on the information below, classify the stress level the individual experienced before going to bed. (0: High stress, 1: Low stress) ",
    "S1": "Based on the provided information, classify how well the individual's total sleep time (TST) aligns with recommended sleep guidelines. (0: Not met, 1: Partially met, 2: Fully met) ",
    "S2": "Using the following indicators, determine whether the individual met the guideline for sleep efficiency (SE). (0: Not met, 1: Met) ",
    "S3": "From the data provided, assess if the sleep onset latency (SOL) guideline was met. (0: Not met, 1: Met) "
}

# %% [markdown]
# # 재현성 확보를 위한 시드 고정

# %%
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
os.environ["TOKENIZERS_PARALLELISM"] = "false"
os.environ["OMP_NUM_THREADS"] = "1"

# %%
# https://github.com/huggingface/transformers/blob/f4fc42216cd56ab6b68270bf80d811614d8d59e4/src/transformers/trainer_utils.py#L93
def enable_full_determinism(seed: int, warn_only: bool = True):
    """
    Helper function for reproducible behavior during distributed training. See
    - https://pytorch.org/docs/stable/notes/randomness.html for pytorch
    - https://www.tensorflow.org/api_docs/python/tf/config/experimental/enable_op_determinism for tensorflow
    """

    os.environ["PYTHONHASHSEED"] = str(seed)
    # set seed first
    set_seed(seed)

    # Enable PyTorch deterministic mode. This potentially requires either the environment
    # variable 'CUDA_LAUNCH_BLOCKING' or 'CUBLAS_WORKSPACE_CONFIG' to be set,
    # depending on the CUDA version, so we set them both here
    os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
    os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":16:8"
    # The environment variable required to enable deterministic mode on Ascend NPUs.
    os.environ["ASCEND_LAUNCH_BLOCKING"] = "1"
    os.environ["HCCL_DETERMINISTIC"] = "1"

    os.environ["FLASH_ATTENTION_DETERMINISTIC"] = "1"
    torch.use_deterministic_algorithms(True, warn_only=warn_only)

    # Enable CUDNN deterministic mode
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


def set_seed(seed: int, deterministic: bool = True):
    """
    Helper function for reproducible behavior to set the seed in `random`, `numpy`, `torch` and/or `tf` (if installed).

    Args:
        seed (`int`):
            The seed to set.
        deterministic (`bool`, *optional*, defaults to `False`):
            Whether to use deterministic algorithms where available. Can slow down training.
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    if deterministic:
        torch.use_deterministic_algorithms(True)

# %%
SEED = 12 #Best
enable_full_determinism(SEED)  # 42는 원하는 시드값

# %%
generator = torch.Generator()
generator.manual_seed(SEED)  # 시드 고정

# %% [markdown]
# ### ============================

# %% [markdown]
# ### run_basemodel

# %%
#epochs = 1
def run_basemodel(train, test, valid_ids, common_params, n_splits, random_state=42):

    lgb_A = 0.3
    xgb_B = 0.3
    tab_C = 0.1
    llm_D = 0.3

    train_df = train.copy()
    test_df = test.copy()

    submission_final = test_df[['subject_id', 'sleep_date', 'lifelog_date']].copy()
    submission_final['lifelog_date'] = pd.to_datetime(submission_final['lifelog_date']).dt.date

    # 타겟
    targets_binary = ['Q1', 'Q2', 'Q3', 'S2', 'S3']
    targets_binary_name = ['기상직후수면질','취침전신체적피로','취침전스트레스','수면효율','수면잠들기시간']
    target_multiclass = 'S1'
    all_targets = targets_binary + [target_multiclass]

    # 노이즈 수준 설정
    def add_noise(series, noise_level, seed=3):
        rng = np.random.default_rng(seed)
        return series * (1 + noise_level * rng.standard_normal(len(series)))

    noise_level = 0.015  # 필요에 따라 조정

    # 타겟인코딩
    for tgt in all_targets:

      encoder_feats = ['subject_id','month','weekend'] # 'weekday', 'subject_id','month','weekend'

      #### 타겟인코딩1

      subject_mean = train_df.groupby(encoder_feats)[tgt].mean().rename(f'{tgt}_te')
      train_df = train_df.merge(subject_mean, on=encoder_feats, how='left')
      test_df = test_df.merge(subject_mean, on=encoder_feats, how='left')
      global_mean = train_df[tgt].mean()
      test_df[f'{tgt}_te'] = test_df[f'{tgt}_te'].fillna(global_mean)

      # 노이즈 추가
      train_df[f'{tgt}_te'] = add_noise(train_df[f'{tgt}_te'], noise_level)
      test_df[f'{tgt}_te'] = add_noise(test_df[f'{tgt}_te'], noise_level)

      #### 타겟인코딩2

      # 새로운 범주형 열 생성
      train_df['TMP'] = train_df[encoder_feats].applymap(str).apply(lambda x: ''.join(x) ,axis=1)
      test_df['TMP'] = test_df[encoder_feats].applymap(str).apply(lambda x: ''.join(x) ,axis=1)

      # 인코더
      encoder = TargetEncoder(cols=['TMP'], smoothing=300) # 40
      encoder.fit(train_df[['TMP']], train_df[tgt])

      # 인코딩 결과를 새로운 열에 저장
      train_df[f'{tgt}_te2'] = encoder.transform(train_df[['TMP']])
      test_df[f'{tgt}_te2'] = encoder.transform(test_df[['TMP']])

      # 노이즈 추가
      train_df[f'{tgt}_te2'] = add_noise(train_df[f'{tgt}_te2'], noise_level)
      test_df[f'{tgt}_te2'] = add_noise(test_df[f'{tgt}_te2'], noise_level)

      # 불필요한 변수 제거
      train_df = train_df.drop(columns=['TMP'])
      test_df = test_df.drop(columns=['TMP'])


    # 인코딩
    PK = ['sleep_date', 'lifelog_date', 'subject_id']
    encoder = LabelEncoder()
    categorical_features = [i for i in train_df.select_dtypes(include=['object', 'category']).columns if i not in PK+['pk']]
    for col in categorical_features:
        print(col)
        train_df[col] = encoder.fit_transform(train_df[col])
        test_df[col] = encoder.fit_transform(test_df[col])

    # X
    X = train_df.drop(columns=PK + all_targets)
    test_X = test_df.drop(columns=PK + all_targets)
    print(f'# X shape: {X.shape}')
    print(f'# test_X shape: {test_X.shape}')

    print('\n STEP1: 실험 결과 확인')
    print("=============== Validation Results ==============")
    total_avg_f1s = []
    val_f1 = []
    binary_val_preds = {}
    multiclass_val_preds = {}
    binary_test_preds = {}
    multiclass_test_preds = {}
    test_preds = {}

    # Find optimal weights
    best_weights = []
    best_scores = []


    for col in targets_binary:
        # binary
        y = train_df[col]

        valid_ids['pk'] = valid_ids['subject_id']+valid_ids['sleep_date']
        train_df['pk'] = train_df['subject_id']+train_df['sleep_date']

        X_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
        X_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
        y_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()
        y_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()

        def prepare_input_text(row):
            target_cols = ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']
            feature_cols = [col for col in X_Feature[col] if col not in target_cols]

            # 프롬프트 시작 문장에 결측치 설명 추가
            base_prompt = Prompt["S1"] if is_multiclass else Prompt[col]
            instruct_txt = base_prompt.strip() + "\n(Note: -1.0 indicates missing value in the data)\n###DATA###\n"
  
            if is_multiclass:
                for orig_name, alias_name in zip(X_Feature["S1"], X_Feature_alias["S1"]):
                    if orig_name not in target_cols:
                        instruct_txt += f"{alias_name} : {row[orig_name]}, "
            else:
                for orig_name, alias_name in zip(X_Feature[col], X_Feature_alias[col]):
                    if orig_name not in target_cols:
                        instruct_txt += f"{alias_name} : {row[orig_name]}, "
                
            return instruct_txt.strip()[:-1]+'.' 


        ######## llm train start #########
        is_multiclass = False
        llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=2, torch_dtype=torch.float16, device_map='auto')
        lora_model = get_peft_model(llm_model, config)
        
        optimizer = torch.optim.AdamW(llm_model.parameters(), lr=3e-4, weight_decay=1e-4)
        #optimizer = torch.optim.AdamW(llm_model.parameters(), lr=1e-5, weight_decay=1e-4)
        # alpha = torch.tensor([1.048, 0.670, 1.807], dtype=torch.float16, device=device)
        # criterion = FocalLoss(gamma=2.0,alpha=alpha)
        criterion = FocalLoss(gamma=2.0)
    
        # Add learning rate scheduler
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=0.5,
            patience=2,
            verbose=True,
            min_lr=1e-6
        )
        
        total_loss = 0
        correct = 0
        bad_counter = 0
        
        #best model 를 찾기 위한
        best = np.inf
    
        X_train_llm = X_train.copy()
        X_valid_llm = X_valid.copy()
    
        # X_train_llm = X_train_llm[:15][X_Feature[col]]
        # print(X_train_llm.head(1))
        # X_valid_llm = X_valid_llm[:15][X_Feature[col]]
        # print(X_valid_llm.head(1))
    
        X_train_llm = X_train_llm[X_Feature[col]]
        X_valid_llm = X_valid_llm[X_Feature[col]]
    
        X_train_llm['input'] = X_train_llm.apply(lambda x: prepare_input_text(x),axis=1)
        #print(X_train_llm.head(1))
        X_valid_llm['input'] = X_valid_llm.apply(lambda x: prepare_input_text(x),axis=1)
        
        # X_train_llm["label"] = y_train[:15]
        # X_valid_llm["label"] = y_valid[:15]
        X_train_llm["label"] = y_train
        X_valid_llm["label"] = y_valid
        X_train_llm["text"] = X_train_llm["input"]
        X_valid_llm["text"] = X_valid_llm["input"]
                
        training_data = CustomDataset(X_train_llm)
        validation_data = CustomDataset(X_valid_llm)
        
        #train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True,worker_init_fn=seed_worker, generator=g)
        #train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True)
        train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True,generator=generator)
        val_dataloader = DataLoader(validation_data, batch_size=1, shuffle=False)
        
    
        X_train_llm_clean = X_train_llm
        X_valid_llm_clean = X_valid_llm
    
        
        for epoch in range(epochs):
            avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, X_train_llm_clean)
            
            avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, X_valid_llm_clean)
    
            # Update learning rate based on validation loss
            scheduler.step(avg_vaild_loss)
            
            if avg_vaild_loss < best:
                best = avg_vaild_loss
                torch.save(llm_model.cpu().state_dict(), col+"_" + best_model_path)
                llm_model.cuda()
                bad_counter = 0
            else:
                bad_counter += 1
        
            if bad_counter == patience:
                break
            
            print(f'{col} Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')
            
            wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})
            
            # ✅ 메모리 정리
            del avg_train_loss, avg_train_acc, avg_vaild_loss, avg_vaild_acc
            gc.collect()
            torch.cuda.empty_cache()         
        ######## llm train end #################

        # Get parameters for both models
        lgb_params = common_params[col].copy()
        lgb_params['random_state'] = random_state

        xgb_params = {
            'n_estimators': 1000,
            'learning_rate': 0.01,
            'max_depth': 6,
            'min_child_weight': 1,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': random_state
        }

        # Train LightGBM
        lgb_model = LGBMClassifier(**lgb_params)
        lgb_model.fit(X_train, y_train)

        # Train XGBoost
        xgb_model = XGBClassifier(**xgb_params)
        xgb_model.fit(X_train, y_train)

        tabpfn_params = {
            'device': 'cuda'
        }

        # Train TabPFN
        tabpfn_model = TabPFNClassifier(**tabpfn_params)
        tabpfn_model.fit(X_train, y_train)

        # Prediction
        tab_pred_valid = tabpfn_model.predict_proba(X_valid.values)[:, 1]
        lgb_pred_valid = lgb_model.predict_proba(X_valid)[:, 1]
        xgb_pred_valid = xgb_model.predict_proba(X_valid)[:, 1]
        _, llm_pred_valid = inference(llm_model, val_dataloader, X_valid_llm, col)
        llm_pred_valid = np.array([arr[1] for arr in llm_pred_valid], dtype=np.float32)

        pred_valid = (lgb_A * lgb_pred_valid + xgb_B * xgb_pred_valid + tab_C * tab_pred_valid + llm_D * llm_pred_valid  > 0.5).astype(int)

        f1 = f1_score(y_valid, pred_valid, average='macro')
        val_f1.append(f1)

        # Store predictions
        binary_val_preds[col] = {
            'lgb': lgb_pred_valid,
            'xgb': xgb_pred_valid,
            'tab': tab_pred_valid,
            'llm': llm_pred_valid,
            'true': y_valid
        }

    # multiclass
    y = train_df[target_multiclass]
    X_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
    X_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
    y_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()
    y_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()


    ######## llm train start #################
    is_multiclass = True
    llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=3, torch_dtype=torch.float16, device_map='auto')
    lora_model = get_peft_model(llm_model, config)
    
    optimizer = torch.optim.AdamW(llm_model.parameters(), lr=3e-4, weight_decay=1e-4)
    #optimizer = torch.optim.AdamW(llm_model.parameters(), lr=1e-5, weight_decay=1e-4)
    # alpha = torch.tensor([1.048, 0.670, 1.807], dtype=torch.float16, device=device)
    # criterion = FocalLoss(gamma=2.0,alpha=alpha)
    criterion = FocalLoss(gamma=2.0)

    # Add learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=2,
        verbose=True,
        min_lr=1e-6
    )
    
    total_loss = 0
    correct = 0
    bad_counter = 0
    
    #best model 를 찾기 위한
    best = np.inf

    X_train_llm = X_train.copy()
    X_valid_llm = X_valid.copy()

    # X_train_llm = X_train_llm[:15][X_Feature[col]]
    # print(X_train_llm.head(1))
    # X_valid_llm = X_valid_llm[:15][X_Feature[col]]
    # print(X_valid_llm.head(1))

    X_train_llm = X_train_llm[X_Feature["S1"]]
    X_valid_llm = X_valid_llm[X_Feature["S1"]]

    X_train_llm['input'] = X_train_llm.apply(lambda x: prepare_input_text(x),axis=1)
    #print(X_train_llm.head(1))
    X_valid_llm['input'] = X_valid_llm.apply(lambda x: prepare_input_text(x),axis=1)
    
    # X_train_llm["label"] = y_train[:15]
    # X_valid_llm["label"] = y_valid[:15]
    X_train_llm["label"] = y_train
    X_valid_llm["label"] = y_valid
    X_train_llm["text"] = X_train_llm["input"]
    X_valid_llm["text"] = X_valid_llm["input"]
            
    training_data = CustomDataset(X_train_llm)
    validation_data = CustomDataset(X_valid_llm)
    
    train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True,generator=generator)
    val_dataloader = DataLoader(validation_data, batch_size=1, shuffle=False)

    X_train_llm_clean = X_train_llm
    X_valid_llm_clean = X_valid_llm

    
    for epoch in range(epochs):
        avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, X_train_llm_clean)
        
        avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, X_valid_llm_clean)

        # Update learning rate based on validation loss
        scheduler.step(avg_vaild_loss)
        
        if avg_vaild_loss < best:
            best = avg_vaild_loss
            torch.save(llm_model.cpu().state_dict(), "S1_" + best_model_path)
            llm_model.cuda()
            bad_counter = 0
        else:
            bad_counter += 1
    
        if bad_counter == patience:
            break
        
        print(f'S1 Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')
        
        wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})
        
        # ✅ 메모리 정리
        del avg_train_loss, avg_train_acc, avg_vaild_loss, avg_vaild_acc
        gc.collect()
        torch.cuda.empty_cache()         
    ######## llm train end #################

    # Get parameters for both models
    lgb_params = common_params['S1'].copy()
    lgb_params['random_state'] = random_state

    xgb_params = {
        'n_estimators': 1000,
        'learning_rate': 0.01,
        'max_depth': 6,
        'min_child_weight': 1,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'random_state': random_state
    }

    # 클래스 weight 계산
    classes = np.unique(y_train)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
    class_weights = dict(zip(classes, weights))

    # 각 샘플에 대해 weight 매핑
    w_train = pd.Series(y_train).map(class_weights)
    w_train = compute_sample_weight(class_weight='balanced', y=y_train)

    # Train LightGBM
    lgb_model = LGBMClassifier(**lgb_params, objective='multiclass', num_class=3)
    lgb_model.fit(X_train, y_train, sample_weight=w_train)

    # Train XGBoost
    xgb_model = XGBClassifier(**xgb_params, objective='multi:softmax', num_class=3)
    xgb_model.fit(X_train, y_train,sample_weight=w_train)

    tabpfn_params = {
        'device': 'cuda'
    }

    # Train TabPFN
    tabpfn_model = TabPFNClassifier(**tabpfn_params)
    tabpfn_model.fit(X_train, y_train)

    # Get predictions and ensemble
    _, llm_pred_valid = inference(llm_model, val_dataloader, X_valid_llm, "S1")
    lgb_pred_valid = lgb_model.predict_proba(X_valid)
    xgb_pred_valid = xgb_model.predict_proba(X_valid)
    tab_pred_valid = tabpfn_model.predict_proba(X_valid.values)
    llm_pred_valid = np.array(llm_pred_valid, dtype=np.float32)


    pred_valid = np.argmax(lgb_A * lgb_pred_valid + xgb_B * xgb_pred_valid + tab_C * tab_pred_valid + llm_D * llm_pred_valid, axis=1)

    f1 = f1_score(y_valid, pred_valid, average='macro')
    val_f1.append(f1)

    multiclass_val_preds = {
        'lgb': lgb_pred_valid,
        'xgb': xgb_pred_valid,
        'tab': tab_pred_valid,
        'llm': llm_pred_valid,
        'true': y_valid
    }

    # Generate all possible weight combinations that sum to 1
    step = 0.1
    for lgb_A in np.arange(0, 1.1, step):
        for xgb_B in np.arange(0, 1.1 - lgb_A, step):
            for tab_C in np.arange(0, 1.1 - lgb_A - xgb_B, step):
                llm_D = 1 - (lgb_A + xgb_B + tab_C)
                if llm_D >= 0:
                    weights = (lgb_A, xgb_B, tab_C, llm_D)
                    print("========================================")
                    print(f"\nTrying weights: lgb_A={lgb_A:.1f}, xgb_B={xgb_B:.1f}, tab_C={tab_C:.1f}, llm_D={llm_D:.1f}")
                    
                    # Calculate validation score with current weights
                    val_scores = []
                    
                    # Binary targets
                    for col in targets_binary:
                        preds = binary_val_preds[col]
                        
                        ensemble_pred = (lgb_A * preds['lgb'] + xgb_B * preds['xgb'] + 
                                      tab_C * preds['tab'] + llm_D * preds['llm'] > 0.5).astype(int)
                        f1 = f1_score(preds['true'], ensemble_pred, average='macro')
                        val_scores.append(f1)
                        print(f" Validation Score {col}:{f1:.4f}")
                        
                    # Multiclass target
                    preds = multiclass_val_preds
                    ensemble_pred = np.argmax(lgb_A * preds['lgb'] + xgb_B * preds['xgb'] + 
                                           tab_C * preds['tab'] + llm_D * preds['llm'], axis=1)
                    f1 = f1_score(preds['true'], ensemble_pred, average='macro')
                    print(f" Validation Score S1:{f1:.4f}")
                    val_scores.append(f1)
                    
                    avg_score = np.mean(val_scores)
                    best_weights.append(weights)
                    best_scores.append(avg_score)
                    
                    print(f"Average Validation Score: {avg_score:.4f}")

    # Sort results and get all
    sorted_indices = np.argsort(best_scores)[::-1]
    all_weights = [best_weights[i] for i in sorted_indices]
    all_scores = [best_scores[i] for i in sorted_indices]

    print("\nTop All Weight Combinations:")
    for i, (weights, score) in enumerate(zip(all_weights, all_scores)):
        print(f"Rank {i+1}: lgb_A={weights[0]:.1f}, xgb_B={weights[1]:.1f}, tab_C={weights[2]:.1f}, llm_D={weights[3]:.1f} - Score: {score:.4f}")

    avg_f1 = np.mean(val_f1)
    total_avg_f1s.append(avg_f1)
    detail = " ".join([f"{name}({tname}):{score:.4f}" for name, tname, score in zip(targets_binary + [target_multiclass], targets_binary_name + ['S1'], val_f1)])
          
    print(f" 평균 F1: {avg_f1:.4f} / [상세] {detail}")
    print(f"# 전체 평균 F1: {np.mean(total_avg_f1s):.4f}")
    print("================================================")

    # ------------------------------------------ modeling with 100% train & no valid --------------------------------------------------------------------
    
    print('\n STEP2: 전체 데이터로 모델 재학습')
    print("====== modeling with 100% train & no valid =====")

    # binary
    binary_preds = {}
    binary_preds_proba = {}
    for col in targets_binary:
        # Get parameters for both models
        lgb_params = common_params[col].copy()
        lgb_params['random_state'] = random_state

        xgb_params = {
            'n_estimators': 1000,
            'learning_rate': 0.01,
            'max_depth': 6,
            'min_child_weight': 1,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': random_state
        }

        y = train_df[col]

        is_multiclass = False

        # LLM Valid Model load and Inference
        test_X_llm = test_X.copy()
        test_X_llm = test_X_llm[X_Feature[col]]
        test_X_llm['input'] = test_X_llm.apply(lambda x: prepare_input_text(x),axis=1)
        test_X_llm["text"] = test_X_llm["input"]
        test_data = CustomDataset(test_X_llm)
        test_dataloader = DataLoader(test_data, batch_size=1, shuffle=False)
        
        llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=2, torch_dtype=torch.float16, device_map='auto')
        lora_model = get_peft_model(llm_model, config)
        _, llm_pred = inference(llm_model, test_dataloader, test_X_llm, col)
        llm_pred = np.array([arr[1] for arr in llm_pred], dtype=np.float32)    
    
        # Train LightGBM
        lgb_model = LGBMClassifier(**lgb_params)
        lgb_model.fit(X, y)

        # Train XGBoost
        xgb_model = XGBClassifier(**xgb_params)
        xgb_model.fit(X, y)

        tabpfn_params = {
            'device': 'cuda'
        }

        # Train TabPFN
        tabpfn_model = TabPFNClassifier(**tabpfn_params)
        tabpfn_model.fit(X, y)

        tab_pred = tabpfn_model.predict_proba(test_X)[:, 1]
        lgb_pred = lgb_model.predict_proba(test_X)[:, 1]
        xgb_pred = xgb_model.predict_proba(test_X)[:, 1]

        binary_preds[col] = (lgb_A * lgb_pred + xgb_B * xgb_pred + tab_C * tab_pred + llm_D * llm_pred > 0.5).astype(int)

        # Store predictions
        binary_test_preds[col] = {
            'lgb': lgb_pred,
            'xgb': xgb_pred,
            'tab': tab_pred,
            'llm': llm_pred,
        }

        # Feature importance (using LightGBM's importance)
        fi_df = pd.DataFrame({'feature': X.columns, 'importance': lgb_model.feature_importances_})
        top10 = fi_df.sort_values(by='importance', ascending=False).head(10)
        feat_str = ", ".join([f"{row['feature']}({int(row['importance'])})" for _, row in top10.iterrows()])
        print(f"[{col}] {feat_str}")

    # multiclass
    y = train_df['S1']

    # Get parameters for both models
    lgb_params = common_params['S1'].copy()
    lgb_params['random_state'] = random_state

    xgb_params = {
        'n_estimators': 1000,
        'learning_rate': 0.01,
        'max_depth': 6,
        'min_child_weight': 1,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'random_state': random_state
    }

    # 클래스 weight 계산
    classes = np.unique(y)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y)
    class_weights = dict(zip(classes, weights))

    # 각 샘플에 대해 weight 매핑
    w_train = pd.Series(y).map(class_weights)
    w_train = compute_sample_weight(class_weight='balanced', y=y)

    is_multiclass = True
    
     # LLM Valid Model load and Inference
    test_X_llm = test_X.copy()
    test_X_llm = test_X_llm[X_Feature["S1"]]
    test_X_llm['input'] = test_X_llm.apply(lambda x: prepare_input_text(x),axis=1)
    test_X_llm["text"] = test_X_llm["input"]
    test_data = CustomDataset(test_X_llm)
    test_dataloader = DataLoader(test_data, batch_size=1, shuffle=False)

    llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=3, torch_dtype=torch.float16, device_map='auto')
    lora_model = get_peft_model(llm_model, config)
    _, llm_pred = inference(llm_model, test_dataloader, test_X_llm, "S1")
    llm_pred = np.array(llm_pred, dtype=np.float32)
    
    # Train LightGBM
    lgb_model = LGBMClassifier(**lgb_params, objective='multiclass', num_class=3)
    lgb_model.fit(X, y, sample_weight=w_train)

    # Train XGBoost
    xgb_model = XGBClassifier(**xgb_params, objective='multi:softmax', num_class=3)
    xgb_model.fit(X, y, sample_weight=w_train)

    tabpfn_params = {
        'device': 'cuda'
    }

     # Train TabPFN
    tabpfn_model = TabPFNClassifier(**tabpfn_params)
    tabpfn_model.fit(X, y)

    # Get predictions and ensemble
    lgb_pred = lgb_model.predict_proba(test_X)
    xgb_pred = xgb_model.predict_proba(test_X)
    tab_pred = tabpfn_model.predict_proba(test_X)

    multiclass_test_preds = {
        'lgb': lgb_pred,
        'xgb': xgb_pred,
        'tab': tab_pred,
        'llm': llm_pred,
    }

    multiclass_pred = np.argmax(lgb_A * lgb_pred + xgb_B * xgb_pred + tab_C * tab_pred + llm_D * llm_pred, axis=1)
    multiclass_pred_proba = lgb_A * lgb_pred + xgb_B * xgb_pred + tab_C * tab_pred + + llm_D * llm_pred
    
    # Feature importance
    fi_df = pd.DataFrame({'feature': X.columns, 'importance': lgb_model.feature_importances_})
    top10 = fi_df.sort_values(by='importance', ascending=False).head(10)
    feat_str = ", ".join([f"{row['feature']}({int(row['importance'])})" for _, row in top10.iterrows()])
    print(f"[S1] {feat_str}")
    
    # 예측 저장
    submission_final['S1'] = multiclass_pred
    for col in targets_binary:
      submission_final[col] = binary_preds[col]
    submission_final = submission_final[['subject_id', 'sleep_date', 'lifelog_date', 'Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']]
    fname = f"submission_{np.mean(total_avg_f1s)}.csv"
    submission_final.to_csv(fname, index=False)
    print(f"# {fname} 저장 완료")
    print(f"# submission shape:{submission_final.shape}")
    print("================================================")
    
    # ---------------------------------------- all Weight Combinations ----------------------------------------
    
    submission_final_dict = {}
    print("\nAll Weight Combinations:")
    for i, (weights, score) in enumerate(zip(all_weights, all_scores)):
    
        print(f"Rank {i+1}: lgb_A={weights[0]:.1f}, xgb_B={weights[1]:.1f}, tab_C={weights[2]:.1f}, llm_D={weights[3]:.1f} - Score: {score:.4f}")
        
        # Generate submission with these weights
        lgb_A, xgb_B, tab_C, llm_D = weights
        
        # Binary predictions
        for col in targets_binary:
            preds = binary_test_preds[col]
            ensemble_pred = (lgb_A * preds['lgb'] + xgb_B * preds['xgb'] + 
                          tab_C * preds['tab'] + llm_D * preds['llm'] > 0.5).astype(int)
            submission_final[col] = ensemble_pred
        
        # Multiclass prediction
        preds = multiclass_test_preds
        ensemble_pred = np.argmax(lgb_A * preds['lgb'] + xgb_B * preds['xgb'] + 
                               tab_C * preds['tab'] + llm_D * preds['llm'], axis=1)
        submission_final['S1'] = ensemble_pred
        
        # 저장 
        submission_final_dict[i] = submission_final.copy()
        fname = f"submission_top{i+1}_{score:.4f}.csv"
        submission_final_dict[i].to_csv(fname, index=False)
        print(f"Saved submission to {fname}")

    # Use the best weights for final submission
    best_weights = all_weights[0]
    lgb_A, xgb_B, cat_C, llm_D = best_weights
    
    
    
    # 모델별 예측결과 비율 비교
    a11 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].sum()
    a13 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].apply(len)
    a12 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].mean()
    a21 = submission_final_dict[0][['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].sum()
    a23 = submission_final_dict[0][['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].apply(len)
    a22 = submission_final_dict[0][['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].mean()
    result = pd.concat([a11, a13, a12, a21, a23, a22], axis=1)
    result.columns = ['학습sum','학습len','학습mean','테스트sum','테스트len','테스트mean']
    print('\n STEP3: 예측결과 비교표')
    display(result)
    
    oof_result = []
    
    return submission_final_dict[0], oof_result

# %% [markdown]
# ### ============================

# %% [markdown]
# ### 📦 모델 학습

# %%
# %%time

# 공통 하이퍼파라미터
common_params = {
  'n_estimators': 5000,
  "learning_rate": 0.01,
  # 'min_data_in_leaf':2,
  # 'bagging_fraction':0.9,
  # 'feature_fraction':0.6,
  'lambda_l1': 5,
  'lambda_l2': 1,
  # 'max_depth': 4,
  'n_jobs': -1,
  'verbosity': -1
}

# 모델별 세부 하이퍼파라미터
best_param_dict = {}
best_param_dict['Q3'] = common_params
best_param_dict['S1'] = common_params
best_param_dict['S2'] = common_params
best_param_dict['S3'] = common_params
best_param_dict['Q1'] = common_params
best_param_dict['Q2'] = common_params

submission_final, oof_result = run_basemodel(train, test, valid_ids, best_param_dict, n_splits=5, random_state=41)
# Out:
# light_week_type_lag1
# weekday
# week_type
# week_type_lag1
# activehour_top_bssid
# beforebed_top_bssid
# # X shape: (450, 262)
# # test_X shape: (250, 262)
#
#  STEP1: 실험 결과 확인
# =============== Validation Results ==============
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [03:24<00:00,  2.00it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.81it/s]
# Q1 Epoch: 1: t_loss:0.270 t_acc:0.494 v_loss:0.158 v_acc:0.498
# 100%|██████████| 410/410 [03:25<00:00,  1.99it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.72it/s]
# Q1 Epoch: 2: t_loss:0.172 t_acc:0.579 v_loss:0.227 v_acc:0.413
# 100%|██████████| 410/410 [03:25<00:00,  2.00it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.78it/s]
# Q1 Epoch: 3: t_loss:0.156 t_acc:0.680 v_loss:0.146 v_acc:0.603
# 100%|██████████| 410/410 [03:25<00:00,  2.00it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.86it/s]
# Q1 Epoch: 4: t_loss:0.144 t_acc:0.734 v_loss:0.139 v_acc:0.763
# 100%|██████████| 410/410 [03:24<00:00,  2.00it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.81it/s]
# Q1 Epoch: 5: t_loss:0.141 t_acc:0.743 v_loss:0.203 v_acc:0.600
# 100%|██████████| 410/410 [03:26<00:00,  1.99it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.73it/s]
# Q1 Epoch: 6: t_loss:0.158 t_acc:0.700 v_loss:0.174 v_acc:0.486
# 100%|██████████| 410/410 [03:28<00:00,  1.97it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.73it/s]
# Q1 Epoch: 7: t_loss:0.135 t_acc:0.758 v_loss:0.138 v_acc:0.697
# 100%|██████████| 410/410 [03:27<00:00,  1.97it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.69it/s]
# Q1 Epoch: 8: t_loss:0.149 t_acc:0.727 v_loss:0.149 v_acc:0.613
# 100%|██████████| 410/410 [03:27<00:00,  1.98it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.83it/s]
# Q1 Epoch: 9: t_loss:0.119 t_acc:0.788 v_loss:0.162 v_acc:0.675
# 100%|██████████| 410/410 [03:25<00:00,  2.00it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.81it/s]
# tabpfn-v2-classifier.ckpt:   0%|          | 0.00/29.0M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/37.0 [00:00<?, ?B/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.81it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [03:08<00:00,  2.17it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.90it/s]
# Q2 Epoch: 1: t_loss:0.254 t_acc:0.537 v_loss:0.269 v_acc:0.365
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.91it/s]
# Q2 Epoch: 2: t_loss:0.181 t_acc:0.600 v_loss:0.312 v_acc:0.365
# 100%|██████████| 410/410 [03:09<00:00,  2.17it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.90it/s]
# Q2 Epoch: 3: t_loss:0.163 t_acc:0.659 v_loss:0.220 v_acc:0.540
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.93it/s]
# Q2 Epoch: 4: t_loss:0.153 t_acc:0.695 v_loss:0.181 v_acc:0.624
# 100%|██████████| 410/410 [03:10<00:00,  2.15it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.83it/s]
# Q2 Epoch: 5: t_loss:0.159 t_acc:0.737 v_loss:0.140 v_acc:0.658
# 100%|██████████| 410/410 [03:10<00:00,  2.15it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.94it/s]
# Q2 Epoch: 6: t_loss:0.136 t_acc:0.738 v_loss:0.131 v_acc:0.716
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.94it/s]
# Q2 Epoch: 7: t_loss:0.150 t_acc:0.702 v_loss:0.160 v_acc:0.500
# 100%|██████████| 410/410 [03:08<00:00,  2.17it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.92it/s]
# Q2 Epoch: 8: t_loss:0.154 t_acc:0.649 v_loss:0.131 v_acc:0.725
# 100%|██████████| 410/410 [03:09<00:00,  2.17it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.84it/s]
# Q2 Epoch: 9: t_loss:0.137 t_acc:0.713 v_loss:0.129 v_acc:0.715
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.94it/s]
# Q2 Epoch: 10: t_loss:0.132 t_acc:0.718 v_loss:0.198 v_acc:0.693
# 100%|██████████| 410/410 [03:08<00:00,  2.17it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.91it/s]
# Q2 Epoch: 11: t_loss:0.131 t_acc:0.749 v_loss:0.149 v_acc:0.625
# 100%|██████████| 410/410 [03:09<00:00,  2.17it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.90it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.96it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [03:06<00:00,  2.20it/s]
# 100%|██████████| 40/40 [00:06<00:00,  6.01it/s]
# Q3 Epoch: 1: t_loss:0.250 t_acc:0.515 v_loss:0.198 v_acc:0.385
# 100%|██████████| 410/410 [03:07<00:00,  2.19it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.98it/s]
# Q3 Epoch: 2: t_loss:0.177 t_acc:0.595 v_loss:0.152 v_acc:0.385
# 100%|██████████| 410/410 [03:05<00:00,  2.21it/s]
# 100%|██████████| 40/40 [00:06<00:00,  6.00it/s]
# Q3 Epoch: 3: t_loss:0.157 t_acc:0.658 v_loss:0.233 v_acc:0.385
# 100%|██████████| 410/410 [03:01<00:00,  2.25it/s]
# 100%|██████████| 40/40 [00:06<00:00,  6.00it/s]
# Q3 Epoch: 4: t_loss:0.158 t_acc:0.626 v_loss:0.156 v_acc:0.482
# 100%|██████████| 410/410 [03:03<00:00,  2.24it/s]
# 100%|██████████| 40/40 [00:06<00:00,  6.06it/s]
# 100%|██████████| 40/40 [00:06<00:00,  6.09it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [03:32<00:00,  1.93it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.37it/s]
# S2 Epoch: 1: t_loss:0.219 t_acc:0.603 v_loss:0.230 v_acc:0.430
# 100%|██████████| 410/410 [03:32<00:00,  1.93it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.41it/s]
# S2 Epoch: 2: t_loss:0.146 t_acc:0.678 v_loss:0.237 v_acc:0.540
# 100%|██████████| 410/410 [03:32<00:00,  1.93it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.35it/s]
# S2 Epoch: 3: t_loss:0.138 t_acc:0.658 v_loss:0.138 v_acc:0.635
# 100%|██████████| 410/410 [03:33<00:00,  1.92it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.28it/s]
# S2 Epoch: 4: t_loss:0.135 t_acc:0.693 v_loss:0.181 v_acc:0.520
# 100%|██████████| 410/410 [03:33<00:00,  1.92it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.32it/s]
# S2 Epoch: 5: t_loss:0.131 t_acc:0.721 v_loss:0.152 v_acc:0.619
# 100%|██████████| 410/410 [03:32<00:00,  1.93it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.34it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.35it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.91it/s]
# S3 Epoch: 1: t_loss:0.267 t_acc:0.563 v_loss:0.174 v_acc:0.581
# 100%|██████████| 410/410 [03:10<00:00,  2.15it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.85it/s]
# S3 Epoch: 2: t_loss:0.151 t_acc:0.668 v_loss:0.280 v_acc:0.524
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.83it/s]
# S3 Epoch: 3: t_loss:0.133 t_acc:0.712 v_loss:0.152 v_acc:0.680
# 100%|██████████| 410/410 [03:10<00:00,  2.15it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.91it/s]
# S3 Epoch: 4: t_loss:0.121 t_acc:0.735 v_loss:0.148 v_acc:0.710
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.90it/s]
# S3 Epoch: 5: t_loss:0.128 t_acc:0.711 v_loss:0.209 v_acc:0.627
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.97it/s]
# S3 Epoch: 6: t_loss:0.116 t_acc:0.721 v_loss:0.255 v_acc:0.498
# 100%|██████████| 410/410 [03:09<00:00,  2.16it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.97it/s]
# 100%|██████████| 40/40 [00:06<00:00,  5.84it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [03:23<00:00,  2.02it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.52it/s]
# S1 Epoch: 1: t_loss:0.559 t_acc:0.337 v_loss:0.567 v_acc:0.190
# 100%|██████████| 410/410 [03:22<00:00,  2.02it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.59it/s]
# S1 Epoch: 2: t_loss:0.441 t_acc:0.385 v_loss:0.428 v_acc:0.407
# 100%|██████████| 410/410 [03:22<00:00,  2.03it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.50it/s]
# S1 Epoch: 3: t_loss:0.420 t_acc:0.441 v_loss:0.509 v_acc:0.361
# 100%|██████████| 410/410 [03:24<00:00,  2.01it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.48it/s]
# S1 Epoch: 4: t_loss:0.386 t_acc:0.514 v_loss:0.467 v_acc:0.338
# 100%|██████████| 410/410 [03:22<00:00,  2.02it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.52it/s]
# 100%|██████████| 40/40 [00:07<00:00,  5.54it/s]
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.0, llm_D=1.0
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7151
#  Validation Score Q3:0.3846
#  Validation Score S2:0.6354
#  Validation Score S3:0.7103
#  Validation Score S1:0.4067
# Average Validation Score: 0.5915
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.1, llm_D=0.9
#  Validation Score Q1:0.6732
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5145
#  Validation Score S2:0.6419
#  Validation Score S3:0.7103
#  Validation Score S1:0.4458
# Average Validation Score: 0.6185
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.2, llm_D=0.8
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.4982
#  Validation Score S2:0.5960
#  Validation Score S3:0.7103
#  Validation Score S1:0.4179
# Average Validation Score: 0.6127
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.3, llm_D=0.7
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.4823
#  Validation Score S2:0.5726
#  Validation Score S3:0.7103
#  Validation Score S1:0.4333
# Average Validation Score: 0.6211
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.4, llm_D=0.6
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5803
#  Validation Score S2:0.5489
#  Validation Score S3:0.7103
#  Validation Score S1:0.4317
# Average Validation Score: 0.6280
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.5, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5803
#  Validation Score S2:0.5500
#  Validation Score S3:0.7396
#  Validation Score S1:0.4317
# Average Validation Score: 0.6331
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.6, llm_D=0.4
#  Validation Score Q1:0.7954
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5803
#  Validation Score S2:0.5747
#  Validation Score S3:0.7396
#  Validation Score S1:0.4137
# Average Validation Score: 0.6382
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.7, llm_D=0.3
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5611
#  Validation Score S2:0.5223
#  Validation Score S3:0.7396
#  Validation Score S1:0.3922
# Average Validation Score: 0.6181
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.8, llm_D=0.2
#  Validation Score Q1:0.7396
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5423
#  Validation Score S2:0.4949
#  Validation Score S3:0.7396
#  Validation Score S1:0.3922
# Average Validation Score: 0.6057
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=0.9, llm_D=0.1
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4949
#  Validation Score S3:0.7396
#  Validation Score S1:0.3922
# Average Validation Score: 0.6076
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, tab_C=1.0, llm_D=0.0
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5175
#  Validation Score S3:0.7396
#  Validation Score S1:0.3695
# Average Validation Score: 0.6038
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.0, llm_D=0.9
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5145
#  Validation Score S2:0.5960
#  Validation Score S3:0.6875
#  Validation Score S1:0.4268
# Average Validation Score: 0.6078
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.1, llm_D=0.8
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.4823
#  Validation Score S2:0.5489
#  Validation Score S3:0.6875
#  Validation Score S1:0.4155
# Average Validation Score: 0.5980
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.2, llm_D=0.7
#  Validation Score Q1:0.7475
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5333
#  Validation Score S2:0.5489
#  Validation Score S3:0.6875
#  Validation Score S1:0.3817
# Average Validation Score: 0.6092
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.3, llm_D=0.6
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5803
#  Validation Score S2:0.5500
#  Validation Score S3:0.6875
#  Validation Score S1:0.4132
# Average Validation Score: 0.6265
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.4, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5803
#  Validation Score S2:0.5747
#  Validation Score S3:0.7163
#  Validation Score S1:0.4137
# Average Validation Score: 0.6355
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.5, llm_D=0.4
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5489
#  Validation Score S3:0.7163
#  Validation Score S1:0.4137
# Average Validation Score: 0.6298
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.6, llm_D=0.3
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5726
#  Validation Score S3:0.7163
#  Validation Score S1:0.4327
# Average Validation Score: 0.6278
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.7, llm_D=0.2
#  Validation Score Q1:0.7396
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5726
#  Validation Score S3:0.7163
#  Validation Score S1:0.4106
# Average Validation Score: 0.6280
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.8, llm_D=0.1
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.7163
#  Validation Score S1:0.4106
# Average Validation Score: 0.6190
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, tab_C=0.9, llm_D=0.0
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5396
#  Validation Score S3:0.6931
#  Validation Score S1:0.4106
# Average Validation Score: 0.6104
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.0, llm_D=0.8
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5333
#  Validation Score S2:0.5747
#  Validation Score S3:0.6647
#  Validation Score S1:0.4458
# Average Validation Score: 0.6120
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.1, llm_D=0.7
#  Validation Score Q1:0.7234
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5333
#  Validation Score S2:0.5500
#  Validation Score S3:0.6647
#  Validation Score S1:0.3984
# Average Validation Score: 0.6044
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.2, llm_D=0.6
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5747
#  Validation Score S3:0.6647
#  Validation Score S1:0.3610
# Average Validation Score: 0.6304
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.3, llm_D=0.5
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5990
#  Validation Score S3:0.6931
#  Validation Score S1:0.4137
# Average Validation Score: 0.6434
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.4, llm_D=0.4
#  Validation Score Q1:0.7396
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5726
#  Validation Score S3:0.6931
#  Validation Score S1:0.4327
# Average Validation Score: 0.6380
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.5, llm_D=0.3
#  Validation Score Q1:0.7396
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5726
#  Validation Score S3:0.6931
#  Validation Score S1:0.4327
# Average Validation Score: 0.6380
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.6, llm_D=0.2
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6341
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.7, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6210
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, tab_C=0.8, llm_D=0.0
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6698
#  Validation Score S1:0.4106
# Average Validation Score: 0.6165
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, tab_C=0.0, llm_D=0.7
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5990
#  Validation Score S3:0.6647
#  Validation Score S1:0.4698
# Average Validation Score: 0.6441
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, tab_C=0.1, llm_D=0.6
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5990
#  Validation Score S3:0.6647
#  Validation Score S1:0.4342
# Average Validation Score: 0.6421
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, tab_C=0.2, llm_D=0.5
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5726
#  Validation Score S3:0.6931
#  Validation Score S1:0.4683
# Average Validation Score: 0.6486
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, tab_C=0.3, llm_D=0.4
#  Validation Score Q1:0.7396
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4683
# Average Validation Score: 0.6439
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, tab_C=0.4, llm_D=0.3
#  Validation Score Q1:0.7396
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6380
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, tab_C=0.5, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6388
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, tab_C=0.6, llm_D=0.1
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6308
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, tab_C=0.7, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6308
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, tab_C=0.0, llm_D=0.6
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6419
#  Validation Score S1:0.4310
# Average Validation Score: 0.6384
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, tab_C=0.1, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4127
# Average Validation Score: 0.6400
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, tab_C=0.2, llm_D=0.4
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4640
# Average Validation Score: 0.6479
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, tab_C=0.3, llm_D=0.3
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4875
# Average Validation Score: 0.6479
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, tab_C=0.4, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4875
# Average Validation Score: 0.6479
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, tab_C=0.5, llm_D=0.1
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4875
# Average Validation Score: 0.6433
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, tab_C=0.6, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4875
# Average Validation Score: 0.6399
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, tab_C=0.0, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4104
# Average Validation Score: 0.6396
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, tab_C=0.1, llm_D=0.4
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4127
# Average Validation Score: 0.6355
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, tab_C=0.2, llm_D=0.3
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4640
# Average Validation Score: 0.6440
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, tab_C=0.3, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5284
# Average Validation Score: 0.6547
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, tab_C=0.4, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5347
# Average Validation Score: 0.6558
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, tab_C=0.5, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5347
# Average Validation Score: 0.6478
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, tab_C=0.0, llm_D=0.4
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4640
# Average Validation Score: 0.6401
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, tab_C=0.1, llm_D=0.3
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4640
# Average Validation Score: 0.6440
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, tab_C=0.2, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6515
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, tab_C=0.3, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5284
# Average Validation Score: 0.6547
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, tab_C=0.4, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5284
# Average Validation Score: 0.6501
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, tab_C=0.0, llm_D=0.3
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6475
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, tab_C=0.1, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6970
#  Validation Score S1:0.4640
# Average Validation Score: 0.6485
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, tab_C=0.2, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6970
#  Validation Score S1:0.5088
# Average Validation Score: 0.6560
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, tab_C=0.3, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5284
# Average Validation Score: 0.6501
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, tab_C=0.0, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6530
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, tab_C=0.1, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6970
#  Validation Score S1:0.5088
# Average Validation Score: 0.6527
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, tab_C=0.2, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6970
#  Validation Score S1:0.5683
# Average Validation Score: 0.6579
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.9, tab_C=0.0, llm_D=0.1
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6490
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.9, tab_C=0.1, llm_D=0.0
#  Validation Score Q1:0.6931
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6444
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=1.0, tab_C=0.0, llm_D=0.0
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6490
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.0, llm_D=0.9
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.6925
#  Validation Score Q3:0.4531
#  Validation Score S2:0.6190
#  Validation Score S3:0.6875
#  Validation Score S1:0.4074
# Average Validation Score: 0.5928
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.1, llm_D=0.8
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.4982
#  Validation Score S2:0.5960
#  Validation Score S3:0.6875
#  Validation Score S1:0.4155
# Average Validation Score: 0.6032
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.2, llm_D=0.7
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.4823
#  Validation Score S2:0.5726
#  Validation Score S3:0.6875
#  Validation Score S1:0.4527
# Average Validation Score: 0.6120
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.3, llm_D=0.6
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5803
#  Validation Score S2:0.5489
#  Validation Score S3:0.6875
#  Validation Score S1:0.4132
# Average Validation Score: 0.6263
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.4, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5500
#  Validation Score S3:0.7163
#  Validation Score S1:0.4137
# Average Validation Score: 0.6334
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.5, llm_D=0.4
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5489
#  Validation Score S3:0.7163
#  Validation Score S1:0.4137
# Average Validation Score: 0.6332
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.6, llm_D=0.3
#  Validation Score Q1:0.7396
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5223
#  Validation Score S3:0.7163
#  Validation Score S1:0.4137
# Average Validation Score: 0.6168
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.7, llm_D=0.2
#  Validation Score Q1:0.7396
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5223
#  Validation Score S3:0.7163
#  Validation Score S1:0.3922
# Average Validation Score: 0.6132
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.8, llm_D=0.1
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5175
#  Validation Score S3:0.6931
#  Validation Score S1:0.3922
# Average Validation Score: 0.6036
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, tab_C=0.9, llm_D=0.0
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5396
#  Validation Score S3:0.6931
#  Validation Score S1:0.3922
# Average Validation Score: 0.6035
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.0, llm_D=0.8
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.4982
#  Validation Score S2:0.5489
#  Validation Score S3:0.6647
#  Validation Score S1:0.4138
# Average Validation Score: 0.5913
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.1, llm_D=0.7
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5803
#  Validation Score S2:0.5747
#  Validation Score S3:0.6647
#  Validation Score S1:0.3977
# Average Validation Score: 0.6118
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.2, llm_D=0.6
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5500
#  Validation Score S3:0.6647
#  Validation Score S1:0.4145
# Average Validation Score: 0.6302
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.3, llm_D=0.5
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5489
#  Validation Score S3:0.6931
#  Validation Score S1:0.3945
# Average Validation Score: 0.6269
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.4, llm_D=0.4
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5726
#  Validation Score S3:0.6931
#  Validation Score S1:0.4137
# Average Validation Score: 0.6390
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.5, llm_D=0.3
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5726
#  Validation Score S3:0.6931
#  Validation Score S1:0.4327
# Average Validation Score: 0.6258
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.6, llm_D=0.2
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6931
#  Validation Score S1:0.4327
# Average Validation Score: 0.6297
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.7, llm_D=0.1
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6931
#  Validation Score S1:0.4106
# Average Validation Score: 0.6250
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, tab_C=0.8, llm_D=0.0
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5396
#  Validation Score S3:0.6931
#  Validation Score S1:0.4106
# Average Validation Score: 0.6156
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, tab_C=0.0, llm_D=0.7
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.6000
#  Validation Score S3:0.6647
#  Validation Score S1:0.4888
# Average Validation Score: 0.6435
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, tab_C=0.1, llm_D=0.6
#  Validation Score Q1:0.7475
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5990
#  Validation Score S3:0.6419
#  Validation Score S1:0.4342
# Average Validation Score: 0.6388
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, tab_C=0.2, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4137
# Average Validation Score: 0.6397
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, tab_C=0.3, llm_D=0.4
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5726
#  Validation Score S3:0.6698
#  Validation Score S1:0.4137
# Average Validation Score: 0.6357
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, tab_C=0.4, llm_D=0.3
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6427
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, tab_C=0.5, llm_D=0.2
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6394
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, tab_C=0.6, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4327
# Average Validation Score: 0.6305
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, tab_C=0.7, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4106
# Average Validation Score: 0.6221
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, tab_C=0.0, llm_D=0.6
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5726
#  Validation Score S3:0.6419
#  Validation Score S1:0.4511
# Average Validation Score: 0.6413
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, tab_C=0.1, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4127
# Average Validation Score: 0.6400
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, tab_C=0.2, llm_D=0.4
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4640
# Average Validation Score: 0.6479
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, tab_C=0.3, llm_D=0.3
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4875
# Average Validation Score: 0.6519
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, tab_C=0.4, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4875
# Average Validation Score: 0.6446
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, tab_C=0.5, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4875
# Average Validation Score: 0.6446
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, tab_C=0.6, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4875
# Average Validation Score: 0.6399
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, tab_C=0.0, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4104
# Average Validation Score: 0.6444
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, tab_C=0.1, llm_D=0.4
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4127
# Average Validation Score: 0.6394
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, tab_C=0.2, llm_D=0.3
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4640
# Average Validation Score: 0.6440
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, tab_C=0.3, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5284
# Average Validation Score: 0.6547
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, tab_C=0.4, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5347
# Average Validation Score: 0.6525
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, tab_C=0.5, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5347
# Average Validation Score: 0.6478
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, tab_C=0.0, llm_D=0.4
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6524
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, tab_C=0.1, llm_D=0.3
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.4640
# Average Validation Score: 0.6488
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, tab_C=0.2, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6515
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, tab_C=0.3, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5284
# Average Validation Score: 0.6514
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, tab_C=0.4, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5284
# Average Validation Score: 0.6468
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.6, tab_C=0.0, llm_D=0.3
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6419
#  Validation Score S1:0.5088
# Average Validation Score: 0.6517
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.6, tab_C=0.1, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6563
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.6, tab_C=0.2, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6563
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.6, tab_C=0.3, llm_D=0.0
#  Validation Score Q1:0.7163
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5284
# Average Validation Score: 0.6468
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.7, tab_C=0.0, llm_D=0.2
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6419
#  Validation Score S1:0.5088
# Average Validation Score: 0.6483
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.7, tab_C=0.1, llm_D=0.1
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6530
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.7, tab_C=0.2, llm_D=0.0
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5636
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5683
# Average Validation Score: 0.6596
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.8, tab_C=0.0, llm_D=0.1
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6490
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.8, tab_C=0.1, llm_D=0.0
#  Validation Score Q1:0.7206
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6490
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.9, tab_C=0.0, llm_D=0.0
#  Validation Score Q1:0.6931
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5960
#  Validation Score S3:0.6698
#  Validation Score S1:0.5088
# Average Validation Score: 0.6444
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, tab_C=0.0, llm_D=0.8
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5513
#  Validation Score S2:0.5960
#  Validation Score S3:0.6647
#  Validation Score S1:0.4138
# Average Validation Score: 0.6132
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, tab_C=0.1, llm_D=0.7
#  Validation Score Q1:0.6970
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5333
#  Validation Score S2:0.5726
#  Validation Score S3:0.6875
#  Validation Score S1:0.4155
# Average Validation Score: 0.6052
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, tab_C=0.2, llm_D=0.6
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5803
#  Validation Score S2:0.5489
#  Validation Score S3:0.6875
#  Validation Score S1:0.4145
# Average Validation Score: 0.6265
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, tab_C=0.3, llm_D=0.5
#  Validation Score Q1:0.7714
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6238
#  Validation Score S2:0.5500
#  Validation Score S3:0.6931
#  Validation Score S1:0.3945
# Average Validation Score: 0.6264
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, tab_C=0.4, llm_D=0.4
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5489
#  Validation Score S3:0.6931
#  Validation Score S1:0.4137
# Average Validation Score: 0.6214
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, tab_C=0.5, llm_D=0.3
#  Validation Score Q1:0.7442
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5726
#  Validation Score S3:0.6931
#  Validation Score S1:0.4137
# Average Validation Score: 0.6220
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, tab_C=0.6, llm_D=0.2
#  Validation Score Q1:0.7679
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6931
#  Validation Score S1:0.3922
# Average Validation Score: 0.6217
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, tab_C=0.7, llm_D=0.1
# ...
# Saved submission to submission_top151_0.6440.csv
# Rank 152: lgb_A=0.1, xgb_B=0.4, tab_C=0.2, llm_D=0.3 - Score: 0.6440
# Saved submission to submission_top152_0.6440.csv
# Rank 153: lgb_A=0.0, xgb_B=0.6, tab_C=0.1, llm_D=0.3 - Score: 0.6440
# Saved submission to submission_top153_0.6440.csv
# Rank 154: lgb_A=0.8, xgb_B=0.1, tab_C=0.1, llm_D=0.0 - Score: 0.6440
# Saved submission to submission_top154_0.6440.csv
# Rank 155: lgb_A=0.0, xgb_B=0.3, tab_C=0.3, llm_D=0.4 - Score: 0.6439
# Saved submission to submission_top155_0.6439.csv
# Rank 156: lgb_A=0.8, xgb_B=0.0, tab_C=0.0, llm_D=0.2 - Score: 0.6438
# Saved submission to submission_top156_0.6438.csv
# Rank 157: lgb_A=0.4, xgb_B=0.0, tab_C=0.2, llm_D=0.4 - Score: 0.6436
# Saved submission to submission_top157_0.6436.csv
# Rank 158: lgb_A=0.1, xgb_B=0.2, tab_C=0.0, llm_D=0.7 - Score: 0.6435
# Saved submission to submission_top158_0.6435.csv
# Rank 159: lgb_A=0.0, xgb_B=0.2, tab_C=0.3, llm_D=0.5 - Score: 0.6434
# Saved submission to submission_top159_0.6434.csv
# Rank 160: lgb_A=0.0, xgb_B=0.4, tab_C=0.5, llm_D=0.1 - Score: 0.6433
# Saved submission to submission_top160_0.6433.csv
# Rank 161: lgb_A=0.8, xgb_B=0.0, tab_C=0.2, llm_D=0.0 - Score: 0.6431
# Saved submission to submission_top161_0.6431.csv
# Rank 162: lgb_A=0.1, xgb_B=0.2, tab_C=0.4, llm_D=0.3 - Score: 0.6427
# Saved submission to submission_top162_0.6427.csv
# Rank 163: lgb_A=0.4, xgb_B=0.0, tab_C=0.1, llm_D=0.5 - Score: 0.6425
# Saved submission to submission_top163_0.6425.csv
# Rank 164: lgb_A=0.3, xgb_B=0.0, tab_C=0.2, llm_D=0.5 - Score: 0.6423
# Saved submission to submission_top164_0.6423.csv
# Rank 165: lgb_A=0.0, xgb_B=0.3, tab_C=0.1, llm_D=0.6 - Score: 0.6421
# Saved submission to submission_top165_0.6421.csv
# Rank 166: lgb_A=0.2, xgb_B=0.2, tab_C=0.0, llm_D=0.6 - Score: 0.6421
# Saved submission to submission_top166_0.6421.csv
# Rank 167: lgb_A=0.4, xgb_B=0.0, tab_C=0.4, llm_D=0.2 - Score: 0.6417
# Saved submission to submission_top167_0.6417.csv
# Rank 168: lgb_A=0.5, xgb_B=0.0, tab_C=0.1, llm_D=0.4 - Score: 0.6413
# Saved submission to submission_top168_0.6413.csv
# Rank 169: lgb_A=0.1, xgb_B=0.3, tab_C=0.0, llm_D=0.6 - Score: 0.6413
# Saved submission to submission_top169_0.6413.csv
# Rank 170: lgb_A=0.4, xgb_B=0.0, tab_C=0.3, llm_D=0.3 - Score: 0.6412
# Saved submission to submission_top170_0.6412.csv
# Rank 171: lgb_A=0.2, xgb_B=0.7, tab_C=0.0, llm_D=0.1 - Score: 0.6411
# Saved submission to submission_top171_0.6411.csv
# Rank 172: lgb_A=0.3, xgb_B=0.2, tab_C=0.1, llm_D=0.4 - Score: 0.6408
# Saved submission to submission_top172_0.6408.csv
# Rank 173: lgb_A=0.3, xgb_B=0.2, tab_C=0.0, llm_D=0.5 - Score: 0.6406
# Saved submission to submission_top173_0.6406.csv
# Rank 174: lgb_A=0.5, xgb_B=0.0, tab_C=0.4, llm_D=0.1 - Score: 0.6403
# Saved submission to submission_top174_0.6403.csv
# Rank 175: lgb_A=0.0, xgb_B=0.6, tab_C=0.0, llm_D=0.4 - Score: 0.6401
# Saved submission to submission_top175_0.6401.csv
# Rank 176: lgb_A=0.0, xgb_B=0.4, tab_C=0.1, llm_D=0.5 - Score: 0.6400
# Saved submission to submission_top176_0.6400.csv
# Rank 177: lgb_A=0.1, xgb_B=0.3, tab_C=0.1, llm_D=0.5 - Score: 0.6400
# Saved submission to submission_top177_0.6400.csv
# Rank 178: lgb_A=0.1, xgb_B=0.3, tab_C=0.6, llm_D=0.0 - Score: 0.6399
# Saved submission to submission_top178_0.6399.csv
# Rank 179: lgb_A=0.0, xgb_B=0.4, tab_C=0.6, llm_D=0.0 - Score: 0.6399
# Saved submission to submission_top179_0.6399.csv
# Rank 180: lgb_A=0.3, xgb_B=0.1, tab_C=0.6, llm_D=0.0 - Score: 0.6397
# Saved submission to submission_top180_0.6397.csv
# Rank 181: lgb_A=0.1, xgb_B=0.2, tab_C=0.2, llm_D=0.5 - Score: 0.6397
# Saved submission to submission_top181_0.6397.csv
# Rank 182: lgb_A=0.0, xgb_B=0.5, tab_C=0.0, llm_D=0.5 - Score: 0.6396
# Saved submission to submission_top182_0.6396.csv
# Rank 183: lgb_A=0.2, xgb_B=0.1, tab_C=0.3, llm_D=0.4 - Score: 0.6394
# Saved submission to submission_top183_0.6394.csv
# Rank 184: lgb_A=0.1, xgb_B=0.2, tab_C=0.5, llm_D=0.2 - Score: 0.6394
# Saved submission to submission_top184_0.6394.csv
# Rank 185: lgb_A=0.1, xgb_B=0.4, tab_C=0.1, llm_D=0.4 - Score: 0.6394
# Saved submission to submission_top185_0.6394.csv
# Rank 186: lgb_A=0.5, xgb_B=0.0, tab_C=0.5, llm_D=0.0 - Score: 0.6393
# Saved submission to submission_top186_0.6393.csv
# Rank 187: lgb_A=0.9, xgb_B=0.0, tab_C=0.0, llm_D=0.1 - Score: 0.6391
# Saved submission to submission_top187_0.6391.csv
# Rank 188: lgb_A=1.0, xgb_B=0.0, tab_C=0.0, llm_D=0.0 - Score: 0.6391
# Saved submission to submission_top188_0.6391.csv
# Rank 189: lgb_A=0.1, xgb_B=0.1, tab_C=0.4, llm_D=0.4 - Score: 0.6390
# Saved submission to submission_top189_0.6390.csv
# Rank 190: lgb_A=0.1, xgb_B=0.2, tab_C=0.1, llm_D=0.6 - Score: 0.6388
# Saved submission to submission_top190_0.6388.csv
# Rank 191: lgb_A=0.0, xgb_B=0.3, tab_C=0.5, llm_D=0.2 - Score: 0.6388
# Saved submission to submission_top191_0.6388.csv
# Rank 192: lgb_A=0.2, xgb_B=0.2, tab_C=0.6, llm_D=0.0 - Score: 0.6388
# Saved submission to submission_top192_0.6388.csv
# Rank 193: lgb_A=0.0, xgb_B=0.4, tab_C=0.0, llm_D=0.6 - Score: 0.6384
# Saved submission to submission_top193_0.6384.csv
# Rank 194: lgb_A=0.5, xgb_B=0.0, tab_C=0.0, llm_D=0.5 - Score: 0.6384
# Saved submission to submission_top194_0.6384.csv
# Rank 195: lgb_A=0.0, xgb_B=0.0, tab_C=0.6, llm_D=0.4 - Score: 0.6382
# Saved submission to submission_top195_0.6382.csv
# Rank 196: lgb_A=0.6, xgb_B=0.0, tab_C=0.4, llm_D=0.0 - Score: 0.6381
# Saved submission to submission_top196_0.6381.csv
# Rank 197: lgb_A=0.0, xgb_B=0.3, tab_C=0.4, llm_D=0.3 - Score: 0.6380
# Saved submission to submission_top197_0.6380.csv
# Rank 198: lgb_A=0.0, xgb_B=0.2, tab_C=0.4, llm_D=0.4 - Score: 0.6380
# Saved submission to submission_top198_0.6380.csv
# Rank 199: lgb_A=0.0, xgb_B=0.2, tab_C=0.5, llm_D=0.3 - Score: 0.6380
# Saved submission to submission_top199_0.6380.csv
# Rank 200: lgb_A=0.5, xgb_B=0.5, tab_C=0.0, llm_D=0.0 - Score: 0.6378
# Saved submission to submission_top200_0.6378.csv
# Rank 201: lgb_A=0.4, xgb_B=0.0, tab_C=0.6, llm_D=0.0 - Score: 0.6372
# Saved submission to submission_top201_0.6372.csv
# Rank 202: lgb_A=0.4, xgb_B=0.0, tab_C=0.5, llm_D=0.1 - Score: 0.6370
# Saved submission to submission_top202_0.6370.csv
# Rank 203: lgb_A=0.4, xgb_B=0.6, tab_C=0.0, llm_D=0.0 - Score: 0.6366
# Saved submission to submission_top203_0.6366.csv
# Rank 204: lgb_A=0.3, xgb_B=0.7, tab_C=0.0, llm_D=0.0 - Score: 0.6365
# Saved submission to submission_top204_0.6365.csv
# Rank 205: lgb_A=0.2, xgb_B=0.8, tab_C=0.0, llm_D=0.0 - Score: 0.6365
# Saved submission to submission_top205_0.6365.csv
# Rank 206: lgb_A=0.2, xgb_B=0.1, tab_C=0.2, llm_D=0.5 - Score: 0.6365
# Saved submission to submission_top206_0.6365.csv
# Rank 207: lgb_A=0.3, xgb_B=0.0, tab_C=0.3, llm_D=0.4 - Score: 0.6363
# Saved submission to submission_top207_0.6363.csv
# Rank 208: lgb_A=0.4, xgb_B=0.1, tab_C=0.0, llm_D=0.5 - Score: 0.6359
# Saved submission to submission_top208_0.6359.csv
# Rank 209: lgb_A=0.1, xgb_B=0.2, tab_C=0.3, llm_D=0.4 - Score: 0.6357
# Saved submission to submission_top209_0.6357.csv
# Rank 210: lgb_A=0.3, xgb_B=0.0, tab_C=0.4, llm_D=0.3 - Score: 0.6356
# Saved submission to submission_top210_0.6356.csv
# Rank 211: lgb_A=0.0, xgb_B=0.1, tab_C=0.4, llm_D=0.5 - Score: 0.6355
# Saved submission to submission_top211_0.6355.csv
# Rank 212: lgb_A=0.0, xgb_B=0.5, tab_C=0.1, llm_D=0.4 - Score: 0.6355
# Saved submission to submission_top212_0.6355.csv
# Rank 213: lgb_A=0.2, xgb_B=0.1, tab_C=0.5, llm_D=0.2 - Score: 0.6343
# Saved submission to submission_top213_0.6343.csv
# Rank 214: lgb_A=0.2, xgb_B=0.1, tab_C=0.6, llm_D=0.1 - Score: 0.6343
# Saved submission to submission_top214_0.6343.csv
# Rank 215: lgb_A=0.9, xgb_B=0.0, tab_C=0.1, llm_D=0.0 - Score: 0.6342
# Saved submission to submission_top215_0.6342.csv
# Rank 216: lgb_A=0.0, xgb_B=0.2, tab_C=0.6, llm_D=0.2 - Score: 0.6341
# Saved submission to submission_top216_0.6341.csv
# Rank 217: lgb_A=0.1, xgb_B=0.0, tab_C=0.4, llm_D=0.5 - Score: 0.6334
# Saved submission to submission_top217_0.6334.csv
# Rank 218: lgb_A=0.1, xgb_B=0.0, tab_C=0.5, llm_D=0.4 - Score: 0.6332
# Saved submission to submission_top218_0.6332.csv
# Rank 219: lgb_A=0.0, xgb_B=0.0, tab_C=0.5, llm_D=0.5 - Score: 0.6331
# Saved submission to submission_top219_0.6331.csv
# Rank 220: lgb_A=0.3, xgb_B=0.1, tab_C=0.0, llm_D=0.6 - Score: 0.6316
# Saved submission to submission_top220_0.6316.csv
# Rank 221: lgb_A=0.2, xgb_B=0.1, tab_C=0.4, llm_D=0.3 - Score: 0.6316
# Saved submission to submission_top221_0.6316.csv
# Rank 222: lgb_A=0.0, xgb_B=0.3, tab_C=0.7, llm_D=0.0 - Score: 0.6308
# Saved submission to submission_top222_0.6308.csv
# Rank 223: lgb_A=0.0, xgb_B=0.3, tab_C=0.6, llm_D=0.1 - Score: 0.6308
# Saved submission to submission_top223_0.6308.csv
# Rank 224: lgb_A=0.2, xgb_B=0.0, tab_C=0.7, llm_D=0.1 - Score: 0.6306
# Saved submission to submission_top224_0.6306.csv
# Rank 225: lgb_A=0.1, xgb_B=0.2, tab_C=0.6, llm_D=0.1 - Score: 0.6305
# Saved submission to submission_top225_0.6305.csv
# Rank 226: lgb_A=0.0, xgb_B=0.2, tab_C=0.2, llm_D=0.6 - Score: 0.6304
# Saved submission to submission_top226_0.6304.csv
# Rank 227: lgb_A=0.1, xgb_B=0.1, tab_C=0.2, llm_D=0.6 - Score: 0.6302
# Saved submission to submission_top227_0.6302.csv
# Rank 228: lgb_A=0.2, xgb_B=0.1, tab_C=0.7, llm_D=0.0 - Score: 0.6298
# Saved submission to submission_top228_0.6298.csv
# Rank 229: lgb_A=0.0, xgb_B=0.1, tab_C=0.5, llm_D=0.4 - Score: 0.6298
# Saved submission to submission_top229_0.6298.csv
# Rank 230: lgb_A=0.1, xgb_B=0.1, tab_C=0.6, llm_D=0.2 - Score: 0.6297
# Saved submission to submission_top230_0.6297.csv
# Rank 231: lgb_A=0.2, xgb_B=0.1, tab_C=0.1, llm_D=0.6 - Score: 0.6294
# Saved submission to submission_top231_0.6294.csv
# Rank 232: lgb_A=0.0, xgb_B=0.0, tab_C=0.4, llm_D=0.6 - Score: 0.6280
# Saved submission to submission_top232_0.6280.csv
# Rank 233: lgb_A=0.0, xgb_B=0.1, tab_C=0.7, llm_D=0.2 - Score: 0.6280
# Saved submission to submission_top233_0.6280.csv
# Rank 234: lgb_A=0.0, xgb_B=0.1, tab_C=0.6, llm_D=0.3 - Score: 0.6278
# Saved submission to submission_top234_0.6278.csv
# Rank 235: lgb_A=0.1, xgb_B=0.1, tab_C=0.3, llm_D=0.5 - Score: 0.6269
# Saved submission to submission_top235_0.6269.csv
# Rank 236: lgb_A=0.3, xgb_B=0.0, tab_C=0.6, llm_D=0.1 - Score: 0.6268
# Saved submission to submission_top236_0.6268.csv
# Rank 237: lgb_A=0.2, xgb_B=0.0, tab_C=0.2, llm_D=0.6 - Score: 0.6265
# Saved submission to submission_top237_0.6265.csv
# Rank 238: lgb_A=0.0, xgb_B=0.1, tab_C=0.3, llm_D=0.6 - Score: 0.6265
# Saved submission to submission_top238_0.6265.csv
# Rank 239: lgb_A=0.2, xgb_B=0.0, tab_C=0.3, llm_D=0.5 - Score: 0.6264
# Saved submission to submission_top239_0.6264.csv
# Rank 240: lgb_A=0.1, xgb_B=0.0, tab_C=0.3, llm_D=0.6 - Score: 0.6263
# Saved submission to submission_top240_0.6263.csv
# Rank 241: lgb_A=0.1, xgb_B=0.1, tab_C=0.5, llm_D=0.3 - Score: 0.6258
# Saved submission to submission_top241_0.6258.csv
# Rank 242: lgb_A=0.3, xgb_B=0.0, tab_C=0.7, llm_D=0.0 - Score: 0.6251
# Saved submission to submission_top242_0.6251.csv
# Rank 243: lgb_A=0.1, xgb_B=0.1, tab_C=0.7, llm_D=0.1 - Score: 0.6250
# Saved submission to submission_top243_0.6250.csv
# Rank 244: lgb_A=0.3, xgb_B=0.0, tab_C=0.5, llm_D=0.2 - Score: 0.6227
# Saved submission to submission_top244_0.6227.csv
# Rank 245: lgb_A=0.1, xgb_B=0.2, tab_C=0.7, llm_D=0.0 - Score: 0.6221
# Saved submission to submission_top245_0.6221.csv
# Rank 246: lgb_A=0.2, xgb_B=0.0, tab_C=0.5, llm_D=0.3 - Score: 0.6220
# Saved submission to submission_top246_0.6220.csv
# Rank 247: lgb_A=0.2, xgb_B=0.0, tab_C=0.6, llm_D=0.2 - Score: 0.6217
# Saved submission to submission_top247_0.6217.csv
# Rank 248: lgb_A=0.2, xgb_B=0.0, tab_C=0.4, llm_D=0.4 - Score: 0.6214
# Saved submission to submission_top248_0.6214.csv
# Rank 249: lgb_A=0.0, xgb_B=0.0, tab_C=0.3, llm_D=0.7 - Score: 0.6211
# Saved submission to submission_top249_0.6211.csv
# Rank 250: lgb_A=0.2, xgb_B=0.0, tab_C=0.8, llm_D=0.0 - Score: 0.6211
# Saved submission to submission_top250_0.6211.csv
# Rank 251: lgb_A=0.0, xgb_B=0.2, tab_C=0.7, llm_D=0.1 - Score: 0.6210
# Saved submission to submission_top251_0.6210.csv
# Rank 252: lgb_A=0.0, xgb_B=0.1, tab_C=0.8, llm_D=0.1 - Score: 0.6190
# Saved submission to submission_top252_0.6190.csv
# Rank 253: lgb_A=0.0, xgb_B=0.0, tab_C=0.1, llm_D=0.9 - Score: 0.6185
# Saved submission to submission_top253_0.6185.csv
# Rank 254: lgb_A=0.0, xgb_B=0.0, tab_C=0.7, llm_D=0.3 - Score: 0.6181
# Saved submission to submission_top254_0.6181.csv
# Rank 255: lgb_A=0.2, xgb_B=0.1, tab_C=0.0, llm_D=0.7 - Score: 0.6178
# Saved submission to submission_top255_0.6178.csv
# Rank 256: lgb_A=0.1, xgb_B=0.0, tab_C=0.6, llm_D=0.3 - Score: 0.6168
# Saved submission to submission_top256_0.6168.csv
# Rank 257: lgb_A=0.0, xgb_B=0.2, tab_C=0.8, llm_D=0.0 - Score: 0.6165
# Saved submission to submission_top257_0.6165.csv
# Rank 258: lgb_A=0.1, xgb_B=0.1, tab_C=0.8, llm_D=0.0 - Score: 0.6156
# Saved submission to submission_top258_0.6156.csv
# Rank 259: lgb_A=0.3, xgb_B=0.0, tab_C=0.1, llm_D=0.6 - Score: 0.6141
# Saved submission to submission_top259_0.6141.csv
# Rank 260: lgb_A=0.2, xgb_B=0.0, tab_C=0.0, llm_D=0.8 - Score: 0.6132
# Saved submission to submission_top260_0.6132.csv
# Rank 261: lgb_A=0.1, xgb_B=0.0, tab_C=0.7, llm_D=0.2 - Score: 0.6132
# Saved submission to submission_top261_0.6132.csv
# Rank 262: lgb_A=0.0, xgb_B=0.0, tab_C=0.2, llm_D=0.8 - Score: 0.6127
# Saved submission to submission_top262_0.6127.csv
# Rank 263: lgb_A=0.1, xgb_B=0.0, tab_C=0.2, llm_D=0.7 - Score: 0.6120
# Saved submission to submission_top263_0.6120.csv
# Rank 264: lgb_A=0.0, xgb_B=0.2, tab_C=0.0, llm_D=0.8 - Score: 0.6120
# Saved submission to submission_top264_0.6120.csv
# Rank 265: lgb_A=0.1, xgb_B=0.1, tab_C=0.1, llm_D=0.7 - Score: 0.6118
# Saved submission to submission_top265_0.6118.csv
# Rank 266: lgb_A=0.0, xgb_B=0.1, tab_C=0.9, llm_D=0.0 - Score: 0.6104
# Saved submission to submission_top266_0.6104.csv
# Rank 267: lgb_A=0.4, xgb_B=0.0, tab_C=0.0, llm_D=0.6 - Score: 0.6093
# Saved submission to submission_top267_0.6093.csv
# Rank 268: lgb_A=0.0, xgb_B=0.1, tab_C=0.2, llm_D=0.7 - Score: 0.6092
# Saved submission to submission_top268_0.6092.csv
# Rank 269: lgb_A=0.0, xgb_B=0.1, tab_C=0.0, llm_D=0.9 - Score: 0.6078
# Saved submission to submission_top269_0.6078.csv
# Rank 270: lgb_A=0.0, xgb_B=0.0, tab_C=0.9, llm_D=0.1 - Score: 0.6076
# Saved submission to submission_top270_0.6076.csv
# Rank 271: lgb_A=0.3, xgb_B=0.0, tab_C=0.0, llm_D=0.7 - Score: 0.6070
# Saved submission to submission_top271_0.6070.csv
# Rank 272: lgb_A=0.0, xgb_B=0.0, tab_C=0.8, llm_D=0.2 - Score: 0.6057
# Saved submission to submission_top272_0.6057.csv
# Rank 273: lgb_A=0.2, xgb_B=0.0, tab_C=0.1, llm_D=0.7 - Score: 0.6052
# Saved submission to submission_top273_0.6052.csv
# Rank 274: lgb_A=0.0, xgb_B=0.2, tab_C=0.1, llm_D=0.7 - Score: 0.6044
# Saved submission to submission_top274_0.6044.csv
# Rank 275: lgb_A=0.0, xgb_B=0.0, tab_C=1.0, llm_D=0.0 - Score: 0.6038
# Saved submission to submission_top275_0.6038.csv
# Rank 276: lgb_A=0.1, xgb_B=0.0, tab_C=0.8, llm_D=0.1 - Score: 0.6036
# Saved submission to submission_top276_0.6036.csv
# Rank 277: lgb_A=0.1, xgb_B=0.0, tab_C=0.9, llm_D=0.0 - Score: 0.6035
# Saved submission to submission_top277_0.6035.csv
# Rank 278: lgb_A=0.1, xgb_B=0.0, tab_C=0.1, llm_D=0.8 - Score: 0.6032
# Saved submission to submission_top278_0.6032.csv
# Rank 279: lgb_A=0.0, xgb_B=0.1, tab_C=0.1, llm_D=0.8 - Score: 0.5980
# Saved submission to submission_top279_0.5980.csv
# Rank 280: lgb_A=0.1, xgb_B=0.0, tab_C=0.0, llm_D=0.9 - Score: 0.5928
# Saved submission to submission_top280_0.5928.csv
# Rank 281: lgb_A=0.0, xgb_B=0.0, tab_C=0.0, llm_D=1.0 - Score: 0.5915
# Saved submission to submission_top281_0.5915.csv
# Rank 282: lgb_A=0.1, xgb_B=0.1, tab_C=0.0, llm_D=0.8 - Score: 0.5913
# Saved submission to submission_top282_0.5913.csv
#
#  STEP3: 예측결과 비교표
#     학습sum  학습len  학습mean  테스트sum  테스트len  테스트mean
# Q1    223    450  0.4956     127     250   0.5080
# Q2    253    450  0.5622     156     250   0.6240
# Q3    270    450  0.6000     187     250   0.7480
# S1    390    450  0.8667     203     250   0.8120
# S2    293    450  0.6511     153     250   0.6120
# S3    298    450  0.6622     178     250   0.7120
# CPU times: user 2h 45min 38s, sys: 1min 18s, total: 2h 46min 57s
# Wall time: 2h 43min 11s

# %% [markdown]
# ### 📦 이전제출과 비교

# %%
from pathlib import Path

# Reference file
# reference_file = '/content/drive/MyDrive/data/ch2025_data_items/share/submissions/'
# reference_path = 'submission_top1_0.6492.csv'

reference_path = '../input/'
reference_file = "submission_top1_0.6492_best_top1.csv"

ref_df = pd.read_csv(reference_path + reference_file)

# Get all CSV files in data directory
data_dir = Path('./')
csv_files = list(data_dir.glob('*.csv'))

# Store differences for each file
differences = []

for csv_file in csv_files:
    if csv_file.name == os.path.basename(reference_file):
        continue

    # Read current file
    current_df = pd.read_csv(csv_file)

    # Calculate differences in specified columns
    diff_count = 0
    for col in ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']:
        diff_count += (ref_df[col] != current_df[col]).sum()

    differences.append((csv_file.name, diff_count))
    # print(f"File: {csv_file.name}, Differences: {diff_count}")

# Sort by difference count and get top 20
differences.sort(key=lambda x: x[1])
print("\nTop 20 files with smallest differences:")
for i, (file_name, diff_count) in enumerate(differences[:20], 1):
    print(f"{str(i).zfill(2)}. {file_name}: {diff_count} differences")
# Out:
# Top 20 files with smallest differences:
# 01. submission_top33_0.6596.csv: 94 differences
# 02. submission_top56_0.6562.csv: 94 differences
# 03. submission_top51_0.6563.csv: 95 differences
# 04. submission_top91_0.6515.csv: 95 differences
# 05. submission_top3_0.6667.csv: 95 differences
# 06. submission_top90_0.6515.csv: 96 differences
# 07. submission_top92_0.6514.csv: 96 differences
# 08. submission_top76_0.6530.csv: 97 differences
# 09. submission_top132_0.6468.csv: 97 differences
# 10. submission_top2_0.6667.csv: 97 differences
# 11. submission_top57_0.6562.csv: 98 differences
# 12. submission_top50_0.6563.csv: 98 differences
# 13. submission_top105_0.6488.csv: 98 differences
# 14. submission_top65_0.6547.csv: 99 differences
# 15. submission_top52_0.6563.csv: 99 differences
# 16. submission_top4_0.6667.csv: 99 differences
# 17. submission_top58_0.6562.csv: 99 differences
# 18. submission_top72_0.6530.csv: 100 differences
# 19. submission_top59_0.6560.csv: 100 differences
# 20. submission_top138_0.6450.csv: 100 differences
