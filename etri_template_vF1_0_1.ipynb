# %% [markdown]
# > title : 제 4회 ETRI 휴먼이해 인공지능 논문경진대회 <br>
# > author : hjy,byc <br>

# %% [markdown]
# ### 📦 라이브러리

# %%
! pip install haversine >/dev/null
! pip install optuna  >/dev/null
! pip install category_encoders >/dev/null
! pip install tabpfn  >/dev/null
! pip install catboost >/dev/null
! pip install torchmetrics >/dev/null

# %%
# 기본 모듈
import os
import sys
import re
import ast
import glob
import random
import warnings
from collections import Counter
from math import radians, cos, sin, asin, sqrt
from functools import reduce
from datetime import datetime, timedelta, time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 머신러닝
from sklearn.model_selection import train_test_split, KFold, StratifiedKFold, cross_val_score
from sklearn.metrics import f1_score, roc_auc_score, roc_curve
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.utils.class_weight import compute_class_weight, compute_sample_weight
from category_encoders import TargetEncoder
from lightgbm import LGBMClassifier, log_evaluation, early_stopping
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
import lightgbm as lgb
from tabpfn import TabPFNClassifier

# PyTorch
import torch
from torch import nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# Hugging Face
from huggingface_hub import login
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    LlamaTokenizer,
    LlamaForCausalLM,
    LlamaForSequenceClassification
)

# PEFT (Parameter-Efficient Fine-Tuning)
from peft import (
    LoraConfig,
    get_peft_model,
    get_peft_model_state_dict,
    TaskType
)

# Evaluation & Utilities
from torchmetrics import Accuracy

# 기타
from tqdm import tqdm
from tqdm.auto import tqdm as auto_tqdm  # 필요 시 구분
from scipy.stats import entropy
from haversine import haversine
from io import StringIO
import gc

# wandb
import wandb
wandb.login(key="5fa8dfb2c5be3c888bfe0101437a8fa22fbdf0e0")
wandb.init(project="etri_lifelog", entity="byc3230")

# 옵션
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TOKENIZERS_PARALLELISM"] = "false"
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.float_format', lambda x: '%0.4f' % x)

# 기타
warnings.filterwarnings('ignore')
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: byc3230 to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/content/wandb/run-20250610_052823-on9782do</code>
# Syncing run <strong><a href='https://wandb.ai/byc3230/etri_lifelog/runs/on9782do' target="_blank">vocal-microwave-104</a></strong> to <a href='https://wandb.ai/byc3230/etri_lifelog' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/byc3230/etri_lifelog' target="_blank">https://wandb.ai/byc3230/etri_lifelog</a>
#  View run at <a href='https://wandb.ai/byc3230/etri_lifelog/runs/on9782do' target="_blank">https://wandb.ai/byc3230/etri_lifelog/runs/on9782do</a>

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(1)

# %%
string = """
subject_id,sleep_date
id01,2024-07-24
id01,2024-08-26
id01,2024-08-28
id01,2024-08-29
id02,2024-08-23
id02,2024-09-24
id02,2024-09-26
id02,2024-09-27
id03,2024-08-30
id03,2024-09-01
id03,2024-09-02
id03,2024-09-06
id04,2024-09-03
id04,2024-10-10
id04,2024-10-12
id04,2024-10-13
id05,2024-10-19
id05,2024-10-23
id05,2024-10-24
id05,2024-10-27
id06,2024-07-25
id06,2024-07-26
id06,2024-07-27
id06,2024-07-30
id07,2024-07-07
id07,2024-08-02
id07,2024-08-04
id07,2024-08-05
id08,2024-08-28
id08,2024-08-29
id08,2024-08-30
id08,2024-09-02
id09,2024-08-02
id09,2024-08-31
id09,2024-09-02
id09,2024-09-03
id10,2024-08-28
id10,2024-08-30
id10,2024-08-31
id10,2024-09-03
"""

# DataFrame 생성
valid_ids = pd.read_csv(StringIO(string), sep=',')
valid_ids['pk'] = valid_ids['subject_id']+valid_ids['sleep_date']

# %% [markdown]
# ### 📦 데이터 읽기

# %%
from google.colab import drive, files
drive.mount('/content/drive')

path = '/content/drive/MyDrive/data/ch2025_data_items/share/'

train = pd.read_parquet(f'{path}train_63775.parquet')
test = pd.read_parquet(f'{path}test_63775.parquet')

print('# train  shape:',train.shape)
print('# test   shape:',test.shape)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# # train  shape: (450, 237)
# # test   shape: (250, 237)

# %%
# drop_features = ['afterwork_max_label','sleeptime_max_label','worktime_max_label']
drop_features = ['top_bssid'] # ,'week_type','week_type_lag1'
drop_features = [i for i in drop_features if i in train.columns.tolist()]
print('# drop_features:',drop_features)
train = train.drop(columns=drop_features)
test = test.drop(columns=drop_features)
# Out:
# # drop_features: []

# %%
# ---
# 추정수면효율
# ---

def calculate_sleep_duration_min(sleep_time, wake_time):
    """
    취침 시각(sleep_time)과 기상 시각(wake_time)을 입력받아 수면 시간(분) 반환
    단위는 float 시간 (예: 23.5, 6.25)
    """
    if pd.isna(sleep_time) or pd.isna(wake_time):
        return None
    if wake_time < sleep_time:
        wake_time += 24  # 자정 넘긴 경우 보정
    duration = (wake_time - sleep_time) * 60
    return round(duration)

train['불끈시간부터기상시간'] = train.apply(lambda x: calculate_sleep_duration_min(x['lights_off_time'],x['wake_time']),axis=1)
test['불끈시간부터기상시간'] = test.apply(lambda x: calculate_sleep_duration_min(x['lights_off_time'],x['wake_time']),axis=1)

train['추정수면효율'] = train['불끈시간부터기상시간']/train['sleep_duration_min']
test['추정수면효율'] = test['불끈시간부터기상시간']/test['sleep_duration_min']

# 이상값 제거
train['추정수면효율'] = np.where(train['추정수면효율']<-5,np.nan,train['추정수면효율'])
test['추정수면효율'] = np.where(test['추정수면효율']<-5,np.nan,test['추정수면효율'])
train['추정수면효율'] = np.where(train['추정수면효율']>5,np.nan,train['추정수면효율'])
test['추정수면효율'] = np.where(test['추정수면효율']>55,np.nan,test['추정수면효율'])

# %%
# 요일 컬럼 추가 (예: 월요일, 화요일, ...)
train['lifelog_date'] = pd.to_datetime(train['lifelog_date'])
test['lifelog_date'] = pd.to_datetime(test['lifelog_date'])

# 요일
weekday_map = {
    0: '월요일', 1: '화요일', 2: '수요일', 3: '목요일',
    4: '금요일', 5: '토요일', 6: '일요일'
}
train['weekday'] = train['lifelog_date'].dt.dayofweek.map(weekday_map)
test['weekday'] = test['lifelog_date'].dt.dayofweek.map(weekday_map)

# 월
train['month'] = train['lifelog_date'].dt.month
test['month'] = test['lifelog_date'].dt.month

# weekend
train['weekend'] = np.where(train['weekday'].isin(['토요일','일요일']),1,0)
test['weekend'] = np.where(test['weekday'].isin(['토요일','일요일']),1,0)

# 공휴일
공휴일 = [
     '2024-08-15'
    ,'2024-09-16'
    ,'2024-09-17'
    ,'2024-09-18'
    ,'2024-10-03'
    ,'2024-10-09'
]
train['공휴일'] = np.where(train['lifelog_date'].isin(공휴일),1,0)
test['공휴일'] = np.where(test['lifelog_date'].isin(공휴일),1,0)

# 주말 + 공휴일 묶어주기
train['weekend_holilday'] = np.where( ((train['weekend']==0) & (train['공휴일']==1)), 1, train['weekend'])
test['weekend_holilday'] = np.where( ((test['weekend']==0) & (test['공휴일']==1)), 1, test['weekend'])

# %%
def add_prev_day_flag(df):
    df = df.copy()
    df['lifelog_date'] = pd.to_datetime(df['lifelog_date'])

    # 각 subject_id별로 전날 날짜 만들기
    df['prev_day'] = df['lifelog_date'] - pd.Timedelta(days=1)

    # subject_id + 날짜 기준으로 원본 키 구성
    key_set = set(zip(df['subject_id'], df['lifelog_date']))

    # 전날 데이터가 존재하면 1, 없으면 0
    df['has_prev_day_data'] = df[['subject_id', 'prev_day']].apply(
        lambda row: 1 if (row['subject_id'], row['prev_day']) in key_set else 0, axis=1
    )

    return df.drop(columns=['prev_day'])

train = add_prev_day_flag(train)
test = add_prev_day_flag(test)

# %%
# ---
# 추정휴가
# ---

def rule_based_sum(x):
    rules = (
        # (x['sleep_duration_min'] > (x['avg_sleep_duration']+30))
          (x['sleep_duration_min'] > (x['avg_sleep_duration']+60))
        & (x['week_type'] == 'weekday')
        # & (x['month'].isin([7,8]))
    )
    return rules

train['vacation'] = train.groupby('subject_id').apply(rule_based_sum).reset_index(level=0, drop=True).astype(int)
test['vacation'] = test.groupby('subject_id').apply(rule_based_sum).reset_index(level=0, drop=True).astype(int)

# %%
# 숫자형 컬럼만 선택해서 결측값 -1로 채우기
train[train.select_dtypes(include='number').columns] = train.select_dtypes(include='number').fillna(-1)
test[test.select_dtypes(include='number').columns] = test.select_dtypes(include='number').fillna(-1)

# %% [markdown]
# ### ============================

# %% [markdown]
# ### CustomDataset

# %%
class CustomDataset(Dataset):
    def __init__(self, twitterDF):
        self.twitterDF = twitterDF

    def __len__(self):
        return len(self.twitterDF.index)

    def __getitem__(self, idx):
        return np.array([idx])

# %% [markdown]
# ### train_iter

# %%
def train_iter(model, loader, optimizer, criterion, twitterDFTrain_clean):
    model.train()

    total_loss = 0
    correct = 0
    pred = []
    label = []
    for batchIdx, sampledIdx in enumerate(tqdm(loader, position=0, leave=True)):

        optimizer.zero_grad()

        #text
        sampledIdx = sampledIdx.cpu().data.numpy()
        sampledRowText = list(twitterDFTrain_clean["text"].iloc[list(sampledIdx.flatten())])

        #label
        sampledRowLabels = torch.tensor(list(twitterDFTrain_clean["label"].iloc[list(sampledIdx.flatten())])).to(device)

        #encoded
        encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to(device) # Output shape: [bs, num_Labels]
        encoded_inputIds = encoded_input["input_ids"].to(device)
        encoded_attnMask = encoded_input["attention_mask"].to(device)

        #model
        outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)

        # label type change
        sampledRowLabels = sampledRowLabels.to(outputs.logits.device).long()  # shape: [1]

        # loss
        loss = criterion(outputs.logits, sampledRowLabels)
        total_loss += loss.item()

        #acurracy
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
        predicted_class = torch.argmax(outputs.logits, dim=-1)
        pred.extend(predicted_class.flatten().cpu().data.numpy())
        label.extend(sampledRowLabels.cpu().data.numpy())

        #back propagation
        loss.backward()
        optimizer.step()

    train_accuracy_score = metrics.f1_score(label,pred, average='macro')
    return total_loss / len(loader), train_accuracy_score

# %% [markdown]
# ### valid_iter

# %%
def valid_iter(model, valid_loader, criterion, twitterDFVal_clean):
    model.eval()
    with torch.no_grad():

        total_loss = 0
        correct = 0
        pred = []
        label = []
        for batchIdx, sampledIdx in enumerate(tqdm(valid_loader, position=0, leave=True)):

            sampledRowText = list(twitterDFVal_clean["text"].iloc[list(sampledIdx.flatten())])
            sampledRowLabels = torch.tensor(list(twitterDFVal_clean["label"].iloc[list(sampledIdx.flatten())]))
            encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to(device) # Output shape: [bs, num_Labels]
            encoded_inputIds = encoded_input["input_ids"].to(device)
            encoded_attnMask = encoded_input["attention_mask"].to(device)

            #model
            outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)

            # label type change
            sampledRowLabels = sampledRowLabels.to(outputs.logits.device).long()  # shape: [1]

            # loss
            loss = criterion(outputs.logits, sampledRowLabels)
            total_loss += loss.item()

            #acurracy
            probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
            predicted_class = torch.argmax(outputs.logits, dim=-1)
            pred.extend(predicted_class.flatten().cpu().data.numpy())
            label.extend(sampledRowLabels.cpu().data.numpy())

        valid_accuracy_score = metrics.f1_score(label,pred, average='macro')

    return total_loss/len(valid_loader), valid_accuracy_score

# %% [markdown]
# ### FocalLoss

# %%
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, alpha=None, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha  # optional: list or tensor of class weights
        self.reduction = reduction

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none', weight=self.alpha)
        pt = torch.exp(-ce_loss)  # prevents nans when probability is 0
        focal_loss = ((1 - pt) ** self.gamma) * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %% [markdown]
# ### get_oof_predictions

# %%
def get_oof_predictions(X, y, lgb_params, xgb_params, n_splits=5, is_multiclass=False, num_class=None, early_stop=False):
    oof_preds_lgb = np.zeros(len(X))
    oof_preds_xgb = np.zeros(len(X))
    oof_preds_cat = np.zeros(len(X))
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

    for train_idx, valid_idx in skf.split(X, y):
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        if is_multiclass:
            llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=3, torch_dtype=torch.float16, device_map='auto')
            lora_model = get_peft_model(llm_model, config)
        else:
            llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=2, torch_dtype=torch.float16, device_map='auto')
            lora_model = get_peft_model(llm_model, config)
        # LightGBM
        if is_multiclass:
            lgb_model = LGBMClassifier(**lgb_params, objective='multiclass', num_class=num_class)
        else:
            lgb_model = LGBMClassifier(**lgb_params)

        # XGBoost
        if is_multiclass:
            xgb_model = XGBClassifier(**xgb_params, objective='multi:softmax', num_class=num_class)
        else:
            xgb_model = XGBClassifier(**xgb_params)

        # CatBoost
        if is_multiclass:
            cat_model = CatBoostClassifier(**common_params_cat2, objective='MultiClass', classes_count=num_class)
        else:
            cat_model = CatBoostClassifier(**common_params_cat)

        if early_stop:
            lgb_model.fit(
                X_train, y_train,
                eval_set=[(X_train, y_train), (X_valid, y_valid)],
                callbacks=[early_stopping(stopping_rounds=100, verbose=False)]
            )
            xgb_model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                early_stopping_rounds=100,
                verbose=False
            )
            cat_model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                early_stopping_rounds=100,
                verbose=False
            )
        else:
            X_train_llm = X_train
            X_valid_llm = X_valid

            def prepare_input_text(row):
                target_cols = ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']
                feature_cols = [col for col in X_train.columns if col not in target_cols]

                instruct_txt = ""
                if is_multiclass:
                    instruct_txt = "Classify 0 or 1 or 2. ###DATA### "
                else:
                    instruct_txt = "Classify 0 or 1. ###DATA### "

                for clm in feature_cols:
                    instruct_txt += f"{clm} : {row[clm]}, "

                return instruct_txt.strip()[:-1]+'.'

            X_train_llm['input'] = X_train_llm.apply(lambda x: prepare_input_text(x),axis=1)
            X_valid_llm['input'] = X_valid_llm.apply(lambda x: prepare_input_text(x),axis=1)

            X_train_llm["label"] = y_train
            X_valid_llm['label'] = y_valid
            X_train_llm["text"] = X_train_llm["input"]
            X_valid_llm["text"] = X_valid_llm["input"]

            training_data = CustomDataset(X_train_llm)
            validation_data = CustomDataset(X_valid_llm)

            train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True)
            val_dataloader = DataLoader(validation_data, batch_size=1, shuffle=False)

            twitterDFTrain_clean = X_train_llm
            twitterDFVal_clean = X_valid_llm

            if is_multiclass:
                total_loss = 0
                correct = 0
                bad_counter = 0
                #best model 를 찾기 위한
                best = np.inf

                for epoch in range(epochs):
                    avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, twitterDFTrain_clean)

                    avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, twitterDFVal_clean)

                    if avg_vaild_loss < best:
                        best = avg_vaild_loss
                        torch.save(llm_model.state_dict(), best_model_path)
                        bad_counter = 0
                    else:
                        bad_counter += 1

                    if bad_counter == patience:
                        break

                    print(f'Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')

                    wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})
            else:
                total_loss = 0
                correct = 0
                bad_counter = 0
                #best model 를 찾기 위한
                best = np.inf
                for epoch in range(epochs):
                    avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, twitterDFTrain_clean)

                    avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, twitterDFVal_clean)

                    if avg_vaild_loss < best:
                        best = avg_vaild_loss
                        torch.save(llm_model.state_dict(), best_model_path)
                        bad_counter = 0
                    else:
                        bad_counter += 1

                    if bad_counter == patience:
                        break

                    print(f'Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')

                    wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})

            if is_multiclass:

                # 클래스 weight 계산
                classes = np.unique(y_train)
                weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
                class_weights = dict(zip(classes, weights))

                # 각 샘플에 대해 weight 매핑
                w_train = pd.Series(y_train).map(class_weights)
                #print(w_train)

                w_train = compute_sample_weight(class_weight='balanced', y=y_train)
                print(w_train)

                lgb_model.fit(X_train, y_train, sample_weight=w_train)
                xgb_model.fit(X_train, y_train, sample_weight=w_train)
                cat_model.fit(X_train, y_train)
            else:
                lgb_model.fit(X_train, y_train)
                xgb_model.fit(X_train, y_train)
                cat_model.fit(X_train, y_train)


        # Get predictions
        lgb_preds = lgb_model.predict(X_valid)
        xgb_preds = xgb_model.predict(X_valid)
        cat_preds = cat_model.predict(X_valid).ravel()  # ✅ 2차원 → 1차원

        # Store predictions
        oof_preds_lgb[valid_idx] = lgb_preds
        oof_preds_xgb[valid_idx] = xgb_preds
        oof_preds_cat[valid_idx] = cat_preds

    # Ensemble predictions (7:3 ratio)
    oof_preds = lgb_A * oof_preds_lgb + xgb_B * oof_preds_xgb + cat_C * oof_preds_cat

    if not is_multiclass:
        oof_preds = (oof_preds > 0.5).astype(int)
    else:
        oof_preds = np.round(oof_preds).astype(int)

    return oof_preds

# %% [markdown]
# ### inference

# %%
def inference(model, loader, test_data, col):
    #best model 불러와서 call 하기
    model.load_state_dict(torch.load(col+"_"+best_model_path))
    model.eval()

    preds = []
    preds_prob = []
    with torch.no_grad():
        total_loss = 0
        correct = 0

        pred = []
        label = []

        for batchIdx, sampledIdx in enumerate(tqdm(loader, position=0, leave=True)):

            sampledRowText = list(test_data["text"].iloc[list(sampledIdx.flatten())])

            encoded_input = tokenizer(sampledRowText, truncation=True, padding=True, return_tensors='pt').to("cuda") # Output shape: [bs, num_Labels]
            encoded_inputIds = encoded_input["input_ids"].to("cuda")
            encoded_attnMask = encoded_input["attention_mask"].to("cuda")

            outputs = model(input_ids=encoded_inputIds, attention_mask=encoded_attnMask)
            logits = outputs.logits


            #acurracy
            probs = torch.nn.functional.softmax(outputs.logits.cpu(), dim=-1)

            #확률구하기
            preds_prob.extend(probs.cpu().data.numpy())

            #acurracy
            pred.extend(torch.argmax(logits, dim=1).flatten().cpu().data.numpy())

    return pred, preds_prob

# %% [markdown]
# ### run_basemodel

# %%
def run_basemodel(train, test, valid_ids, common_params, n_splits, random_state=42, early_stop=False):

    #version 33로 진행완료 Best
    lgb_A = 0.3
    xgb_B = 0.3
    cat_C = 0.3
    llm_D = 0.1

    print("=========valid_ids==========")
    # print(valid_ids)
    train_df = train.copy()
    test_df = test.copy()

    submission_final = test_df[['subject_id', 'sleep_date', 'lifelog_date']].copy()
    submission_final['lifelog_date'] = pd.to_datetime(submission_final['lifelog_date']).dt.date

    # 타겟
    targets_binary = ['Q1', 'Q2', 'Q3', 'S2', 'S3']
    targets_binary_name = ['기상직후수면질','취침전신체적피로','취침전스트레스','수면효율','수면잠들기시간']
    target_multiclass = 'S1'
    all_targets = targets_binary + [target_multiclass]

    # 노이즈 수준 설정
    def add_noise(series, noise_level, seed=3):
        rng = np.random.default_rng(seed)
        return series * (1 + noise_level * rng.standard_normal(len(series)))

    noise_level = 0.015  # 필요에 따라 조정

    # 타겟인코딩
    # m = 0: 스무딩 없이 범주별 평균만 사용합니다. 관측 수가 많은 범주에는 적합하지만, 적은 경우 과적합 위험이 있습니다.
    # m = 1~10: 일반적인 기본값으로, 대부분의 상황에서 안정적인 성능을 보입니다.
    # m = 50~300: 관측 수가 매우 적은 범주가 많거나 데이터가 희소한 경우에 유용합니다.
    for tgt in all_targets:

      encoder_feats = ['subject_id','month','weekend'] # 'weekday', 'subject_id','month','weekend'

      #### 타겟인코딩1

      subject_mean = train_df.groupby(encoder_feats)[tgt].mean().rename(f'{tgt}_te')
      train_df = train_df.merge(subject_mean, on=encoder_feats, how='left')
      test_df = test_df.merge(subject_mean, on=encoder_feats, how='left')
      global_mean = train_df[tgt].mean()
      test_df[f'{tgt}_te'] = test_df[f'{tgt}_te'].fillna(global_mean)

      # 노이즈 추가
      train_df[f'{tgt}_te'] = add_noise(train_df[f'{tgt}_te'], noise_level)
      test_df[f'{tgt}_te'] = add_noise(test_df[f'{tgt}_te'], noise_level)

      #### 타겟인코딩2

      # 새로운 범주형 열 생성
      train_df['TMP'] = train_df[encoder_feats].applymap(str).apply(lambda x: ''.join(x) ,axis=1)
      test_df['TMP'] = test_df[encoder_feats].applymap(str).apply(lambda x: ''.join(x) ,axis=1)

      # 인코더
      encoder = TargetEncoder(cols=['TMP'], smoothing=300) # 40
      encoder.fit(train_df[['TMP']], train_df[tgt])

      # 인코딩 결과를 새로운 열에 저장
      train_df[f'{tgt}_te2'] = encoder.transform(train_df[['TMP']])
      test_df[f'{tgt}_te2'] = encoder.transform(test_df[['TMP']])

      # 노이즈 추가
      train_df[f'{tgt}_te2'] = add_noise(train_df[f'{tgt}_te2'], noise_level)
      test_df[f'{tgt}_te2'] = add_noise(test_df[f'{tgt}_te2'], noise_level)

      # 불필요한 변수 제거
      train_df = train_df.drop(columns=['TMP'])
      test_df = test_df.drop(columns=['TMP'])


    # 인코딩
    PK = ['sleep_date', 'lifelog_date', 'subject_id']
    encoder = LabelEncoder()
    categorical_features = [i for i in train_df.select_dtypes(include=['object', 'category']).columns if i not in PK+['pk']]
    for col in categorical_features:
        print(col)
        train_df[col] = encoder.fit_transform(train_df[col])
        test_df[col] = encoder.fit_transform(test_df[col])


    # X
    X = train_df.drop(columns=PK + all_targets)
    test_X = test_df.drop(columns=PK + all_targets)
    print(f'# X shape: {X.shape}')
    print(f'# test_X shape: {test_X.shape}')

    print('\n STEP1: 실험 결과 확인')
    print("=============== Validation Results ==============")
    total_avg_f1s = []
    best_iteration_temp = {k: [] for k in all_targets}

    val_f1 = []

    binary_val_preds = {}
    multiclass_val_preds = {}

    binary_test_preds = {}
    multiclass_test_preds = {}

    test_preds = {}

    # Find optimal weights
    best_weights = []
    best_scores = []

    for col in targets_binary:
        # binary
        y = train_df[col]

        valid_ids['pk'] = valid_ids['subject_id']+valid_ids['sleep_date']
        train_df['pk'] = train_df['subject_id']+train_df['sleep_date']

        X_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
        X_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
        y_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()
        y_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()

        # Get parameters for both models
        lgb_params = common_params[col].copy()
        lgb_params['random_state'] = random_state

        xgb_params = {
            'n_estimators': 1000,
            'learning_rate': 0.01,
            'max_depth': 6,
            'min_child_weight': 1,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': random_state
        }

        # Train LLM
        is_multiclass = False
        llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=2, torch_dtype=torch.float16, device_map='auto')
        lora_model = get_peft_model(llm_model, config)
        # print(llm_model)
        #optimizer = torch.optim.AdamW(llm_model.parameters(), lr=1e-6, weight_decay=1e-4)
        optimizer = torch.optim.AdamW(llm_model.parameters(), lr=3e-4, weight_decay=1e-4)
        criterion = FocalLoss(gamma=2.0)

        # Add learning rate scheduler
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=0.5,
            patience=2,
            verbose=True,
            min_lr=1e-6
        )

        total_loss = 0
        correct = 0
        bad_counter = 0
        #best model 를 찾기 위한
        best = np.inf

        X_train_llm = X_train.copy()
        X_valid_llm = X_valid.copy()

        # X_train_llm = X_train_llm[:15][X_Feature[col]]
        # print(X_train_llm.head(1))
        # X_valid_llm = X_valid_llm[:15][X_Feature[col]]
        # print(X_valid_llm.head(1))

        X_train_llm = X_train_llm[X_Feature[col]]
        X_valid_llm = X_valid_llm[X_Feature[col]]

        def prepare_input_text(row):
            target_cols = ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']
            feature_cols = [col for col in X_Feature[col] if col not in target_cols]


            # 프롬프트 시작 문장에 결측치 설명 추가
            base_prompt = Prompt["S1"] if is_multiclass else Prompt[col]
            instruct_txt = base_prompt.strip() + "\n(Note: -1.0 indicates missing value in the data)\n###DATA###\n"
            #instruct_txt = base_prompt.strip() + "\n(Note 1: -1.0 indicates missing value in the data)\n(Note 2: label_target_encoding embeds target-related info into label and user features to support learning)\n###DATA###\n"

            # instruct_txt = ""
            # if is_multiclass:
            #     instruct_txt = Prompt["S1"]+"###DATA### "
            # else:
            #     instruct_txt = Prompt[col]+"###DATA### "

            # for clm in feature_cols:
            #     instruct_txt += f"{clm} : {row[clm]}, "

            if is_multiclass:
                # feature 값을 alias 이름과 함께 텍스트로 구성
                for orig_name, alias_name in zip(X_Feature["S1"], X_Feature_alias["S1"]):
                    if orig_name not in target_cols:
                        instruct_txt += f"{alias_name} : {row[orig_name]}, "
            else:
                # feature 값을 alias 이름과 함께 텍스트로 구성
                for orig_name, alias_name in zip(X_Feature[col], X_Feature_alias[col]):
                    if orig_name not in target_cols:
                        instruct_txt += f"{alias_name} : {row[orig_name]}, "

            #print(instruct_txt)
            return instruct_txt.strip()[:-1]+'.'

        ######## llm 학습 시작 #################
        is_multiclass = False
        X_train_llm['input'] = X_train_llm.apply(lambda x: prepare_input_text(x),axis=1)
        #print(X_train_llm.head(1))
        X_valid_llm['input'] = X_valid_llm.apply(lambda x: prepare_input_text(x),axis=1)

        # X_train_llm["label"] = y_train[:15]
        # X_valid_llm["label"] = y_valid[:15]
        X_train_llm["label"] = y_train
        X_valid_llm["label"] = y_valid
        X_train_llm["text"] = X_train_llm["input"]
        X_valid_llm["text"] = X_valid_llm["input"]

        training_data = CustomDataset(X_train_llm)
        validation_data = CustomDataset(X_valid_llm)

        train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True,worker_init_fn=seed_worker, generator=g)
        val_dataloader = DataLoader(validation_data, batch_size=1, shuffle=False)

        # twitterDFTrain_clean = X_train_llm[:15]
        # twitterDFVal_clean = X_valid_llm[:15]

        twitterDFTrain_clean = X_train_llm
        twitterDFVal_clean = X_valid_llm


        for epoch in range(epochs):
            avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, twitterDFTrain_clean)

            avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, twitterDFVal_clean)

            # Update learning rate based on validation loss
            scheduler.step(avg_vaild_loss)

            if avg_vaild_loss < best:
                best = avg_vaild_loss
                # torch.save(llm_model.state_dict(), col+"_"+best_model_path)
                torch.save(llm_model.cpu().state_dict(), col+"_"+ best_model_path)
                llm_model.cuda()
                bad_counter = 0
            else:
                bad_counter += 1

            if bad_counter == patience:
                break

            print(f'{col} Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')

            wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})

            # ✅ 메모리 정리
            del avg_train_loss, avg_train_acc, avg_vaild_loss, avg_vaild_acc
            gc.collect()
            torch.cuda.empty_cache()
        ######## llm 학습 끝 #################

        # Train LightGBM
        lgb_model = LGBMClassifier(**lgb_params)
        if early_stop:
            lgb_model.fit(
                X_train, y_train,
                eval_set=[(X_train, y_train), (X_valid, y_valid)],
                callbacks=[early_stopping(stopping_rounds=100,verbose=False)]
            )
            best_iteration_temp[col].append(lgb_model.best_iteration_)
        else:
            lgb_model.fit(X_train, y_train)
            best_iteration_temp[col].append(1000)

        # Train XGBoost
        xgb_model = XGBClassifier(**xgb_params)
        if early_stop:
            xgb_model.fit(
                X_train, y_train,
                eval_set=[(X_valid, y_valid)],
                early_stopping_rounds=100,
                verbose=False
            )
        else:
            xgb_model.fit(X_train, y_train)

        # Train Catboost
        # cat_model = CatBoostClassifier(**common_params_cat, loss_function='Logloss')
        # if early_stop:
        #     cat_model.fit(
        #         X_train, y_train,
        #         eval_set=[(X_valid, y_valid)],
        #         early_stopping_rounds=100,
        #         verbose=False
        #     )
        # else:
        #     cat_model.fit(X_train, y_train)

        tabpfn_params = {
            'device': 'cuda'
        }

        # Train TabPFN
        tabpfn_model = TabPFNClassifier(**tabpfn_params)
        tabpfn_model.fit(X_train, y_train)

        # Get predictions and ensemble
        _, llm_pred_valid = inference(llm_model, val_dataloader, X_valid_llm, col)

        lgb_pred_valid = lgb_model.predict_proba(X_valid)[:, 1]
        xgb_pred_valid = xgb_model.predict_proba(X_valid)[:, 1]
        # cat_pred_valid = cat_model.predict_proba(X_valid)[:, 1]
        # tabnet_pred_valid = tabpfn_model.predict_proba(X_valid.values)[:, 1]
        cat_pred_valid = tabpfn_model.predict_proba(X_valid.values)[:, 1]

        llm_pred_valid = np.array([arr[1] for arr in llm_pred_valid], dtype=np.float32)
        # print(llm_pred_valid)
        pred_valid = (lgb_A * lgb_pred_valid + xgb_B * xgb_pred_valid + cat_C * cat_pred_valid + llm_D * llm_pred_valid  > 0.5).astype(int)

        f1 = f1_score(y_valid, pred_valid, average='macro')
        val_f1.append(f1)

        # Store predictions
        binary_val_preds[col] = {
            'llm': llm_pred_valid,
            'lgb': lgb_pred_valid,
            'xgb': xgb_pred_valid,
            'cat': cat_pred_valid,
            'true': y_valid
        }

    # multiclass
    y = train_df[target_multiclass]

    X_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
    X_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),X.columns.tolist()].reset_index(drop=True).copy()
    y_valid = train_df.loc[train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()
    y_train = train_df.loc[~train_df['pk'].isin(valid_ids['pk']),y.name].reset_index(drop=True).copy()

    # Get parameters for both models
    lgb_params = common_params['S1'].copy()
    lgb_params['random_state'] = random_state

    xgb_params = {
        'n_estimators': 1000,
        'learning_rate': 0.01,
        'max_depth': 6,
        'min_child_weight': 1,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'random_state': random_state
    }

    # 클래스 weight 계산
    classes = np.unique(y_train)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y_train)
    class_weights = dict(zip(classes, weights))

    # 각 샘플에 대해 weight 매핑
    w_train = pd.Series(y_train).map(class_weights)
    # print("----compute_class_weight:")
    # print(w_train)

    w_train = compute_sample_weight(class_weight='balanced', y=y_train)
    # print("----compute_sample_weight:")
    # print(w_train)

    ######## llm 학습 시작 #################
    is_multiclass = True
    llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=3, torch_dtype=torch.float16, device_map='auto')
    lora_model = get_peft_model(llm_model, config)

    optimizer = torch.optim.AdamW(llm_model.parameters(), lr=3e-4, weight_decay=1e-4)
    #optimizer = torch.optim.AdamW(llm_model.parameters(), lr=1e-5, weight_decay=1e-4)
    # alpha = torch.tensor([1.048, 0.670, 1.807], dtype=torch.float16, device=device)
    # criterion = FocalLoss(gamma=2.0,alpha=alpha)
    criterion = FocalLoss(gamma=2.0)

    # Add learning rate scheduler
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='min',
        factor=0.5,
        patience=2,
        verbose=True,
        min_lr=1e-6
    )

    total_loss = 0
    correct = 0
    bad_counter = 0

    #best model 를 찾기 위한
    best = np.inf

    X_train_llm = X_train.copy()
    X_valid_llm = X_valid.copy()

    # X_train_llm = X_train_llm[:15][X_Feature[col]]
    # print(X_train_llm.head(1))
    # X_valid_llm = X_valid_llm[:15][X_Feature[col]]
    # print(X_valid_llm.head(1))

    X_train_llm = X_train_llm[X_Feature["S1"]]
    X_valid_llm = X_valid_llm[X_Feature["S1"]]

    X_train_llm['input'] = X_train_llm.apply(lambda x: prepare_input_text(x),axis=1)
    #print(X_train_llm.head(1))
    X_valid_llm['input'] = X_valid_llm.apply(lambda x: prepare_input_text(x),axis=1)

    # X_train_llm["label"] = y_train[:15]
    # X_valid_llm["label"] = y_valid[:15]
    X_train_llm["label"] = y_train
    X_valid_llm["label"] = y_valid
    X_train_llm["text"] = X_train_llm["input"]
    X_valid_llm["text"] = X_valid_llm["input"]

    training_data = CustomDataset(X_train_llm)
    validation_data = CustomDataset(X_valid_llm)

    #train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True,worker_init_fn=seed_worker, generator=g)
    train_dataloader = DataLoader(training_data, batch_size=1, shuffle=True)
    val_dataloader = DataLoader(validation_data, batch_size=1, shuffle=False)

    # twitterDFTrain_clean = X_train_llm[:15]
    # twitterDFVal_clean = X_valid_llm[:15]

    twitterDFTrain_clean = X_train_llm
    twitterDFVal_clean = X_valid_llm


    for epoch in range(epochs):
        avg_train_loss, avg_train_acc  = train_iter(llm_model, train_dataloader, optimizer, criterion, twitterDFTrain_clean)

        avg_vaild_loss, avg_vaild_acc = valid_iter(llm_model, val_dataloader, criterion, twitterDFVal_clean)

        # Update learning rate based on validation loss
        scheduler.step(avg_vaild_loss)

        if avg_vaild_loss < best:
            best = avg_vaild_loss
            # torch.save(llm_model.state_dict(), "S1_"+best_model_path)
            torch.save(llm_model.cpu().state_dict(), "S1_" + best_model_path)
            llm_model.cuda()
            bad_counter = 0
        else:
            bad_counter += 1

        if bad_counter == patience:
            break

        print(f'S1 Epoch: {str(epoch+1)}: t_loss:{avg_train_loss:.3f} t_acc:{avg_train_acc:.3f} v_loss:{avg_vaild_loss:.3f} v_acc:{avg_vaild_acc:.3f}')

        wandb.log({"train": {'epoch': epoch, "acc": avg_train_acc, "loss": avg_train_loss}, "val": {'epoch': epoch, "acc": avg_vaild_acc, "loss": avg_vaild_loss}})

        # ✅ 메모리 정리
        del avg_train_loss, avg_train_acc, avg_vaild_loss, avg_vaild_acc
        gc.collect()
        torch.cuda.empty_cache()
    ######## llm 학습 끝 #################


    # Train LightGBM
    lgb_model = LGBMClassifier(**lgb_params, objective='multiclass', num_class=3)
    if early_stop:
        lgb_model.fit(
            X_train, y_train,
            eval_set=[(X_train, y_train), (X_valid, y_valid)],
            callbacks=[early_stopping(stopping_rounds=100,verbose=False)], sample_weight=w_train
        )
        best_iteration_temp[target_multiclass].append(lgb_model.best_iteration_)
    else:
        lgb_model.fit(X_train, y_train, sample_weight=w_train)
        best_iteration_temp[target_multiclass].append(1000)

    # Train XGBoost
    xgb_model = XGBClassifier(**xgb_params, objective='multi:softmax', num_class=3)
    if early_stop:
        xgb_model.fit(
            X_train, y_train,
            eval_set=[(X_valid, y_valid)],
            early_stopping_rounds=100,
            verbose=False, sample_weight=w_train
        )
    else:
        xgb_model.fit(X_train, y_train,sample_weight=w_train)

    # Train Catboost
    # cat_model = CatBoostClassifier(**common_params_cat2, loss_function='MultiClass', classes_count=3)
    # if early_stop:
    #     cat_model.fit(
    #         X_train, y_train,
    #         eval_set=[(X_valid, y_valid)],
    #         early_stopping_rounds=100,
    #         verbose=False
    #     )
    # else:
    #     cat_model.fit(X_train, y_train)


    tabpfn_params = {
        'device': 'cuda'
    }

    # Train TabPFN
    tabpfn_model = TabPFNClassifier(**tabpfn_params)
    tabpfn_model.fit(X_train, y_train)

    # Get predictions and ensemble
    _, llm_pred_valid = inference(llm_model, val_dataloader, X_valid_llm, "S1")
    lgb_pred_valid = lgb_model.predict_proba(X_valid)
    xgb_pred_valid = xgb_model.predict_proba(X_valid)
    #cat_pred_valid = cat_model.predict_proba(X_valid)
    #tabnet_pred_valid = tabpfn_model.predict_proba(X_valid.values)
    cat_pred_valid = tabpfn_model.predict_proba(X_valid.values)
    # print(llm_pred_valid)
    # print(lgb_pred_valid)
    llm_pred_valid = np.array(llm_pred_valid, dtype=np.float32)
    #print(llm_pred_valid)
    pred_valid = np.argmax(lgb_A * lgb_pred_valid + xgb_B * xgb_pred_valid + cat_C * cat_pred_valid + llm_D * llm_pred_valid, axis=1)

    f1 = f1_score(y_valid, pred_valid, average='macro')
    val_f1.append(f1)

    multiclass_val_preds = {
        'llm': llm_pred_valid,
        'lgb': lgb_pred_valid,
        'xgb': xgb_pred_valid,
        'cat': cat_pred_valid,
        'true': y_valid
    }

    # Generate all possible weight combinations that sum to 1
    step = 0.1
    for lgb_A in np.arange(0, 1.1, step):
        for xgb_B in np.arange(0, 1.1 - lgb_A, step):
            for cat_C in np.arange(0, 1.1 - lgb_A - xgb_B, step):
                llm_D = 1 - (lgb_A + xgb_B + cat_C)
                if llm_D >= 0:
                    weights = (lgb_A, xgb_B, cat_C, llm_D)
                    print("========================================")
                    print(f"\nTrying weights: lgb_A={lgb_A:.1f}, xgb_B={xgb_B:.1f}, cat_C={cat_C:.1f}, llm_D={llm_D:.1f}")

                    # Calculate validation score with current weights
                    val_scores = []

                    # Binary targets
                    for col in targets_binary:
                        preds = binary_val_preds[col]

                        ensemble_pred = (lgb_A * preds['lgb'] + xgb_B * preds['xgb'] +
                                      cat_C * preds['cat'] + llm_D * preds['llm'] > 0.5).astype(int)
                        f1 = f1_score(preds['true'], ensemble_pred, average='macro')
                        val_scores.append(f1)
                        print(f" Validation Score {col}:{f1:.4f}")

                    # Multiclass target
                    preds = multiclass_val_preds
                    ensemble_pred = np.argmax(lgb_A * preds['lgb'] + xgb_B * preds['xgb'] +
                                           cat_C * preds['cat'] + llm_D * preds['llm'], axis=1)
                    f1 = f1_score(preds['true'], ensemble_pred, average='macro')
                    print(f" Validation Score S1:{f1:.4f}")
                    val_scores.append(f1)

                    avg_score = np.mean(val_scores)
                    best_weights.append(weights)
                    best_scores.append(avg_score)

                    print(f"Average Validation Score: {avg_score:.4f}")

    # Sort results and get top 3
    #sorted_indices = np.argsort(best_scores)[::-1][:3]
    sorted_indices = np.argsort(best_scores)[::-1]
    top_3_weights = [best_weights[i] for i in sorted_indices]
    top_3_scores = [best_scores[i] for i in sorted_indices]

    print("\nTop All Weight Combinations:")
    for i, (weights, score) in enumerate(zip(top_3_weights, top_3_scores)):
        print(f"Rank {i+1}: lgb_A={weights[0]:.1f}, xgb_B={weights[1]:.1f}, cat_C={weights[2]:.1f}, llm_D={weights[3]:.1f} - Score: {score:.4f}")

    avg_f1 = np.mean(val_f1)
    total_avg_f1s.append(avg_f1)
    detail = " ".join([f"{name}({tname}):{score:.4f}" for name, tname, score in zip(targets_binary + [target_multiclass], targets_binary_name + ['S1'], val_f1)])
    print(f" 평균 F1: {avg_f1:.4f} / [상세] {detail}")

    best_iteration_dict = {k: max(best_iteration_temp[k]) for k in all_targets}

    if early_stop==True:
      print("\n[best_iteration_dict]")
      for k, v in best_iteration_dict.items():
          print(f"{k}: {v}")

    print(f"# 전체 평균 F1: {np.mean(total_avg_f1s):.4f}")
    print("================================================")

    # modoling with 100% train & no valid
    print('\n STEP2: 전체 데이터로 모델 재학습')
    print("====== modeling with 100% train & no valid =====")

    # binary
    binary_preds = {}
    binary_preds_proba = {}
    for col in targets_binary:
        # Get parameters for both models
        lgb_params = common_params[col].copy()
        lgb_params['random_state'] = random_state

        xgb_params = {
            'n_estimators': 1000,
            'learning_rate': 0.01,
            'max_depth': 6,
            'min_child_weight': 1,
            'subsample': 0.8,
            'colsample_bytree': 0.8,
            'random_state': random_state
        }

        y = train_df[col]

        if early_stop:
            lgb_params['n_estimators'] = best_iteration_dict[col]
            xgb_params['n_estimators'] = best_iteration_dict[col]

        # LLM Valid Model load and Inference

        is_multiclass = False
        test_X_llm = test_X.copy()
        test_X_llm = test_X_llm[X_Feature[col]]
        test_X_llm['input'] = test_X_llm.apply(lambda x: prepare_input_text(x),axis=1)
        test_X_llm["text"] = test_X_llm["input"]
        test_data = CustomDataset(test_X_llm)
        test_dataloader = DataLoader(test_data, batch_size=1, shuffle=False)

        llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=2, torch_dtype=torch.float16, device_map='auto')
        lora_model = get_peft_model(llm_model, config)
        _, llm_pred = inference(llm_model, test_dataloader, test_X_llm, col)
        llm_pred = np.array([arr[1] for arr in llm_pred], dtype=np.float32)

        # Train LightGBM
        lgb_model = LGBMClassifier(**lgb_params)
        lgb_model.fit(X, y)

        # Train XGBoost
        xgb_model = XGBClassifier(**xgb_params)
        xgb_model.fit(X, y)

        # Train CatBoost
        # cat_model = CatBoostClassifier(**common_params_cat)
        # cat_model.fit(X, y)

        tabpfn_params = {
            'device': 'cuda'
        }

        # Train TabPFN
        tabpfn_model = TabPFNClassifier(**tabpfn_params)
        tabpfn_model.fit(X, y)

        # Get predictions and ensemble
        #_, llm_pred_vaild = inference(llm_model, val_dataloader, X_valid_llm, "S1")
        lgb_pred = lgb_model.predict_proba(test_X)[:, 1]
        xgb_pred = xgb_model.predict_proba(test_X)[:, 1]
        #cat_pred = cat_model.predict_proba(test_X)[:, 1]
        cat_pred = tabpfn_model.predict_proba(test_X)[:, 1]

        binary_preds[col] = (lgb_A * lgb_pred + xgb_B * xgb_pred + cat_C * cat_pred + llm_D * llm_pred  > 0.5).astype(int)
        #binary_preds_proba[col] = lgb_A * lgb_model.predict_proba(test_X) + xgb_B * xgb_model.predict_proba(test_X) + cat_C * cat_model.predict_proba(test_X)

        # Store predictions
        binary_test_preds[col] = {
            'llm': llm_pred,
            'lgb': lgb_pred,
            'xgb': xgb_pred,
            'cat': cat_pred
        }

        # Feature importance (using LightGBM's importance)
        fi_df = pd.DataFrame({'feature': X.columns, 'importance': lgb_model.feature_importances_})
        top10 = fi_df.sort_values(by='importance', ascending=False).head(10)
        feat_str = ", ".join([f"{row['feature']}({int(row['importance'])})" for _, row in top10.iterrows()])
        print(f"[{col}] {feat_str}")

    # multiclass
    y = train_df['S1']

    # Get parameters for both models
    lgb_params = common_params['S1'].copy()
    lgb_params['random_state'] = random_state

    xgb_params = {
        'n_estimators': 1000,
        'learning_rate': 0.01,
        'max_depth': 6,
        'min_child_weight': 1,
        'subsample': 0.8,
        'colsample_bytree': 0.8,
        'random_state': random_state
    }

    if early_stop:
        lgb_params['n_estimators'] = best_iteration_dict['S1']
        xgb_params['n_estimators'] = best_iteration_dict['S1']

    # 클래스 weight 계산
    classes = np.unique(y)
    weights = compute_class_weight(class_weight='balanced', classes=classes, y=y)
    class_weights = dict(zip(classes, weights))

    # 각 샘플에 대해 weight 매핑
    w_train = pd.Series(y).map(class_weights)
    # print("----compute_class_weight:")
    # print(w_train)

    w_train = compute_sample_weight(class_weight='balanced', y=y)
    # print("----compute_sample_weight:")
    # print(w_train)

    # LLM Valid Model load and Inference

    is_multiclass = True
    test_X_llm = test_X.copy()
    test_X_llm = test_X_llm[X_Feature["S1"]]
    test_X_llm['input'] = test_X_llm.apply(lambda x: prepare_input_text(x),axis=1)
    test_X_llm["text"] = test_X_llm["input"]
    test_data = CustomDataset(test_X_llm)
    test_dataloader = DataLoader(test_data, batch_size=1, shuffle=False)

    llm_model = AutoModelForSequenceClassification.from_pretrained(llm_model_path, num_labels=3, torch_dtype=torch.float16, device_map='auto')
    lora_model = get_peft_model(llm_model, config)
    _, llm_pred = inference(llm_model, test_dataloader, test_X_llm, "S1")
    llm_pred = np.array(llm_pred, dtype=np.float32)
    #print(llm_pred)

    # Train LightGBM
    lgb_model = LGBMClassifier(**lgb_params, objective='multiclass', num_class=3)
    lgb_model.fit(X, y, sample_weight=w_train)

    # Train XGBoost
    xgb_model = XGBClassifier(**xgb_params, objective='multi:softmax', num_class=3)
    xgb_model.fit(X, y, sample_weight=w_train)

    # Train CatBoost
    # cat_model = CatBoostClassifier(**common_params_cat2, objective='MultiClass', classes_count=3)
    # cat_model.fit(X, y)

    tabpfn_params = {
        'device': 'cuda'
    }

     # Train TabPFN
    tabpfn_model = TabPFNClassifier(**tabpfn_params)
    tabpfn_model.fit(X, y)

    # Get predictions and ensemble
    lgb_pred = lgb_model.predict_proba(test_X)
    xgb_pred = xgb_model.predict_proba(test_X)
    #cat_pred = cat_model.predict_proba(test_X)
    cat_pred = tabpfn_model.predict_proba(test_X)

    multiclass_test_preds = {
        'llm': llm_pred,
        'lgb': lgb_pred,
        'xgb': xgb_pred,
        'cat': cat_pred
    }

    multiclass_pred = np.argmax(lgb_A * lgb_pred + xgb_B * xgb_pred + cat_C * cat_pred +llm_D * llm_pred, axis=1)
    multiclass_pred_proba = lgb_A * lgb_pred + xgb_B * xgb_pred + cat_C * cat_pred + llm_D * llm_pred

    # Feature importance
    fi_df = pd.DataFrame({'feature': X.columns, 'importance': lgb_model.feature_importances_})
    top10 = fi_df.sort_values(by='importance', ascending=False).head(10)
    feat_str = ", ".join([f"{row['feature']}({int(row['importance'])})" for _, row in top10.iterrows()])
    print(f"[S1] {feat_str}")

    # 예측 저장
    submission_final['S1'] = multiclass_pred
    for col in targets_binary:
      submission_final[col] = binary_preds[col]
    submission_final = submission_final[['subject_id', 'sleep_date', 'lifelog_date', 'Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']]
    fname = f"submission_{np.mean(total_avg_f1s)}.csv"
    submission_final.to_csv(fname, index=False)
    print(f"# {fname} 저장 완료")
    print(f"# submission shape:{submission_final.shape}")
    print("================================================")

    # 확률 결과 추가
    # submission_proba = submission_final.copy()
    # for col in targets_binary:
    #     for i in range(2):
    #         submission_proba[f'{col}_class{i}_proba'] = binary_preds_proba[col][:, i]
    # for i in range(3):
    #     submission_proba[f'S1_class{i}_proba'] = multiclass_pred_proba[:, i]

    # # 저장
    # fname_proba = f"submission_with_proba_{np.mean(total_avg_f1s):.4f}.csv"
    # submission_proba.to_csv(fname_proba, index=False)
    # print(f"# {fname_proba} 저장 완료 (확률 포함)")



    print("\nTop 3 Weight Combinations:")
    for i, (weights, score) in enumerate(zip(top_3_weights, top_3_scores)):
        print(f"Rank {i+1}: lgb_A={weights[0]:.1f}, xgb_B={weights[1]:.1f}, cat_C={weights[2]:.1f}, llm_D={weights[3]:.1f} - Score: {score:.4f}")

        # Generate submission with these weights
        lgb_A, xgb_B, cat_C, llm_D = weights

        # Binary predictions
        for col in targets_binary:
            preds = binary_test_preds[col]
            ensemble_pred = (lgb_A * preds['lgb'] + xgb_B * preds['xgb'] +
                          cat_C * preds['cat'] + llm_D * preds['llm'] > 0.5).astype(int)
            submission_final[col] = ensemble_pred

        # Multiclass prediction
        preds = multiclass_test_preds
        ensemble_pred = np.argmax(lgb_A * preds['lgb'] + xgb_B * preds['xgb'] +
                               cat_C * preds['cat'] + llm_D * preds['llm'], axis=1)
        submission_final['S1'] = ensemble_pred

        fname = f"submission_top{i+1}_{score:.4f}.csv"
        submission_final.to_csv(fname, index=False)
        print(f"Saved submission to {fname}")

    # Use the best weights for final submission
    best_weights = top_3_weights[0]
    lgb_A, xgb_B, cat_C, llm_D = best_weights

    # 모델별 예측결과 비율 비교
    a11 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].sum()
    a13 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].apply(len)
    a12 = train_df[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].mean()
    a21 = submission_final[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].sum()
    a23 = submission_final[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].apply(len)
    a22 = submission_final[['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']].mean()
    result = pd.concat([a11, a13, a12, a21, a23, a22], axis=1)
    result.columns = ['학습sum','학습len','학습mean','테스트sum','테스트len','테스트mean']
    print('\n STEP3: 예측결과 비교표')
    display(result)
    oof_result = []
    return submission_final, oof_result

# %% [markdown]
# ### ============================

# %% [markdown]
# ### 📦 모델 학습

# %%
X_Feature = {
    "Q1": [
        "Q1_te2",
        "wake_time_ratio",
        "mlight_first_wakeup_minutes",
        "wake_time_diff",
        "Q1_te",
        "lights_off_time",
        "sleep_duration_ratio",
        "active_hour_mean_speed",
        "beforebed_통화_time",
        "rolling_sleep_time_2d",
        "activehour_NAVER_time"
    ],
    "Q2": [
        "Q2_te",
        "Q2_te2",
        "activehour_total_screen_time",
        "beforebed_unique_bssid_count",
        "wake_time_lag1",
        "light_rolling_wake_time_2d",
        "beforebed_max_rssi",
        "active_hour_std_hr",
        "beforebed_top_bssid_count",
        "activehour_screen_time_vs_avg_pct",
        "activehour_메신저_time"
    ],
    "Q3": [
        "Q3_te2",
        "light_sleep_time_lag2",
        "mlight_first_wakeup_minutes",
        "rolling_sleep_time_3d",
        "light_rolling_sleep_duration_3d",
        "Q3_te",
        "beforebed_scan_count",
        "active_hour_distance_x",
        "activehour_통화_time",
        "walking_minutes"
    ],
    "S1": [
        "S1_te",
        "wake_time_diff",
        "S1_te2",
        "sleep_duration_ratio",
        "m_activity_met@240min@sum@04h00m",
        "beforebed_screen_time_vs_avg_pct",
        "wake_time_ratio",
        "rolling_wake_time_3d",
        "m_activity_0@240min@std@20h00m",
        "m_activity@240min@std@12h00m",
        "beforebed_메신저_time",
        "sleep_duration_diff",
        "light_sleep_time_diff",
        "active_hour_min_hr"
    ],
    "S2": [
        "S2_te2",
        "S2_te",
        "light_sleep_time_lag1",
        "work_hour_unknown_ratio",
        "m_activity@240min@std@12h00m",
        "beforebed_strong_signal_ratio",
        "light_rolling_wake_time_2d",
        "free_hour_rssi_mean",
        "activehour_전화_time",
        "sleep_hour_mean_speed",
        "activehour_screen_time_vs_avg_pct",
        "light_wake_time_diff_lag2",
        "beforebed_max_rssi",
        "avg_charging_duration",
        "m_activity_met@240min@std@12h00m"
    ],
    "S3": [
        "S3_te",
        "S3_te2",
        "beforebed_메신저_time",
        "light_wake_time_diff",
        "sleep_time_diff_lag1",
        "light_sleep_time_lag2",
        "m_activity_met@240min@sum@16h00m",
        "free_hour_rssi_max",
        "light_weekday_avg_sleep",
        "불끈시간부터기상시간",
        "sleep_hour_distance_x",
        "activehour_scan_count"
    ]
}

X_Feature_alias = {
    "Q1": [
        "Q1_encoded_time_2",
        "wake_time_to_baseline_ratio",
        "minutes_to_first_wake_after_light",
        "wake_time_difference",
        "Q1_encoded_time",
        "lights_off_clock_time",
        "sleep_duration_ratio_to_guideline",
        "mean_speed_during_active_hours",
        "call_duration_before_bed",
        "sleep_time_rolling_avg_2d",
        "NAVER_time_active_hours"
    ],
    "Q2": [
        "Q2_encoded_time",
        "Q2_encoded_time_2",
        "total_screen_time_active_hours",
        "unique_wifi_count_before_bed",
        "previous_day_wake_time",
        "light_based_wake_time_rolling_avg_2d",
        "max_wifi_signal_before_bed",
        "std_heart_rate_active_hours",
        "frequent_wifi_count_before_bed",
        "screen_time_vs_avg_pct_active_hours",
        "messenger_usage_time_active_hours"
    ],
    "Q3": [
        "Q3_encoded_time_2",
        "light_sleep_duration_lag2",
        "minutes_to_first_wake_after_light",
        "sleep_time_rolling_avg_3d",
        "light_based_sleep_duration_rolling_avg_3d",
        "Q3_encoded_time",
        "wifi_scan_count_before_bed",
        "distance_traveled_active_hours",
        "call_duration_active_hours",
        "total_walking_minutes"
    ],
    "S1": [
        "S1_encoded_time",
        "wake_time_difference",
        "S1_encoded_time_2",
        "sleep_duration_ratio_to_guideline",
        "met_sum_0to4am",
        "screen_time_vs_avg_pct_before_bed",
        "wake_time_to_baseline_ratio",
        "wake_time_rolling_avg_3d",
        "activity_std_8pm_to_midnight",
        "activity_std_12pm_to_4pm"
        "messenger_usage_time_before_bed",
        "sleep_time_difference",
        "light_based_sleep_time_difference",
        "activity_time_mininum_hours"

    ],
    "S2": [
        "S2_encoded_time_2",
        "S2_encoded_time",
        "light_sleep_duration_lag1",
        "unknown_activity_ratio_work_hours",
        "activity_std_12pm_to_4pm",
        "strong_wifi_signal_ratio_before_bed",
        "light_based_wake_time_rolling_avg_2d",
        "avg_wifi_signal_strength_free_hours",
        "phone_call_time_active_hours",
        "mean_movement_speed_sleep_hours",
        "activity_time_screen_hour_vs_avg_pct","light_wake_time_diff_lag2","beforebed_max_rssi","avg_charging_duration","m_activity_met@240min@std@12h00m"
    ],
    "S3": [
        "S3_encoded_time",
        "S3_encoded_time_2",
        "messenger_usage_time_before_bed",
        "light_based_wake_time_difference",
        "sleep_time_difference_lag1",
        "light_sleep_duration_lag2",
        "met_sum_4pm_to_8pm",
        "max_wifi_signal_strength_free_hours",
        "light_based_weekday_avg_sleep_duration",
        "time_from_first_movement_to_final_wake",
        "sleep_hour_distance_x","active_hour_scan_count"
    ]
}

# %%
Prompt = {
    "Q1": "Based on the following sleep-related information, classify the overall perceived sleep quality upon waking as either below or above the individual’s average. (0: Below average, 1: Above average) ",
    "Q2": "Using the following data, determine the level of physical fatigue the individual felt before sleep. (0: High fatigue, 1: Low fatigue) ",
    "Q3": "Based on the information below, classify the stress level the individual experienced before going to bed. (0: High stress, 1: Low stress) ",
    "S1": "Based on the provided information, classify how well the individual's total sleep time (TST) aligns with recommended sleep guidelines. (0: Not met, 1: Partially met, 2: Fully met) ",
    "S2": "Using the following indicators, determine whether the individual met the guideline for sleep efficiency (SE). (0: Not met, 1: Met) ",
    "S3": "From the data provided, assess if the sleep onset latency (SOL) guideline was met. (0: Not met, 1: Met) "
}

# %%
def seed_worker(worker_id):
    worker_seed = 42 + worker_id
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(42)

# %%
# ---
# Define llm_model
# --

#llm_model_path = 'Qwen/Qwen2.5-0.5B'
#llm_model_path = "Qwen/Qwen3-0.6B-Base" #똑같음
#llm_model_path = "Qwen/Qwen3-1.7B" # 성공 좋음
#llm_model_path = "EleutherAI/pythia-70m"
#llm_model_path = "facebook/opt-125m" # 괜찮음
#llm_model_path = "openai-community/gpt2"
#llm_model_path = 'Qwen/Qwen2.5-0.5B-Instruct'
#llm_model_path = "distilbert/distilgpt2"
llm_model_path = "Qwen/Qwen3-0.6B"

tokenizer = AutoTokenizer.from_pretrained(llm_model_path, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %%
# ---
# Define LoraConfig
# ---

config = LoraConfig(
    # r=16,
    # lora_alpha=32,
    r=16,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],#Best
    #target_modules=["q_proj", "v_proj", "k_proj", "o_proj"],
    lora_dropout=0.1,
    bias="none",
    # task_type="SEQ_CLS",
    #task_type=TaskType.SEQ_CLS,
    modules_to_save=["classifier"],
)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# ---
# Define your training loop
# ---

epochs = 16 # 5
#optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
#criterion = nn.BCEWithLogitsLoss()
total_loss = 0
correct = 0
best = np.inf # best model 를 찾기 위한
patience = 3  # 3번까지 validation loss 터지면 stop 시킴

# best model save
# result_path = "./"
# best_model_path = os.path.join(result_path, 'best_model.pt')
best_model_path = 'best_model.pt'
bad_counter = 0

# %%
# %%time

# 공통 하이퍼파라미터
common_params = {
  'n_estimators': 5000,
  "learning_rate": 0.01,
  # 'min_data_in_leaf':2,
  # 'bagging_fraction':0.9,
  # 'feature_fraction':0.6,
  'lambda_l1': 5,
  'lambda_l2': 1,
  # 'max_depth': 4,
  'n_jobs': -1,
  'verbosity': -1
}

# 모델별 세부 하이퍼파라미터
best_param_dict = {}
best_param_dict['Q3'] = common_params
best_param_dict['S1'] = common_params
best_param_dict['S2'] = common_params
best_param_dict['S3'] = common_params
best_param_dict['Q1'] = common_params
best_param_dict['Q2'] = common_params

"""
// submission_top1_0.6492.csv

Top 3 Weight Combinations:
Rank 1: lgb_A=0.2, xgb_B=0.4, cat_C=0.0, llm_D=0.4 - Score: 0.6492
Saved submission to submission_top1_0.6492.csv
Rank 2: lgb_A=0.1, xgb_B=0.5, cat_C=0.2, llm_D=0.2 - Score: 0.6487
Saved submission to submission_top2_0.6487.csv
Rank 3: lgb_A=0.1, xgb_B=0.5, cat_C=0.1, llm_D=0.3 - Score: 0.6478
Saved submission to submission_top282_0.5889.csv

평균 F1: 0.6278 / [상세] Q1(기상직후수면질):0.6931 Q2(취침전신체적피로):0.7867 Q3(취침전스트레스):0.6011 S2(수면효율):0.5726 S3(수면잠들기시간):0.6970 S1(S1):0.4163
# 전체 평균 F1: 0.6278

Rank 1: lgb_A=0.3, xgb_B=0.7, cat_C=0.0, llm_D=0.0 - Score: 0.6475
Saved submission to submission_top1_0.6475.csv
Rank 2: lgb_A=0.2, xgb_B=0.8, cat_C=0.0, llm_D=0.0 - Score: 0.6471
Saved submission to submission_top2_0.6471.csv
Rank 3: lgb_A=0.2, xgb_B=0.7, cat_C=0.0, llm_D=0.1 - Score: 0.6464
Saved submission to submission_top3_0.6464.csv
"""

submission_final, oof_result = run_basemodel(train, test, valid_ids, best_param_dict, n_splits=5, random_state=41, early_stop=False)
# Out:
# =========valid_ids==========
# light_week_type_lag1
# weekday
# week_type
# week_type_lag1
# activehour_top_bssid
# beforebed_top_bssid
# # X shape: (450, 247)
# # test_X shape: (250, 247)
#
#  STEP1: 실험 결과 확인
# =============== Validation Results ==============
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [01:14<00:00,  5.51it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.03it/s]
# Q1 Epoch: 1: t_loss:0.281 t_acc:0.527 v_loss:0.169 v_acc:0.522
# 100%|██████████| 410/410 [01:12<00:00,  5.66it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.44it/s]
# Q1 Epoch: 2: t_loss:0.172 t_acc:0.593 v_loss:0.210 v_acc:0.375
# 100%|██████████| 410/410 [01:12<00:00,  5.69it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.44it/s]
# Q1 Epoch: 3: t_loss:0.157 t_acc:0.646 v_loss:0.146 v_acc:0.561
# 100%|██████████| 410/410 [01:12<00:00,  5.68it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.45it/s]
# Q1 Epoch: 4: t_loss:0.143 t_acc:0.707 v_loss:0.203 v_acc:0.486
# 100%|██████████| 410/410 [01:11<00:00,  5.72it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.51it/s]
# Q1 Epoch: 5: t_loss:0.150 t_acc:0.700 v_loss:0.148 v_acc:0.635
# 100%|██████████| 410/410 [01:11<00:00,  5.71it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.40it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.46it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [01:11<00:00,  5.77it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.17it/s]
# Q2 Epoch: 1: t_loss:0.269 t_acc:0.553 v_loss:0.167 v_acc:0.427
# 100%|██████████| 410/410 [01:10<00:00,  5.79it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.50it/s]
# Q2 Epoch: 2: t_loss:0.209 t_acc:0.526 v_loss:0.197 v_acc:0.298
# 100%|██████████| 410/410 [01:11<00:00,  5.75it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.35it/s]
# Q2 Epoch: 3: t_loss:0.182 t_acc:0.519 v_loss:0.173 v_acc:0.365
# 100%|██████████| 410/410 [01:11<00:00,  5.73it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.18it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.97it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [01:12<00:00,  5.69it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.99it/s]
# Q3 Epoch: 1: t_loss:0.249 t_acc:0.504 v_loss:0.166 v_acc:0.385
# 100%|██████████| 410/410 [01:11<00:00,  5.74it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.81it/s]
# Q3 Epoch: 2: t_loss:0.175 t_acc:0.550 v_loss:0.222 v_acc:0.385
# 100%|██████████| 410/410 [01:11<00:00,  5.73it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.29it/s]
# Q3 Epoch: 3: t_loss:0.178 t_acc:0.539 v_loss:0.171 v_acc:0.573
# 100%|██████████| 410/410 [01:11<00:00,  5.75it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.33it/s]
# Q3 Epoch: 4: t_loss:0.158 t_acc:0.658 v_loss:0.164 v_acc:0.482
# 100%|██████████| 410/410 [01:11<00:00,  5.75it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.95it/s]
# Q3 Epoch: 5: t_loss:0.158 t_acc:0.686 v_loss:0.125 v_acc:0.670
# 100%|██████████| 410/410 [01:11<00:00,  5.75it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.85it/s]
# Q3 Epoch: 6: t_loss:0.155 t_acc:0.697 v_loss:0.161 v_acc:0.514
# 100%|██████████| 410/410 [01:11<00:00,  5.75it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.64it/s]
# Q3 Epoch: 7: t_loss:0.142 t_acc:0.713 v_loss:0.136 v_acc:0.542
# 100%|██████████| 410/410 [01:11<00:00,  5.73it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.19it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.39it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [01:11<00:00,  5.72it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.32it/s]
# S2 Epoch: 1: t_loss:0.278 t_acc:0.549 v_loss:0.178 v_acc:0.531
# 100%|██████████| 410/410 [01:11<00:00,  5.72it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.04it/s]
# S2 Epoch: 2: t_loss:0.183 t_acc:0.495 v_loss:0.220 v_acc:0.413
# 100%|██████████| 410/410 [01:11<00:00,  5.73it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.26it/s]
# S2 Epoch: 3: t_loss:0.181 t_acc:0.568 v_loss:0.276 v_acc:0.331
# 100%|██████████| 410/410 [01:11<00:00,  5.73it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.23it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.20it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [01:11<00:00,  5.71it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.06it/s]
# S3 Epoch: 1: t_loss:0.340 t_acc:0.497 v_loss:0.181 v_acc:0.333
# 100%|██████████| 410/410 [01:11<00:00,  5.72it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.31it/s]
# S3 Epoch: 2: t_loss:0.162 t_acc:0.629 v_loss:0.130 v_acc:0.725
# 100%|██████████| 410/410 [01:11<00:00,  5.73it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.18it/s]
# S3 Epoch: 3: t_loss:0.135 t_acc:0.697 v_loss:0.142 v_acc:0.699
# 100%|██████████| 410/410 [01:11<00:00,  5.71it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.18it/s]
# S3 Epoch: 4: t_loss:0.123 t_acc:0.725 v_loss:0.151 v_acc:0.505
# 100%|██████████| 410/410 [01:11<00:00,  5.72it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.39it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.17it/s]
# Some weights of Qwen3ForSequenceClassification were not initialized from the model checkpoint at Qwen/Qwen3-0.6B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 410/410 [01:11<00:00,  5.70it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.99it/s]
# S1 Epoch: 1: t_loss:0.539 t_acc:0.343 v_loss:0.496 v_acc:0.346
# 100%|██████████| 410/410 [01:11<00:00,  5.72it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.15it/s]
# S1 Epoch: 2: t_loss:0.455 t_acc:0.361 v_loss:0.494 v_acc:0.245
# 100%|██████████| 410/410 [01:11<00:00,  5.73it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.06it/s]
# S1 Epoch: 3: t_loss:0.442 t_acc:0.380 v_loss:0.428 v_acc:0.342
# 100%|██████████| 410/410 [01:11<00:00,  5.74it/s]
# 100%|██████████| 40/40 [00:02<00:00, 15.99it/s]
# S1 Epoch: 4: t_loss:0.554 t_acc:0.393 v_loss:0.512 v_acc:0.190
# 100%|██████████| 410/410 [01:11<00:00,  5.74it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.10it/s]
# S1 Epoch: 5: t_loss:0.468 t_acc:0.296 v_loss:0.612 v_acc:0.190
# 100%|██████████| 410/410 [01:11<00:00,  5.74it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.20it/s]
# 100%|██████████| 40/40 [00:02<00:00, 16.54it/s]
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.0, llm_D=1.0
#  Validation Score Q1:0.5611
#  Validation Score Q2:0.4265
#  Validation Score Q3:0.6703
#  Validation Score S2:0.5312
#  Validation Score S3:0.7248
#  Validation Score S1:0.3417
# Average Validation Score: 0.5426
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.1, llm_D=0.9
#  Validation Score Q1:0.6034
#  Validation Score Q2:0.6644
#  Validation Score Q3:0.6703
#  Validation Score S2:0.5100
#  Validation Score S3:0.7494
#  Validation Score S1:0.3648
# Average Validation Score: 0.5937
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.2, llm_D=0.8
#  Validation Score Q1:0.6218
#  Validation Score Q2:0.6800
#  Validation Score Q3:0.6484
#  Validation Score S2:0.5100
#  Validation Score S3:0.7234
#  Validation Score S1:0.4055
# Average Validation Score: 0.5982
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.3, llm_D=0.7
#  Validation Score Q1:0.6366
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6581
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.3824
# Average Validation Score: 0.5980
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.4, llm_D=0.6
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6581
#  Validation Score S2:0.4667
#  Validation Score S3:0.7206
#  Validation Score S1:0.3824
# Average Validation Score: 0.6003
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.5, llm_D=0.5
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.7206
#  Validation Score S1:0.3824
# Average Validation Score: 0.5942
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.6, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.7206
#  Validation Score S1:0.4028
# Average Validation Score: 0.6029
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.7, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.6931
#  Validation Score S1:0.4028
# Average Validation Score: 0.5983
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.8, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.7163
#  Validation Score S1:0.4237
# Average Validation Score: 0.6056
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=0.9, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.7396
#  Validation Score S1:0.4456
# Average Validation Score: 0.6132
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.0, cat_C=1.0, llm_D=0.0
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4667
#  Validation Score S3:0.7396
#  Validation Score S1:0.4456
# Average Validation Score: 0.6094
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.0, llm_D=0.9
#  Validation Score Q1:0.5833
#  Validation Score Q2:0.6644
#  Validation Score Q3:0.6154
#  Validation Score S2:0.5100
#  Validation Score S3:0.7234
#  Validation Score S1:0.3987
# Average Validation Score: 0.5825
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.1, llm_D=0.8
#  Validation Score Q1:0.6218
#  Validation Score Q2:0.6581
#  Validation Score Q3:0.6011
#  Validation Score S2:0.5175
#  Validation Score S3:0.7234
#  Validation Score S1:0.4194
# Average Validation Score: 0.5902
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.2, llm_D=0.7
#  Validation Score Q1:0.6581
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6581
#  Validation Score S2:0.5175
#  Validation Score S3:0.6970
#  Validation Score S1:0.4466
# Average Validation Score: 0.6171
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.3, llm_D=0.6
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6581
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4469
# Average Validation Score: 0.6107
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.4, llm_D=0.5
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6581
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4254
# Average Validation Score: 0.6071
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.5, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4028
# Average Validation Score: 0.6026
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.6, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4237
# Average Validation Score: 0.5996
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.7, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6931
#  Validation Score S1:0.4456
# Average Validation Score: 0.6026
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.8, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6931
#  Validation Score S1:0.4456
# Average Validation Score: 0.6026
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.1, cat_C=0.9, llm_D=0.0
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6931
#  Validation Score S1:0.4456
# Average Validation Score: 0.5989
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.0, llm_D=0.8
#  Validation Score Q1:0.6218
#  Validation Score Q2:0.6925
#  Validation Score Q3:0.6581
#  Validation Score S2:0.5175
#  Validation Score S3:0.7234
#  Validation Score S1:0.4161
# Average Validation Score: 0.6049
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.1, llm_D=0.7
#  Validation Score Q1:0.6218
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5175
#  Validation Score S3:0.6970
#  Validation Score S1:0.4161
# Average Validation Score: 0.5987
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.2, llm_D=0.6
#  Validation Score Q1:0.6703
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5175
#  Validation Score S3:0.6970
#  Validation Score S1:0.4194
# Average Validation Score: 0.6073
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.3, llm_D=0.5
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5175
#  Validation Score S3:0.6970
#  Validation Score S1:0.4674
# Average Validation Score: 0.6181
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.4, llm_D=0.4
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6205
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.5, llm_D=0.3
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4683
# Average Validation Score: 0.6209
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.6, llm_D=0.2
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4466
# Average Validation Score: 0.6173
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.7, llm_D=0.1
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6698
#  Validation Score S1:0.4456
# Average Validation Score: 0.6126
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.2, cat_C=0.8, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6698
#  Validation Score S1:0.4456
# Average Validation Score: 0.6050
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.0, llm_D=0.7
#  Validation Score Q1:0.6581
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4161
# Average Validation Score: 0.6247
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.1, llm_D=0.6
#  Validation Score Q1:0.6366
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.4334
# Average Validation Score: 0.6161
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.2, llm_D=0.5
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.4365
# Average Validation Score: 0.6186
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.3, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.4538
# Average Validation Score: 0.6298
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.4, llm_D=0.3
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6407
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.5, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6206
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.6, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6206
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.3, cat_C=0.7, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6698
#  Validation Score S1:0.4466
# Average Validation Score: 0.6052
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.0, llm_D=0.6
#  Validation Score Q1:0.6366
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4334
# Average Validation Score: 0.6240
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.1, llm_D=0.5
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4334
# Average Validation Score: 0.6259
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.2, llm_D=0.4
#  Validation Score Q1:0.6267
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4365
# Average Validation Score: 0.6164
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.3, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6034
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4538
# Average Validation Score: 0.6328
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.4, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.5087
# Average Validation Score: 0.6450
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.5, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6417
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.4, cat_C=0.6, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6267
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.0, llm_D=0.5
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7630
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6321
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.1, llm_D=0.4
#  Validation Score Q1:0.6267
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4334
# Average Validation Score: 0.6223
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.2, llm_D=0.3
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4334
# Average Validation Score: 0.6275
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.3, llm_D=0.2
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4538
# Average Validation Score: 0.6256
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.4, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4538
# Average Validation Score: 0.6358
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.5, cat_C=0.5, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6429
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.5087
# Average Validation Score: 0.6447
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.0, llm_D=0.4
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7630
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6283
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.1, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6410
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.2, llm_D=0.2
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6360
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.3, llm_D=0.1
#  Validation Score Q1:0.6354
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4538
# Average Validation Score: 0.6207
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.6, cat_C=0.4, llm_D=0.0
#  Validation Score Q1:0.6419
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4538
# Average Validation Score: 0.6218
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, cat_C=0.0, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7630
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6333
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, cat_C=0.1, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, cat_C=0.2, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.7, cat_C=0.3, llm_D=0.0
#  Validation Score Q1:0.6132
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.5087
# Average Validation Score: 0.6288
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, cat_C=0.0, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7630
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6333
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, cat_C=0.1, llm_D=0.1
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7630
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6295
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.8, cat_C=0.2, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6334
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.9, cat_C=0.0, llm_D=0.1
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7917
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6343
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=0.9, cat_C=0.1, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7917
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6343
# ========================================
#
# Trying weights: lgb_A=0.0, xgb_B=1.0, cat_C=0.0, llm_D=0.0
#  Validation Score Q1:0.6931
#  Validation Score Q2:0.7917
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4823
# Average Validation Score: 0.6386
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.0, llm_D=0.9
#  Validation Score Q1:0.5423
#  Validation Score Q2:0.6644
#  Validation Score Q3:0.6366
#  Validation Score S2:0.5312
#  Validation Score S3:0.6992
#  Validation Score S1:0.3628
# Average Validation Score: 0.5728
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.1, llm_D=0.8
#  Validation Score Q1:0.6366
#  Validation Score Q2:0.7151
#  Validation Score Q3:0.6703
#  Validation Score S2:0.5616
#  Validation Score S3:0.7234
#  Validation Score S1:0.3806
# Average Validation Score: 0.6146
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.2, llm_D=0.7
#  Validation Score Q1:0.6366
#  Validation Score Q2:0.6925
#  Validation Score Q3:0.6581
#  Validation Score S2:0.5312
#  Validation Score S3:0.7234
#  Validation Score S1:0.4055
# Average Validation Score: 0.6079
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.3, llm_D=0.6
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6581
#  Validation Score S2:0.4885
#  Validation Score S3:0.7234
#  Validation Score S1:0.3845
# Average Validation Score: 0.6047
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.4, llm_D=0.5
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.3845
# Average Validation Score: 0.5943
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.5, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.3824
# Average Validation Score: 0.5992
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.6, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.7206
#  Validation Score S1:0.4028
# Average Validation Score: 0.6001
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.7, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.7206
#  Validation Score S1:0.4028
# Average Validation Score: 0.6001
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.8, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6931
#  Validation Score S1:0.4237
# Average Validation Score: 0.5990
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.0, cat_C=0.9, llm_D=0.0
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6931
#  Validation Score S1:0.4237
# Average Validation Score: 0.5990
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.0, llm_D=0.8
#  Validation Score Q1:0.6581
#  Validation Score Q2:0.6925
#  Validation Score Q3:0.6011
#  Validation Score S2:0.5396
#  Validation Score S3:0.7234
#  Validation Score S1:0.3987
# Average Validation Score: 0.6023
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.1, llm_D=0.7
#  Validation Score Q1:0.6011
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5175
#  Validation Score S3:0.7234
#  Validation Score S1:0.4161
# Average Validation Score: 0.6061
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.2, llm_D=0.6
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5175
#  Validation Score S3:0.7234
#  Validation Score S1:0.3985
# Average Validation Score: 0.6110
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.3, llm_D=0.5
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4463
# Average Validation Score: 0.6098
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.4, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4261
# Average Validation Score: 0.6052
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.5, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4254
# Average Validation Score: 0.6051
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.6, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4237
# Average Validation Score: 0.6048
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.7, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4456
# Average Validation Score: 0.6085
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.1, cat_C=0.8, llm_D=0.0
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6698
#  Validation Score S1:0.4456
# Average Validation Score: 0.6003
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, cat_C=0.0, llm_D=0.7
#  Validation Score Q1:0.6581
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5175
#  Validation Score S3:0.7234
#  Validation Score S1:0.4161
# Average Validation Score: 0.6206
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, cat_C=0.1, llm_D=0.6
#  Validation Score Q1:0.6366
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5175
#  Validation Score S3:0.6970
#  Validation Score S1:0.4161
# Average Validation Score: 0.6062
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, cat_C=0.2, llm_D=0.5
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.3985
# Average Validation Score: 0.6169
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, cat_C=0.3, llm_D=0.4
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.4674
# Average Validation Score: 0.6371
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, cat_C=0.4, llm_D=0.3
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4674
# Average Validation Score: 0.6272
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, cat_C=0.5, llm_D=0.2
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6244
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, cat_C=0.6, llm_D=0.1
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4683
# Average Validation Score: 0.6209
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.2, cat_C=0.7, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6698
#  Validation Score S1:0.4687
# Average Validation Score: 0.6089
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, cat_C=0.0, llm_D=0.6
#  Validation Score Q1:0.6703
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6011
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4161
# Average Validation Score: 0.6232
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, cat_C=0.1, llm_D=0.5
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6011
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4334
# Average Validation Score: 0.6277
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, cat_C=0.2, llm_D=0.4
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4365
# Average Validation Score: 0.6265
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, cat_C=0.3, llm_D=0.3
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.4163
# Average Validation Score: 0.6286
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, cat_C=0.4, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5396
#  Validation Score S3:0.6970
#  Validation Score S1:0.4674
# Average Validation Score: 0.6333
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, cat_C=0.5, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6256
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.3, cat_C=0.6, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5100
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6218
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, cat_C=0.0, llm_D=0.5
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6398
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, cat_C=0.1, llm_D=0.4
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6011
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4334
# Average Validation Score: 0.6290
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, cat_C=0.2, llm_D=0.3
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5636
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4334
# Average Validation Score: 0.6189
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, cat_C=0.3, llm_D=0.2
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6011
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4365
# Average Validation Score: 0.6257
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, cat_C=0.4, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4674
# Average Validation Score: 0.6381
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.4, cat_C=0.5, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5833
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4889
# Average Validation Score: 0.6315
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, cat_C=0.0, llm_D=0.4
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6322
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, cat_C=0.1, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, cat_C=0.2, llm_D=0.2
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, cat_C=0.3, llm_D=0.1
#  Validation Score Q1:0.6931
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.5636
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4365
# Average Validation Score: 0.6242
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.5, cat_C=0.4, llm_D=0.0
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6011
#  Validation Score S2:0.5683
#  Validation Score S3:0.6970
#  Validation Score S1:0.4365
# Average Validation Score: 0.6257
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.6, cat_C=0.0, llm_D=0.3
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.6, cat_C=0.1, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.6, cat_C=0.2, llm_D=0.1
#  Validation Score Q1:0.6647
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6334
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.6, cat_C=0.3, llm_D=0.0
#  Validation Score Q1:0.6698
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4878
# Average Validation Score: 0.6348
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.7, cat_C=0.0, llm_D=0.2
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7630
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6333
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.7, cat_C=0.1, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6372
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.7, cat_C=0.2, llm_D=0.0
#  Validation Score Q1:0.6419
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6296
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.8, cat_C=0.0, llm_D=0.1
#  Validation Score Q1:0.6875
#  Validation Score Q2:0.7917
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4823
# Average Validation Score: 0.6376
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.8, cat_C=0.1, llm_D=0.0
#  Validation Score Q1:0.6931
#  Validation Score Q2:0.8157
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4849
# Average Validation Score: 0.6430
# ========================================
#
# Trying weights: lgb_A=0.1, xgb_B=0.9, cat_C=0.0, llm_D=0.0
#  Validation Score Q1:0.6931
#  Validation Score Q2:0.7917
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5455
#  Validation Score S3:0.6970
#  Validation Score S1:0.4823
# Average Validation Score: 0.6386
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.0, llm_D=0.8
#  Validation Score Q1:0.6366
#  Validation Score Q2:0.7802
#  Validation Score Q3:0.6581
#  Validation Score S2:0.5616
#  Validation Score S3:0.6992
#  Validation Score S1:0.3360
# Average Validation Score: 0.6120
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.1, llm_D=0.7
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5616
#  Validation Score S3:0.6992
#  Validation Score S1:0.3772
# Average Validation Score: 0.6056
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.2, llm_D=0.6
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5100
#  Validation Score S3:0.7234
#  Validation Score S1:0.4254
# Average Validation Score: 0.6195
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.3, llm_D=0.5
#  Validation Score Q1:0.6484
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.7234
#  Validation Score S1:0.4254
# Average Validation Score: 0.6043
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.4, llm_D=0.4
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.7234
#  Validation Score S1:0.3845
# Average Validation Score: 0.6027
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.5, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.3845
# Average Validation Score: 0.5931
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.6, llm_D=0.2
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4028
# Average Validation Score: 0.5961
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.7, llm_D=0.1
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4028
# Average Validation Score: 0.5961
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.0, cat_C=0.8, llm_D=0.0
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7253
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6931
#  Validation Score S1:0.4237
# Average Validation Score: 0.5990
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.1, cat_C=0.0, llm_D=0.7
#  Validation Score Q1:0.6366
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5396
#  Validation Score S3:0.7234
#  Validation Score S1:0.3987
# Average Validation Score: 0.6128
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.1, cat_C=0.1, llm_D=0.6
#  Validation Score Q1:0.6267
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5175
#  Validation Score S3:0.7234
#  Validation Score S1:0.3772
# Average Validation Score: 0.6089
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.1, cat_C=0.2, llm_D=0.5
#  Validation Score Q1:0.6577
#  Validation Score Q2:0.7867
#  Validation Score Q3:0.6218
#  Validation Score S2:0.5175
#  Validation Score S3:0.7234
#  Validation Score S1:0.3806
# Average Validation Score: 0.6146
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.1, cat_C=0.3, llm_D=0.4
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.6218
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4254
# Average Validation Score: 0.6166
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.1, cat_C=0.4, llm_D=0.3
#  Validation Score Q1:0.6800
#  Validation Score Q2:0.7566
#  Validation Score Q3:0.5833
#  Validation Score S2:0.4885
#  Validation Score S3:0.6970
#  Validation Score S1:0.4254
# Average Validation Score: 0.6051
# ========================================
#
# Trying weights: lgb_A=0.2, xgb_B=0.1, cat_C=0.5, llm_D=0.2
#  Validation Score Q1:0.7103
#  Validation Score Q2:0.7566
# ...
# Saved submission to submission_top150_0.6263.csv
# Rank 151: lgb_A=0.7, xgb_B=0.1, cat_C=0.1, llm_D=0.1 - Score: 0.6262
# Saved submission to submission_top151_0.6262.csv
# Rank 152: lgb_A=0.4, xgb_B=0.0, cat_C=0.5, llm_D=0.1 - Score: 0.6260
# Saved submission to submission_top152_0.6260.csv
# Rank 153: lgb_A=0.0, xgb_B=0.4, cat_C=0.1, llm_D=0.5 - Score: 0.6259
# Saved submission to submission_top153_0.6259.csv
# Rank 154: lgb_A=0.5, xgb_B=0.0, cat_C=0.0, llm_D=0.5 - Score: 0.6259
# Saved submission to submission_top154_0.6259.csv
# Rank 155: lgb_A=0.8, xgb_B=0.2, cat_C=0.0, llm_D=0.0 - Score: 0.6258
# Saved submission to submission_top155_0.6258.csv
# Rank 156: lgb_A=0.2, xgb_B=0.2, cat_C=0.5, llm_D=0.1 - Score: 0.6258
# Saved submission to submission_top156_0.6258.csv
# Rank 157: lgb_A=0.1, xgb_B=0.4, cat_C=0.3, llm_D=0.2 - Score: 0.6257
# Saved submission to submission_top157_0.6257.csv
# Rank 158: lgb_A=0.1, xgb_B=0.5, cat_C=0.4, llm_D=0.0 - Score: 0.6257
# Saved submission to submission_top158_0.6257.csv
# Rank 159: lgb_A=0.0, xgb_B=0.5, cat_C=0.3, llm_D=0.2 - Score: 0.6256
# Saved submission to submission_top159_0.6256.csv
# Rank 160: lgb_A=0.1, xgb_B=0.3, cat_C=0.5, llm_D=0.1 - Score: 0.6256
# Saved submission to submission_top160_0.6256.csv
# Rank 161: lgb_A=0.2, xgb_B=0.2, cat_C=0.6, llm_D=0.0 - Score: 0.6256
# Saved submission to submission_top161_0.6256.csv
# Rank 162: lgb_A=0.4, xgb_B=0.0, cat_C=0.3, llm_D=0.3 - Score: 0.6253
# Saved submission to submission_top162_0.6253.csv
# Rank 163: lgb_A=0.4, xgb_B=0.0, cat_C=0.4, llm_D=0.2 - Score: 0.6253
# Saved submission to submission_top163_0.6253.csv
# Rank 164: lgb_A=0.3, xgb_B=0.1, cat_C=0.4, llm_D=0.2 - Score: 0.6249
# Saved submission to submission_top164_0.6249.csv
# Rank 165: lgb_A=0.4, xgb_B=0.0, cat_C=0.6, llm_D=0.0 - Score: 0.6247
# Saved submission to submission_top165_0.6247.csv
# Rank 166: lgb_A=0.0, xgb_B=0.3, cat_C=0.0, llm_D=0.7 - Score: 0.6247
# Saved submission to submission_top166_0.6247.csv
# Rank 167: lgb_A=0.1, xgb_B=0.2, cat_C=0.5, llm_D=0.2 - Score: 0.6244
# Saved submission to submission_top167_0.6244.csv
# Rank 168: lgb_A=0.1, xgb_B=0.5, cat_C=0.3, llm_D=0.1 - Score: 0.6242
# Saved submission to submission_top168_0.6242.csv
# Rank 169: lgb_A=0.7, xgb_B=0.0, cat_C=0.3, llm_D=0.0 - Score: 0.6241
# Saved submission to submission_top169_0.6241.csv
# Rank 170: lgb_A=0.4, xgb_B=0.2, cat_C=0.0, llm_D=0.4 - Score: 0.6240
# Saved submission to submission_top170_0.6240.csv
# Rank 171: lgb_A=0.0, xgb_B=0.4, cat_C=0.0, llm_D=0.6 - Score: 0.6240
# Saved submission to submission_top171_0.6240.csv
# Rank 172: lgb_A=0.1, xgb_B=0.3, cat_C=0.0, llm_D=0.6 - Score: 0.6232
# Saved submission to submission_top172_0.6232.csv
# Rank 173: lgb_A=0.2, xgb_B=0.2, cat_C=0.0, llm_D=0.6 - Score: 0.6229
# Saved submission to submission_top173_0.6229.csv
# Rank 174: lgb_A=0.4, xgb_B=0.1, cat_C=0.2, llm_D=0.3 - Score: 0.6226
# Saved submission to submission_top174_0.6226.csv
# Rank 175: lgb_A=0.0, xgb_B=0.5, cat_C=0.1, llm_D=0.4 - Score: 0.6223
# Saved submission to submission_top175_0.6223.csv
# Rank 176: lgb_A=0.8, xgb_B=0.1, cat_C=0.1, llm_D=0.0 - Score: 0.6222
# Saved submission to submission_top176_0.6222.csv
# Rank 177: lgb_A=0.0, xgb_B=0.6, cat_C=0.4, llm_D=0.0 - Score: 0.6218
# Saved submission to submission_top177_0.6218.csv
# Rank 178: lgb_A=0.1, xgb_B=0.3, cat_C=0.6, llm_D=0.0 - Score: 0.6218
# Saved submission to submission_top178_0.6218.csv
# Rank 179: lgb_A=0.4, xgb_B=0.1, cat_C=0.1, llm_D=0.4 - Score: 0.6214
# Saved submission to submission_top179_0.6214.csv
# Rank 180: lgb_A=0.4, xgb_B=0.1, cat_C=0.0, llm_D=0.5 - Score: 0.6210
# Saved submission to submission_top180_0.6210.csv
# Rank 181: lgb_A=0.1, xgb_B=0.2, cat_C=0.6, llm_D=0.1 - Score: 0.6209
# Saved submission to submission_top181_0.6209.csv
# Rank 182: lgb_A=0.0, xgb_B=0.2, cat_C=0.5, llm_D=0.3 - Score: 0.6209
# Saved submission to submission_top182_0.6209.csv
# Rank 183: lgb_A=0.0, xgb_B=0.6, cat_C=0.3, llm_D=0.1 - Score: 0.6207
# Saved submission to submission_top183_0.6207.csv
# Rank 184: lgb_A=0.1, xgb_B=0.2, cat_C=0.0, llm_D=0.7 - Score: 0.6206
# Saved submission to submission_top184_0.6206.csv
# Rank 185: lgb_A=0.0, xgb_B=0.3, cat_C=0.5, llm_D=0.2 - Score: 0.6206
# Saved submission to submission_top185_0.6206.csv
# Rank 186: lgb_A=0.0, xgb_B=0.3, cat_C=0.6, llm_D=0.1 - Score: 0.6206
# Saved submission to submission_top186_0.6206.csv
# Rank 187: lgb_A=0.6, xgb_B=0.0, cat_C=0.1, llm_D=0.3 - Score: 0.6205
# Saved submission to submission_top187_0.6205.csv
# Rank 188: lgb_A=0.0, xgb_B=0.2, cat_C=0.4, llm_D=0.4 - Score: 0.6205
# Saved submission to submission_top188_0.6205.csv
# Rank 189: lgb_A=0.8, xgb_B=0.0, cat_C=0.2, llm_D=0.0 - Score: 0.6202
# Saved submission to submission_top189_0.6202.csv
# Rank 190: lgb_A=0.6, xgb_B=0.0, cat_C=0.2, llm_D=0.2 - Score: 0.6196
# Saved submission to submission_top190_0.6196.csv
# Rank 191: lgb_A=0.2, xgb_B=0.0, cat_C=0.2, llm_D=0.6 - Score: 0.6195
# Saved submission to submission_top191_0.6195.csv
# Rank 192: lgb_A=0.5, xgb_B=0.0, cat_C=0.2, llm_D=0.3 - Score: 0.6194
# Saved submission to submission_top192_0.6194.csv
# Rank 193: lgb_A=0.1, xgb_B=0.4, cat_C=0.2, llm_D=0.3 - Score: 0.6189
# Saved submission to submission_top193_0.6189.csv
# Rank 194: lgb_A=0.4, xgb_B=0.0, cat_C=0.1, llm_D=0.5 - Score: 0.6186
# Saved submission to submission_top194_0.6186.csv
# Rank 195: lgb_A=0.0, xgb_B=0.3, cat_C=0.2, llm_D=0.5 - Score: 0.6186
# Saved submission to submission_top195_0.6186.csv
# Rank 196: lgb_A=0.5, xgb_B=0.1, cat_C=0.0, llm_D=0.4 - Score: 0.6184
# Saved submission to submission_top196_0.6184.csv
# Rank 197: lgb_A=0.0, xgb_B=0.2, cat_C=0.3, llm_D=0.5 - Score: 0.6181
# Saved submission to submission_top197_0.6181.csv
# Rank 198: lgb_A=0.0, xgb_B=0.2, cat_C=0.6, llm_D=0.2 - Score: 0.6173
# Saved submission to submission_top198_0.6173.csv
# Rank 199: lgb_A=0.2, xgb_B=0.1, cat_C=0.7, llm_D=0.0 - Score: 0.6171
# Saved submission to submission_top199_0.6171.csv
# Rank 200: lgb_A=0.0, xgb_B=0.1, cat_C=0.2, llm_D=0.7 - Score: 0.6171
# Saved submission to submission_top200_0.6171.csv
# Rank 201: lgb_A=0.1, xgb_B=0.2, cat_C=0.2, llm_D=0.5 - Score: 0.6169
# Saved submission to submission_top201_0.6169.csv
# Rank 202: lgb_A=0.2, xgb_B=0.1, cat_C=0.3, llm_D=0.4 - Score: 0.6166
# Saved submission to submission_top202_0.6166.csv
# Rank 203: lgb_A=0.0, xgb_B=0.4, cat_C=0.2, llm_D=0.4 - Score: 0.6164
# Saved submission to submission_top203_0.6164.csv
# Rank 204: lgb_A=0.7, xgb_B=0.0, cat_C=0.2, llm_D=0.1 - Score: 0.6163
# Saved submission to submission_top204_0.6163.csv
# Rank 205: lgb_A=0.7, xgb_B=0.1, cat_C=0.2, llm_D=0.0 - Score: 0.6162
# Saved submission to submission_top205_0.6162.csv
# Rank 206: lgb_A=0.3, xgb_B=0.0, cat_C=0.4, llm_D=0.3 - Score: 0.6161
# Saved submission to submission_top206_0.6161.csv
# Rank 207: lgb_A=0.0, xgb_B=0.3, cat_C=0.1, llm_D=0.6 - Score: 0.6161
# Saved submission to submission_top207_0.6161.csv
# Rank 208: lgb_A=0.1, xgb_B=0.0, cat_C=0.1, llm_D=0.8 - Score: 0.6146
# Saved submission to submission_top208_0.6146.csv
# Rank 209: lgb_A=0.2, xgb_B=0.1, cat_C=0.2, llm_D=0.5 - Score: 0.6146
# Saved submission to submission_top209_0.6146.csv
# Rank 210: lgb_A=0.3, xgb_B=0.0, cat_C=0.3, llm_D=0.4 - Score: 0.6146
# Saved submission to submission_top210_0.6146.csv
# Rank 211: lgb_A=0.2, xgb_B=0.2, cat_C=0.1, llm_D=0.5 - Score: 0.6144
# Saved submission to submission_top211_0.6144.csv
# Rank 212: lgb_A=0.4, xgb_B=0.2, cat_C=0.3, llm_D=0.1 - Score: 0.6141
# Saved submission to submission_top212_0.6141.csv
# Rank 213: lgb_A=0.3, xgb_B=0.1, cat_C=0.1, llm_D=0.5 - Score: 0.6141
# Saved submission to submission_top213_0.6141.csv
# Rank 214: lgb_A=0.4, xgb_B=0.0, cat_C=0.2, llm_D=0.4 - Score: 0.6138
# Saved submission to submission_top214_0.6138.csv
# Rank 215: lgb_A=0.2, xgb_B=0.1, cat_C=0.6, llm_D=0.1 - Score: 0.6137
# Saved submission to submission_top215_0.6137.csv
# Rank 216: lgb_A=0.0, xgb_B=0.0, cat_C=0.9, llm_D=0.1 - Score: 0.6132
# Saved submission to submission_top216_0.6132.csv
# Rank 217: lgb_A=0.2, xgb_B=0.1, cat_C=0.0, llm_D=0.7 - Score: 0.6128
# Saved submission to submission_top217_0.6128.csv
# Rank 218: lgb_A=0.0, xgb_B=0.2, cat_C=0.7, llm_D=0.1 - Score: 0.6126
# Saved submission to submission_top218_0.6126.csv
# Rank 219: lgb_A=0.4, xgb_B=0.0, cat_C=0.0, llm_D=0.6 - Score: 0.6124
# Saved submission to submission_top219_0.6124.csv
# Rank 220: lgb_A=0.3, xgb_B=0.0, cat_C=0.1, llm_D=0.6 - Score: 0.6124
# Saved submission to submission_top220_0.6124.csv
# Rank 221: lgb_A=0.2, xgb_B=0.0, cat_C=0.0, llm_D=0.8 - Score: 0.6120
# Saved submission to submission_top221_0.6120.csv
# Rank 222: lgb_A=0.3, xgb_B=0.0, cat_C=0.5, llm_D=0.2 - Score: 0.6117
# Saved submission to submission_top222_0.6117.csv
# Rank 223: lgb_A=0.5, xgb_B=0.0, cat_C=0.1, llm_D=0.4 - Score: 0.6112
# Saved submission to submission_top223_0.6112.csv
# Rank 224: lgb_A=0.1, xgb_B=0.1, cat_C=0.2, llm_D=0.6 - Score: 0.6110
# Saved submission to submission_top224_0.6110.csv
# Rank 225: lgb_A=0.0, xgb_B=0.1, cat_C=0.3, llm_D=0.6 - Score: 0.6107
# Saved submission to submission_top225_0.6107.csv
# Rank 226: lgb_A=0.2, xgb_B=0.1, cat_C=0.5, llm_D=0.2 - Score: 0.6103
# Saved submission to submission_top226_0.6103.csv
# Rank 227: lgb_A=0.1, xgb_B=0.1, cat_C=0.3, llm_D=0.5 - Score: 0.6098
# Saved submission to submission_top227_0.6098.csv
# Rank 228: lgb_A=0.0, xgb_B=0.0, cat_C=1.0, llm_D=0.0 - Score: 0.6094
# Saved submission to submission_top228_0.6094.csv
# Rank 229: lgb_A=0.3, xgb_B=0.0, cat_C=0.2, llm_D=0.5 - Score: 0.6093
# Saved submission to submission_top229_0.6093.csv
# Rank 230: lgb_A=0.2, xgb_B=0.1, cat_C=0.1, llm_D=0.6 - Score: 0.6089
# Saved submission to submission_top230_0.6089.csv
# Rank 231: lgb_A=0.1, xgb_B=0.2, cat_C=0.7, llm_D=0.0 - Score: 0.6089
# Saved submission to submission_top231_0.6089.csv
# Rank 232: lgb_A=0.1, xgb_B=0.1, cat_C=0.7, llm_D=0.1 - Score: 0.6085
# Saved submission to submission_top232_0.6085.csv
# Rank 233: lgb_A=0.1, xgb_B=0.0, cat_C=0.2, llm_D=0.7 - Score: 0.6079
# Saved submission to submission_top233_0.6079.csv
# Rank 234: lgb_A=0.0, xgb_B=0.2, cat_C=0.2, llm_D=0.6 - Score: 0.6073
# Saved submission to submission_top234_0.6073.csv
# Rank 235: lgb_A=0.0, xgb_B=0.1, cat_C=0.4, llm_D=0.5 - Score: 0.6071
# Saved submission to submission_top235_0.6071.csv
# Rank 236: lgb_A=0.3, xgb_B=0.0, cat_C=0.0, llm_D=0.7 - Score: 0.6070
# Saved submission to submission_top236_0.6070.csv
# Rank 237: lgb_A=0.3, xgb_B=0.0, cat_C=0.6, llm_D=0.1 - Score: 0.6065
# Saved submission to submission_top237_0.6065.csv
# Rank 238: lgb_A=0.1, xgb_B=0.2, cat_C=0.1, llm_D=0.6 - Score: 0.6062
# Saved submission to submission_top238_0.6062.csv
# Rank 239: lgb_A=0.3, xgb_B=0.0, cat_C=0.7, llm_D=0.0 - Score: 0.6062
# Saved submission to submission_top239_0.6062.csv
# Rank 240: lgb_A=0.1, xgb_B=0.1, cat_C=0.1, llm_D=0.7 - Score: 0.6061
# Saved submission to submission_top240_0.6061.csv
# Rank 241: lgb_A=0.3, xgb_B=0.1, cat_C=0.0, llm_D=0.6 - Score: 0.6058
# Saved submission to submission_top241_0.6058.csv
# Rank 242: lgb_A=0.0, xgb_B=0.0, cat_C=0.8, llm_D=0.2 - Score: 0.6056
# Saved submission to submission_top242_0.6056.csv
# Rank 243: lgb_A=0.2, xgb_B=0.0, cat_C=0.1, llm_D=0.7 - Score: 0.6056
# Saved submission to submission_top243_0.6056.csv
# Rank 244: lgb_A=0.1, xgb_B=0.1, cat_C=0.4, llm_D=0.4 - Score: 0.6052
# Saved submission to submission_top244_0.6052.csv
# Rank 245: lgb_A=0.0, xgb_B=0.3, cat_C=0.7, llm_D=0.0 - Score: 0.6052
# Saved submission to submission_top245_0.6052.csv
# Rank 246: lgb_A=0.2, xgb_B=0.1, cat_C=0.4, llm_D=0.3 - Score: 0.6051
# Saved submission to submission_top246_0.6051.csv
# Rank 247: lgb_A=0.1, xgb_B=0.1, cat_C=0.5, llm_D=0.3 - Score: 0.6051
# Saved submission to submission_top247_0.6051.csv
# Rank 248: lgb_A=0.0, xgb_B=0.2, cat_C=0.8, llm_D=0.0 - Score: 0.6050
# Saved submission to submission_top248_0.6050.csv
# Rank 249: lgb_A=0.0, xgb_B=0.2, cat_C=0.0, llm_D=0.8 - Score: 0.6049
# Saved submission to submission_top249_0.6049.csv
# Rank 250: lgb_A=0.1, xgb_B=0.1, cat_C=0.6, llm_D=0.2 - Score: 0.6048
# Saved submission to submission_top250_0.6048.csv
# Rank 251: lgb_A=0.1, xgb_B=0.0, cat_C=0.3, llm_D=0.6 - Score: 0.6047
# Saved submission to submission_top251_0.6047.csv
# Rank 252: lgb_A=0.2, xgb_B=0.0, cat_C=0.3, llm_D=0.5 - Score: 0.6043
# Saved submission to submission_top252_0.6043.csv
# Rank 253: lgb_A=0.0, xgb_B=0.0, cat_C=0.6, llm_D=0.4 - Score: 0.6029
# Saved submission to submission_top253_0.6029.csv
# Rank 254: lgb_A=0.2, xgb_B=0.0, cat_C=0.4, llm_D=0.4 - Score: 0.6027
# Saved submission to submission_top254_0.6027.csv
# Rank 255: lgb_A=0.0, xgb_B=0.1, cat_C=0.8, llm_D=0.1 - Score: 0.6026
# Saved submission to submission_top255_0.6026.csv
# Rank 256: lgb_A=0.0, xgb_B=0.1, cat_C=0.7, llm_D=0.2 - Score: 0.6026
# Saved submission to submission_top256_0.6026.csv
# Rank 257: lgb_A=0.0, xgb_B=0.1, cat_C=0.5, llm_D=0.4 - Score: 0.6026
# Saved submission to submission_top257_0.6026.csv
# Rank 258: lgb_A=0.1, xgb_B=0.1, cat_C=0.0, llm_D=0.8 - Score: 0.6023
# Saved submission to submission_top258_0.6023.csv
# Rank 259: lgb_A=0.1, xgb_B=0.1, cat_C=0.8, llm_D=0.0 - Score: 0.6003
# Saved submission to submission_top259_0.6003.csv
# Rank 260: lgb_A=0.0, xgb_B=0.0, cat_C=0.4, llm_D=0.6 - Score: 0.6003
# Saved submission to submission_top260_0.6003.csv
# Rank 261: lgb_A=0.1, xgb_B=0.0, cat_C=0.7, llm_D=0.2 - Score: 0.6001
# Saved submission to submission_top261_0.6001.csv
# Rank 262: lgb_A=0.1, xgb_B=0.0, cat_C=0.6, llm_D=0.3 - Score: 0.6001
# Saved submission to submission_top262_0.6001.csv
# Rank 263: lgb_A=0.0, xgb_B=0.1, cat_C=0.6, llm_D=0.3 - Score: 0.5996
# Saved submission to submission_top263_0.5996.csv
# Rank 264: lgb_A=0.1, xgb_B=0.0, cat_C=0.5, llm_D=0.4 - Score: 0.5992
# Saved submission to submission_top264_0.5992.csv
# Rank 265: lgb_A=0.1, xgb_B=0.0, cat_C=0.8, llm_D=0.1 - Score: 0.5990
# Saved submission to submission_top265_0.5990.csv
# Rank 266: lgb_A=0.2, xgb_B=0.0, cat_C=0.8, llm_D=0.0 - Score: 0.5990
# Saved submission to submission_top266_0.5990.csv
# Rank 267: lgb_A=0.1, xgb_B=0.0, cat_C=0.9, llm_D=0.0 - Score: 0.5990
# Saved submission to submission_top267_0.5990.csv
# Rank 268: lgb_A=0.0, xgb_B=0.1, cat_C=0.9, llm_D=0.0 - Score: 0.5989
# Saved submission to submission_top268_0.5989.csv
# Rank 269: lgb_A=0.0, xgb_B=0.2, cat_C=0.1, llm_D=0.7 - Score: 0.5987
# Saved submission to submission_top269_0.5987.csv
# Rank 270: lgb_A=0.0, xgb_B=0.0, cat_C=0.7, llm_D=0.3 - Score: 0.5983
# Saved submission to submission_top270_0.5983.csv
# Rank 271: lgb_A=0.0, xgb_B=0.0, cat_C=0.2, llm_D=0.8 - Score: 0.5982
# Saved submission to submission_top271_0.5982.csv
# Rank 272: lgb_A=0.0, xgb_B=0.0, cat_C=0.3, llm_D=0.7 - Score: 0.5980
# Saved submission to submission_top272_0.5980.csv
# Rank 273: lgb_A=0.2, xgb_B=0.0, cat_C=0.7, llm_D=0.1 - Score: 0.5961
# Saved submission to submission_top273_0.5961.csv
# Rank 274: lgb_A=0.2, xgb_B=0.0, cat_C=0.6, llm_D=0.2 - Score: 0.5961
# Saved submission to submission_top274_0.5961.csv
# Rank 275: lgb_A=0.1, xgb_B=0.0, cat_C=0.4, llm_D=0.5 - Score: 0.5943
# Saved submission to submission_top275_0.5943.csv
# Rank 276: lgb_A=0.0, xgb_B=0.0, cat_C=0.5, llm_D=0.5 - Score: 0.5942
# Saved submission to submission_top276_0.5942.csv
# Rank 277: lgb_A=0.0, xgb_B=0.0, cat_C=0.1, llm_D=0.9 - Score: 0.5937
# Saved submission to submission_top277_0.5937.csv
# Rank 278: lgb_A=0.2, xgb_B=0.0, cat_C=0.5, llm_D=0.3 - Score: 0.5931
# Saved submission to submission_top278_0.5931.csv
# Rank 279: lgb_A=0.0, xgb_B=0.1, cat_C=0.1, llm_D=0.8 - Score: 0.5902
# Saved submission to submission_top279_0.5902.csv
# Rank 280: lgb_A=0.0, xgb_B=0.1, cat_C=0.0, llm_D=0.9 - Score: 0.5825
# Saved submission to submission_top280_0.5825.csv
# Rank 281: lgb_A=0.1, xgb_B=0.0, cat_C=0.0, llm_D=0.9 - Score: 0.5728
# Saved submission to submission_top281_0.5728.csv
# Rank 282: lgb_A=0.0, xgb_B=0.0, cat_C=0.0, llm_D=1.0 - Score: 0.5426
# Saved submission to submission_top282_0.5426.csv
#
#  STEP3: 예측결과 비교표
#     학습sum  학습len  학습mean  테스트sum  테스트len  테스트mean
# Q1    223    450  0.4956     199     250   0.7960
# Q2    253    450  0.5622     240     250   0.9600
# Q3    270    450  0.6000     148     250   0.5920
# S1    390    450  0.8667     254     250   1.0160
# S2    293    450  0.6511     189     250   0.7560
# S3    298    450  0.6622     124     250   0.4960

# %% [markdown]
# ### 📦 이전제출과 비교

# %%
from pathlib import Path

# Reference file
reference_file = '/content/drive/MyDrive/data/ch2025_data_items/share/submissions/submission_top1_0.6492.csv'
ref_df = pd.read_csv(reference_file)

# Get all CSV files in data directory
data_dir = Path('./')
csv_files = list(data_dir.glob('*.csv'))

# Store differences for each file
differences = []

for csv_file in csv_files:
    if csv_file.name == os.path.basename(reference_file):
        continue

    # Read current file
    current_df = pd.read_csv(csv_file)

    # Calculate differences in specified columns
    diff_count = 0
    for col in ['Q1', 'Q2', 'Q3', 'S1', 'S2', 'S3']:
        diff_count += (ref_df[col] != current_df[col]).sum()

    differences.append((csv_file.name, diff_count))
    # print(f"File: {csv_file.name}, Differences: {diff_count}")

# Sort by difference count and get top 20
differences.sort(key=lambda x: x[1])
print("\nTop 10 files with smallest differences:")
for i, (file_name, diff_count) in enumerate(differences[:10], 1):
    print(f"{i}. {file_name}: {diff_count} differences")
# Out:
# Top 10 files with smallest differences:
# 1. submission_top37_0.6392.csv: 22 differences
# 2. submission_top147_0.6307.csv: 24 differences
# 3. submission_top96_0.6345.csv: 28 differences
# 4. submission_top48_0.6379.csv: 28 differences
# 5. submission_top81_0.6354.csv: 29 differences
# 6. submission_top38_0.6388.csv: 29 differences
# 7. submission_top94_0.6345.csv: 29 differences
# 8. submission_top31_0.6392.csv: 30 differences
# 9. submission_top104_0.6341.csv: 30 differences
# 10. submission_top3_0.6475.csv: 32 differences
